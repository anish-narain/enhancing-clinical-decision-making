# %% [markdown]
# # Dependencies

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# Inside terminal run the following:
#
# ```
# ollama serve &
# ollama run llama3
# ```

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.3-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 34.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain-0.2.2-py3-none-any.whl (973 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 973.6/973.6 kB 64.0 MB/s eta 0:00:00
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain_core-0.2.4-py3-none-any.whl (310 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.4/310.4 kB 41.8 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain_community)
#   Downloading langsmith-0.1.74-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.8/124.8 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.7 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.0->langchain_community)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.3)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.7 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain_community)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 23.8 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, typing-inspect, marshmallow, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.6 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.2 langchain-core-0.2.4 langchain-text-splitters-0.2.1 langchain_community-0.2.3 langsmith-0.1.74 marshmallow-3.21.3 mypy-extensions-1.0.0 orjson-3.10.3 packaging-23.2 typing-inspect-0.9.0

# %%
# Load Google Drive because it stores /content/drive/My Drive/ards-cohort-notes/ards-cohort-notes.csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
import pandas as pd
import time
import random
import csv
from langchain_community.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# # Functions to load data, specify LLM prompt, and perform LLM inference

# %%
def load_data(file_path):
    df = pd.read_csv(file_path)
    df.fillna('', inplace=True)
    return df

def select_random_start(num_rows, min_rows=15):
    if num_rows < min_rows:
        raise ValueError(f"The dataset must contain at least {min_rows} rows to process.")
    return random.randint(0, num_rows - min_rows)

def create_prompt_template():
    return PromptTemplate(
        template=(
            "Context: You are a clinician receiving chunks of clinical text for patients in an ICU. Please do the reviewing as quickly as possible.\n"
            "Task: Determine if the patient suffered from pancreatitis.\n"
            "Instructions: Answer with 'Yes' or 'No'. If there is not enough information, answer 'No'.\n"
            "Discharge Text:\n{discharge_text}\n\n"
            "Query: Does the chunk of text mention that the patient suffered from pancreatitis? Answer strictly in 'Yes' or 'No'."
        ),
        input_variables=["discharge_text"]
    )

def chunk_text(text, chunk_size, overlap):
    start = 0
    chunks = []
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

def check_for_pancreatitis(discharge_text, llm, prompt_template, chunk_size, chunk_overlap):
    chunks = chunk_text(discharge_text, chunk_size, chunk_overlap)
    results = []
    for chunk in chunks:
        prompt = prompt_template.format(discharge_text=chunk)
        try:
            response = llm.invoke(prompt)
            results.append(response.strip())
        except Exception as e:
            results.append(f"Error invoking model: {e}")
    pancreatitis_mentions = [res for res in results if "Yes" in res]
    if pancreatitis_mentions:
        return "Yes", pancreatitis_mentions[0], len(discharge_text) # Return pancreatitis result, explanation, and length of discharge_text
    else:
        return "No", results[0] if results else "No sufficient data", len(discharge_text) # Return pancreatitis result, explanation, and length of discharge_text

def process_patients(df, start_index, num_patients, llm, prompt_template, chunk_size, chunk_overlap, output_csv_file, progress_report_file):
    processing_time = []
    with open(output_csv_file, 'a', newline='') as csvfile, open(progress_report_file, 'a') as report_file:
        # Open the CSV file for writing
        fieldnames = ['hadm_id', 'discharge_text_length', 'pancreatitis_detected', 'time_taken']
        # Define the column names
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        # Only write header if the file is empty
        if csvfile.tell() == 0:
            writer.writeheader()  # Write the header row

        for i in range(start_index, start_index + num_patients):
            current_hadm_id = df['hadm_id'].values[i]
            start_time = time.time()
            data = df[df['hadm_id'] == current_hadm_id]
            if data.empty:
                result = f"No data found for hadm_id: {current_hadm_id}"
            else:
                discharge_text = data['discharge_text'].values[0]
                pancreatitis_result, explanation, discharge_text_length = check_for_pancreatitis(discharge_text, llm, prompt_template, chunk_size, chunk_overlap)
                end_time = time.time()
                elapsed_time = end_time - start_time
                minutes, seconds = divmod(elapsed_time, 60)
                processing_time.append(elapsed_time)
                # Write data to CSV file
                writer.writerow({
                    'hadm_id': current_hadm_id,
                    'discharge_text_length': discharge_text_length,
                    'pancreatitis_detected': pancreatitis_result,
                    'time_taken': round(elapsed_time)
                })
                csvfile.flush()  # Flush the buffer to ensure data is written

                # Write data to progress report file
                report_file.write(f"Patient Number: {i}, HADM ID: {current_hadm_id}, Discharge Text Length: {discharge_text_length}, Pancreatitis Detected: {pancreatitis_result}, Time Taken: {round(elapsed_time)}\n")
                report_file.flush()  # Flush the buffer to ensure data is written

                print(f"Processed Patient Number {i}\n")

# %% [markdown]
# # Main (calls all the functions above)

# %%
def main(file_path, model_name, chunk_size, chunk_overlap, output_csv_file, progress_report_file, num_patients):
    df = load_data(file_path)
    #start_index = select_random_start(len(df))
    start_index = 0
    prompt_template = create_prompt_template()
    llm = Ollama(model=model_name, callback_manager=CallbackManager([StreamingStdOutCallbackHandler()]))
    process_patients(df, start_index, num_patients, llm, prompt_template, chunk_size, chunk_overlap, output_csv_file, progress_report_file)

if __name__ == "__main__":
    main(
        file_path='/content/drive/My Drive/ards-cohort-notes/ards-cohort-notes.csv',
        model_name="llama3",
        chunk_size=4096,
        chunk_overlap=100,
        output_csv_file='pancreatitis-trial-2020.csv',  # Change the output file name to a CSV file
        progress_report_file='pancreatitis-trial-2020.txt',  # Path to the progress report file
        num_patients = 2021
    )
# Out:
# NoNoNoNoNoNo.NoProcessed Patient Number 0
#
# No.NoNoProcessed Patient Number 1
#
# NoNo.NoNoNoNoYesNoProcessed Patient Number 2
#
# NoNo.NoProcessed Patient Number 3
#
# NoNoNoProcessed Patient Number 4
#
# No.NoNo.NoNoProcessed Patient Number 5
#
# No.NoProcessed Patient Number 6
#
# NoProcessed Patient Number 7
#
# NoNoNoNoNoProcessed Patient Number 8
#
# NoNoNo.NoProcessed Patient Number 9
#
# NoNoNoNoProcessed Patient Number 10
#
# NoNoNo.No.Processed Patient Number 11
#
# No.NoNoProcessed Patient Number 12
#
# NoNoProcessed Patient Number 13
#
# NoNoNo.Processed Patient Number 14
#
# NoNoNoNoProcessed Patient Number 15
#
# NoNoNoNo.Processed Patient Number 16
#
# NoNo.Processed Patient Number 17
#
# NoI can help you with that!
#
# After reviewing the provided clinical text, I found no mentions of pancreatitis in any of the chunks. Therefore, my answer is:
#
# **No**
#
# Please let me know if there's anything else I can assist you with!NoNoNoNoNoProcessed Patient Number 18
#
# NoNoNoNoProcessed Patient Number 19
#
# NoNoNo.NoNoNoProcessed Patient Number 20
#
# NoNoNoNoProcessed Patient Number 21
#
# NoNoNoNoProcessed Patient Number 22
#
# YesNoNoProcessed Patient Number 23
#
# NoNo.NoNoNo.Processed Patient Number 24
#
# NoNoNo.No.Processed Patient Number 25
#
# NoNoNo.No.Processed Patient Number 26
#
# NoNoNoProcessed Patient Number 27
#
# No.NoProcessed Patient Number 28
#
# NoNoNoNoNoNoProcessed Patient Number 29
#
# NoNoNoNoProcessed Patient Number 30
#
# No.NoNo.Processed Patient Number 31
#
# NoNoProcessed Patient Number 32
#
# No.No.Processed Patient Number 33
#
# No.No.NoNoNo.NoProcessed Patient Number 34
#
# NoNo.NoProcessed Patient Number 35
#
# NoNoProcessed Patient Number 36
#
# NoNoNoNoNoNo.Processed Patient Number 37
#
# YesYesYesNo.Processed Patient Number 38
#
# No.NoProcessed Patient Number 39
#
# NoNo.NoProcessed Patient Number 40
#
# NoNoNoProcessed Patient Number 41
#
# YesYesYes.YesProcessed Patient Number 42
#
# YesNoNoNo.No.Processed Patient Number 43
#
# NoNoNoNoNo.Processed Patient Number 44
#
# NoNoNoNoProcessed Patient Number 45
#
# NoNoNoNoProcessed Patient Number 46
#
# NoNoNoProcessed Patient Number 47
#
# NoNo.No.NoNo.Processed Patient Number 48
#
# NoNoNoNo.Processed Patient Number 49
#
# NoNoNoNoProcessed Patient Number 50
#
# NoNoNoNoNo.No.Processed Patient Number 51
#
# No.No.No.NoNoNoNo.Processed Patient Number 52
#
# No.NoNoNoProcessed Patient Number 53
#
# No.NoNoProcessed Patient Number 54
#
# NoNo.No.No.NoProcessed Patient Number 55
#
# No.NoNoNo.Processed Patient Number 56
#
# NoNoNoNoNoProcessed Patient Number 57
#
# YesNoNo.Processed Patient Number 58
#
# NoNoNo.NoNoNoProcessed Patient Number 59
#
# NoNoNoProcessed Patient Number 60
#
# NoNoNoNoProcessed Patient Number 61
#
# YesNoNoProcessed Patient Number 62
#
# NoNoNoNoProcessed Patient Number 63
#
# YesNoNoNo.NoProcessed Patient Number 64
#
# NoNoNo.NoNoNoNo.NoNoProcessed Patient Number 65
#
# No.NoNoProcessed Patient Number 66
#
# NoNoNoNoNo.Processed Patient Number 67
#
# NoNoProcessed Patient Number 68
#
# Yes.NoYes.NoNoNoNoProcessed Patient Number 69
#
# NoNo.NoNoNoProcessed Patient Number 70
#
# NoNoNo.NoProcessed Patient Number 71
#
# NoNoNoNoNoProcessed Patient Number 72
#
# NoNoNoProcessed Patient Number 73
#
# No.YesNoProcessed Patient Number 74
#
# NoNoNoProcessed Patient Number 75
#
# No.NoNoNoNo.Processed Patient Number 76
#
# No.NoNoNo.Processed Patient Number 77
#
# Yes.YesNo.Processed Patient Number 78
#
# NoNoProcessed Patient Number 79
#
# YesNoNoNo.Processed Patient Number 80
#
# NoNoNoNoProcessed Patient Number 81
#
# No.NoNo.NoNoNoNoNoNoProcessed Patient Number 82
#
# NoNoNoNoNoNoNoNo.Processed Patient Number 83
#
# NoNoNo.NoNo.Processed Patient Number 84
#
# NoNoNoNoNo.NoProcessed Patient Number 85
#
# YesYesNoNoProcessed Patient Number 86
#
# No.NoNoNoProcessed Patient Number 87
#
# No.NoNoNoNoNoNoProcessed Patient Number 88
#
# No.NoNoNo.No.Processed Patient Number 89
#
# NoNo.NoNoNoNo.Processed Patient Number 90
#
# NoNoNo.Processed Patient Number 91
#
# NoNoNoNoProcessed Patient Number 92
#
# NoNoNoNoNoNoProcessed Patient Number 93
#
# NoNoNoNoNoNoProcessed Patient Number 94
#
# NoNoNoNoProcessed Patient Number 95
#
# NoNoProcessed Patient Number 96
#
# YesYesYesYesProcessed Patient Number 97
#
# NoNo.NoNoNo.Processed Patient Number 98
#
# NoNoNoNoNoNo.NoProcessed Patient Number 99
#
# NoNoNo.No.NoNo.No.Processed Patient Number 100
#
# NoNo.NoProcessed Patient Number 101
#
# No.Processed Patient Number 102
#
# NoNoNoNoNoProcessed Patient Number 103
#
# NoNoProcessed Patient Number 104
#
# NoNo.NoNoProcessed Patient Number 105
#
# NoNoNoNo.Processed Patient Number 106
#
# No.NoYesNoNoNoNoNo.YesNo.NoProcessed Patient Number 107
#
# No.NoNoNoNoProcessed Patient Number 108
#
# NoNoNo.NoNoNo.Processed Patient Number 109
#
# NoNo.NoNo.Processed Patient Number 110
#
# NoNoNoProcessed Patient Number 111
#
# NoNoNo.No.Processed Patient Number 112
#
# NoNoNoNoNoProcessed Patient Number 113
#
# NoNoNoNoNoProcessed Patient Number 114
#
# NoNoNo.No.Processed Patient Number 115
#
# NoNoNoNoProcessed Patient Number 116
#
# NoNoNoProcessed Patient Number 117
#
# No.NoNoNoProcessed Patient Number 118
#
# YesNoNoNo.NoProcessed Patient Number 119
#
# NoNoNoProcessed Patient Number 120
#
# NoNoNo.Processed Patient Number 121
#
# YesNoNoYesNoNoProcessed Patient Number 122
#
# NoNoNoNoNoProcessed Patient Number 123
#
# NoNoNoProcessed Patient Number 124
#
# NoNoNo.NoNoNoProcessed Patient Number 125
#
# NoNo.NoNoProcessed Patient Number 126
#
# NoNoProcessed Patient Number 127
#
# YesNoNoProcessed Patient Number 128
#
# NoNoNoNoNoProcessed Patient Number 129
#
# No.NoNoNoProcessed Patient Number 130
#
# NoYesNoNoProcessed Patient Number 131
#
# NoNoNoProcessed Patient Number 132
#
# NoNoNoNo.No.Processed Patient Number 133
#
# NoNoNoNo.Processed Patient Number 134
#
# NoNoNoNoNoNoProcessed Patient Number 135
#
# NoNo.Processed Patient Number 136
#
# No.NoNoNoProcessed Patient Number 137
#
# No.NoNoNoNo.NoNoProcessed Patient Number 138
#
# No.NoNoNoNoNoProcessed Patient Number 139
#
# NoYesYesYesNoProcessed Patient Number 140
#
# NoNoNoNo.Processed Patient Number 141
#
# NoNoNoNoNo.NoProcessed Patient Number 142
#
# NoNoNoProcessed Patient Number 143
#
# NoNoNoNoNoProcessed Patient Number 144
#
# NoNoNoNoNoNoNoProcessed Patient Number 145
#
# NoNoNoNo.Processed Patient Number 146
#
# YesYesYesYesYesProcessed Patient Number 147
#
# No.No.NoNo.Processed Patient Number 148
#
# No.NoNoNoProcessed Patient Number 149
#
# YesNoNo.NoNoProcessed Patient Number 150
#
# NoNoNoProcessed Patient Number 151
#
# No.NoNo.NoNoNoNoNoProcessed Patient Number 152
#
# NoNoNoProcessed Patient Number 153
#
# NoNoNoNo.Processed Patient Number 154
#
# NoNoNoNoNo.NoNo.Processed Patient Number 155
#
# NoNoProcessed Patient Number 156
#
# No.NoNo.NoProcessed Patient Number 157
#
# No.No.No.NoProcessed Patient Number 158
#
# NoNo.NoNoNoProcessed Patient Number 159
#
# NoNoProcessed Patient Number 160
#
# NoNo.NoProcessed Patient Number 161
#
# NoNo.No.NoNoNo.NoProcessed Patient Number 162
#
# NoNoNo.No.Processed Patient Number 163
#
# NoNo.NoProcessed Patient Number 164
#
# YesNoNoProcessed Patient Number 165
#
# NoNoNo.Processed Patient Number 166
#
# NoNoNoNo.Processed Patient Number 167
#
# YesYesProcessed Patient Number 168
#
# NoNoNoProcessed Patient Number 169
#
# No.NoNoNoNoNo.Processed Patient Number 170
#
# NoNoNoNoProcessed Patient Number 171
#
# No.NoProcessed Patient Number 172
#
# NoNoNoNoNoProcessed Patient Number 173
#
# NoNoNoNoProcessed Patient Number 174
#
# YesNoNoNo.Processed Patient Number 175
#
# NoNoNoNo.Processed Patient Number 176
#
# No.NoNoNoNoProcessed Patient Number 177
#
# No.NoNoNoProcessed Patient Number 178
#
# NoNoNoNo.Processed Patient Number 179
#
# NoNoNoNoNo.Processed Patient Number 180
#
# NoNoNo.Processed Patient Number 181
#
# NoNoNo.NoProcessed Patient Number 182
#
# NoNoNo.NoNoNoNoNoProcessed Patient Number 183
#
# No.NoNoNoNoProcessed Patient Number 184
#
# No.NoNoProcessed Patient Number 185
#
# NoNo.NoProcessed Patient Number 186
#
# No.NoNo.Processed Patient Number 187
#
# NoNoNoProcessed Patient Number 188
#
# NoNoNoProcessed Patient Number 189
#
# NoNoNoNoNoProcessed Patient Number 190
#
# NoNoNo.Processed Patient Number 191
#
# NoNoNoProcessed Patient Number 192
#
# NoNo.No.NoNo.No.Processed Patient Number 193
#
# NoNoNo.NoProcessed Patient Number 194
#
# NoNoNo.NoNo.Processed Patient Number 195
#
# No.NoNoProcessed Patient Number 196
#
# NoNo.NoNoProcessed Patient Number 197
#
# NoNoNoNoNoNoNo.Processed Patient Number 198
#
# NoNoNoNo.Processed Patient Number 199
#
# NoNoNoNoNoProcessed Patient Number 200
#
# NoNoNoProcessed Patient Number 201
#
# NoNo.Processed Patient Number 202
#
# NoNoNoNoProcessed Patient Number 203
#
# NoNo.NoNoNo.Processed Patient Number 204
#
# NoNoProcessed Patient Number 205
#
# NoNoNoNoProcessed Patient Number 206
#
# NoNoNoNoNoProcessed Patient Number 207
#
# NoNoNoNoProcessed Patient Number 208
#
# YesYesYesProcessed Patient Number 209
#
# No.NoNoNoNoNo.NoProcessed Patient Number 210
#
# NoNoNoNoNoNo.Processed Patient Number 211
#
# NoNoNoNo.Processed Patient Number 212
#
# NoNoNoNoNoNoNoProcessed Patient Number 213
#
# NoNoNo.No.NoNoProcessed Patient Number 214
#
# NoNoYesNoNoNoProcessed Patient Number 215
#
# No.No.No.NoNo.No.Processed Patient Number 216
#
# NoYes.NoNo.Processed Patient Number 217
#
# YesNo.NoNo.Processed Patient Number 218
#
# NoNoProcessed Patient Number 219
#
# NoNoNoNo.Processed Patient Number 220
#
# NoNoNoProcessed Patient Number 221
#
# NoNoNo.Processed Patient Number 222
#
# NoNoYesNoNoProcessed Patient Number 223
#
# No.NoNoNoNo.Processed Patient Number 224
#
# NoNoNo.NoProcessed Patient Number 225
#
# NoNo.Processed Patient Number 226
#
# NoNoNo.Processed Patient Number 227
#
# NoNoNo.NoProcessed Patient Number 228
#
# NoNoNoNo.Processed Patient Number 229
#
# No.No.Processed Patient Number 230
#
# No.NoNoNo.No.Processed Patient Number 231
#
# NoNoNoNo.Processed Patient Number 232
#
# NoNoNoNoProcessed Patient Number 233
#
# NoNoNo.NoNoProcessed Patient Number 234
#
# No.No.NoNo.NoNo.No.Processed Patient Number 235
#
# NoNoNo.No.Processed Patient Number 236
#
# NoNoNoProcessed Patient Number 237
#
# NoNoNoProcessed Patient Number 238
#
# NoNoNoNo.Processed Patient Number 239
#
# NoNoNoProcessed Patient Number 240
#
# NoYesProcessed Patient Number 241
#
# No.NoNoNo.Processed Patient Number 242
#
# YesYesYesYesNoProcessed Patient Number 243
#
# NoNoNo.No.NoNoProcessed Patient Number 244
#
# NoNoNoProcessed Patient Number 245
#
# NoNo.YesNo.Processed Patient Number 246
#
# YesNo.NoNo.Processed Patient Number 247
#
# NoNoNo.Processed Patient Number 248
#
# NoNoNoNoNoNoNo.Processed Patient Number 249
#
# NoNo.Processed Patient Number 250
#
# NoNoNo.NoProcessed Patient Number 251
#
# No.NoNoProcessed Patient Number 252
#
# NoNoNo.No.Processed Patient Number 253
#
# Yes.YesYesYesYesProcessed Patient Number 254
#
# YesNoNoProcessed Patient Number 255
#
# No.NoNoNoNoNo.Processed Patient Number 256
#
# No.NoNoNoNoNoProcessed Patient Number 257
#
# NoNoNoNoNoNoProcessed Patient Number 258
#
# No.NoNo.Processed Patient Number 259
#
# No.NoNoNoNoProcessed Patient Number 260
#
# YesNoNoNoNoNoProcessed Patient Number 261
#
# NoNoNoNoNoNoProcessed Patient Number 262
#
# NoNoNoNoNoProcessed Patient Number 263
#
# No.No.NoNoProcessed Patient Number 264
#
# NoNoNo.Processed Patient Number 265
#
# NoNoNoProcessed Patient Number 266
#
# NoNoNoNoProcessed Patient Number 267
#
# NoNoNoNo.Processed Patient Number 268
#
# No.NoNoNo.Processed Patient Number 269
#
# NoNoNoProcessed Patient Number 270
#
# NoNoNoNo.No.Processed Patient Number 271
#
# NoNoProcessed Patient Number 272
#
# No.NoNoNoNoNoNo.Processed Patient Number 273
#
# NoNo.NoNoNoNo.NoProcessed Patient Number 274
#
# YesNoNoNoNoNoProcessed Patient Number 275
#
# NoNoNoProcessed Patient Number 276
#
# YesYesYesYesYesNoProcessed Patient Number 277
#
# NoNo.NoProcessed Patient Number 278
#
# NoNoNoProcessed Patient Number 279
#
# NoYesNoNo.Processed Patient Number 280
#
# NoNoNoProcessed Patient Number 281
#
# YesNo.NoNo.Processed Patient Number 282
#
# NoNoNoNoProcessed Patient Number 283
#
# NoNoNoProcessed Patient Number 284
#
# NoNoNoNoNoProcessed Patient Number 285
#
# NoProcessed Patient Number 286
#
# No.NoNoNoProcessed Patient Number 287
#
# NoNoNoProcessed Patient Number 288
#
# NoNoNoNoNoProcessed Patient Number 289
#
# NoNoNoNoNo.Processed Patient Number 290
#
# No.YesNoNo.No.NoNoProcessed Patient Number 291
#
# No.NoNoNo.Processed Patient Number 292
#
# NoNo.No.Processed Patient Number 293
#
# NoNoNoNoNoProcessed Patient Number 294
#
# NoNoNoNo.Processed Patient Number 295
#
# NoNoProcessed Patient Number 296
#
# NoYesNoProcessed Patient Number 297
#
# No.NoNo.Processed Patient Number 298
#
# NoNoNo.NoNoProcessed Patient Number 299
#
# NoNo.NoNoNoNoNoNo.Processed Patient Number 300
#
# NoNo.No.Processed Patient Number 301
#
# NoNoNoNoNoProcessed Patient Number 302
#
# NoNo.Processed Patient Number 303
#
# NoNoProcessed Patient Number 304
#
# YesYesYesNoProcessed Patient Number 305
#
# NoNoNoNoNoNoProcessed Patient Number 306
#
# NoNo.Processed Patient Number 307
#
# NoNoNoNoNoNoNoNoNoNoProcessed Patient Number 308
#
# NoProcessed Patient Number 309
#
# NoNoNoProcessed Patient Number 310
#
# NoNoProcessed Patient Number 311
#
# NoNo.No.Processed Patient Number 312
#
# No.NoNo.NoProcessed Patient Number 313
#
# NoNoNo.Processed Patient Number 314
#
# NoNo.NoProcessed Patient Number 315
#
# NoNoNoNoProcessed Patient Number 316
#
# NoNoNoProcessed Patient Number 317
#
# NoNoNoNoNoProcessed Patient Number 318
#
# NoNoNoNo.NoNoNoNoProcessed Patient Number 319
#
# NoNoNoNoProcessed Patient Number 320
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 321
#
# NoNoNoNoProcessed Patient Number 322
#
# Yes.Processed Patient Number 323
#
# NoNoNoNo.Processed Patient Number 324
#
# NoNoNoNoProcessed Patient Number 325
#
# NoNoNoNoNoNoNo.NoProcessed Patient Number 326
#
# NoNoNoNoNo.Processed Patient Number 327
#
# NoNo.NoNo.No.Processed Patient Number 328
#
# NoNoNoNo.Processed Patient Number 329
#
# YesNo.YesNoNo.No.Processed Patient Number 330
#
# NoNo.Processed Patient Number 331
#
# NoNo.No.Processed Patient Number 332
#
# NoNoNoNoNoNoNoProcessed Patient Number 333
#
# NoNoNoNoProcessed Patient Number 334
#
# NoNoNoNoNoNoNoNo.NoProcessed Patient Number 335
#
# YesNoNoProcessed Patient Number 336
#
# NoNoNoNoNoNo.NoProcessed Patient Number 337
#
# NoNoNoProcessed Patient Number 338
#
# NoNoNo.NoNoNoProcessed Patient Number 339
#
# NoNoNoProcessed Patient Number 340
#
# YesNoNoProcessed Patient Number 341
#
# YesNoNoNoProcessed Patient Number 342
#
# NoNoNo.NoNoProcessed Patient Number 343
#
# NoNoNoProcessed Patient Number 344
#
# NoNoNoNoNoNoNoProcessed Patient Number 345
#
# NoNoProcessed Patient Number 346
#
# No.NoNoNoNoProcessed Patient Number 347
#
# NoNoNoNoNo.No.NoProcessed Patient Number 348
#
# No.NoProcessed Patient Number 349
#
# NoNoNoNoNoNo.Processed Patient Number 350
#
# No.NoNoProcessed Patient Number 351
#
# NoNoNoNoNo.Processed Patient Number 352
#
# No.Processed Patient Number 353
#
# NoNoNoNoProcessed Patient Number 354
#
# No.NoNoNoNoNoProcessed Patient Number 355
#
# NoNoNoNoNoNoNoNoNoNoProcessed Patient Number 356
#
# NoNoProcessed Patient Number 357
#
# No.No.Processed Patient Number 358
#
# YesNo.YesNoProcessed Patient Number 359
#
# NoNoNoNoNoProcessed Patient Number 360
#
# Yes.NoNoNoNoNoNoNoNoNo.Processed Patient Number 361
#
# NoNoNoProcessed Patient Number 362
#
# No.NoNoProcessed Patient Number 363
#
# YesYesYesYesProcessed Patient Number 364
#
# NoNo.NoProcessed Patient Number 365
#
# NoNoNoProcessed Patient Number 366
#
# NoNoNo.NoNo.No.Processed Patient Number 367
#
# No.NoNo.No.Processed Patient Number 368
#
# NoNo.NoProcessed Patient Number 369
#
# No.NoNoNoProcessed Patient Number 370
#
# NoNoNoProcessed Patient Number 371
#
# NoNo.No.Processed Patient Number 372
#
# YesNoNoNoNoProcessed Patient Number 373
#
# NoYesNoNoNoProcessed Patient Number 374
#
# No.YesNoNoProcessed Patient Number 375
#
# NoNoNoNoNoProcessed Patient Number 376
#
# NoNoNoProcessed Patient Number 377
#
# NoNoNoNoNoNoProcessed Patient Number 378
#
# NoNoNo.NoNoNoNo.Processed Patient Number 379
#
# NoNo.NoNo.NoProcessed Patient Number 380
#
# No.NoNoNo.NoProcessed Patient Number 381
#
# NoNo.No.NoNoNoNoNoNoNoNo.Processed Patient Number 382
#
# NoNoNoNoProcessed Patient Number 383
#
# NoNoNoNoNoProcessed Patient Number 384
#
# NoNoNoNo.Processed Patient Number 385
#
# NoNoNoNoYesYesNoYesProcessed Patient Number 386
#
# NoNo.NoProcessed Patient Number 387
#
# NoNoNoNo.Processed Patient Number 388
#
# NoNoNoProcessed Patient Number 389
#
# NoNoNoNoNoNoProcessed Patient Number 390
#
# NoNoNoProcessed Patient Number 391
#
# No.NoProcessed Patient Number 392
#
# NoNo.NoProcessed Patient Number 393
#
# NoNoNo.Processed Patient Number 394
#
# NoNo.NoNoNoProcessed Patient Number 395
#
# NoNoNoNoNoProcessed Patient Number 396
#
# YesNo.NoNoProcessed Patient Number 397
#
# NoNoNo.NoNoNoProcessed Patient Number 398
#
# NoNo.No.NoNoProcessed Patient Number 399
#
# No.NoNoProcessed Patient Number 400
#
# NoNoNoProcessed Patient Number 401
#
# NoNoNoNoYes.Processed Patient Number 402
#
# NoNoNoProcessed Patient Number 403
#
# NoNoNoNoNoProcessed Patient Number 404
#
# No.NoNoNo.Processed Patient Number 405
#
# NoNoProcessed Patient Number 406
#
# NoNoNoNo.Processed Patient Number 407
#
# NoNoNoNo.NoNoProcessed Patient Number 408
#
# NoNoNoProcessed Patient Number 409
#
# NoNoNoProcessed Patient Number 410
#
# NoNoNoProcessed Patient Number 411
#
# No.NoNoNoNoNoProcessed Patient Number 412
#
# NoNoNoNo.NoProcessed Patient Number 413
#
# NoNoNoProcessed Patient Number 414
#
# NoNoYesNoNo.NoNoNoProcessed Patient Number 415
#
# NoNoNoNoProcessed Patient Number 416
#
# NoNoNoNo.Processed Patient Number 417
#
# No.NoNoNoProcessed Patient Number 418
#
# NoNoNoNoNo.Processed Patient Number 419
#
# YesNoNoYesProcessed Patient Number 420
#
# YesYesYesNoNoNoProcessed Patient Number 421
#
# NoNoNoNo.NoNoProcessed Patient Number 422
#
# No.NoNoNoNoNoProcessed Patient Number 423
#
# NoNoNoNoNoProcessed Patient Number 424
#
# NoNoNoNoNo.NoProcessed Patient Number 425
#
# YesNoNoProcessed Patient Number 426
#
# NoNo.NoNoProcessed Patient Number 427
#
# NoNoNoNoNoProcessed Patient Number 428
#
# NoNoNoNoProcessed Patient Number 429
#
# No.NoNoNoNoNoProcessed Patient Number 430
#
# NoNoProcessed Patient Number 431
#
# NoNoNo.NoNoProcessed Patient Number 432
#
# NoNoNoProcessed Patient Number 433
#
# NoNoNoNoProcessed Patient Number 434
#
# NoNoProcessed Patient Number 435
#
# NoNo.NoNo.NoProcessed Patient Number 436
#
# NoNoYesNoNoProcessed Patient Number 437
#
# NoNoNoNo.Processed Patient Number 438
#
# NoNoNoNoNoProcessed Patient Number 439
#
# NoNoProcessed Patient Number 440
#
# NoNoNoNo.NoProcessed Patient Number 441
#
# NoNoNoProcessed Patient Number 442
#
# NoNoNoNoNoProcessed Patient Number 443
#
# No.NoNoNoNoProcessed Patient Number 444
#
# NoNoNo.Processed Patient Number 445
#
# No.NoNoNoProcessed Patient Number 446
#
# No.NoYesNoNoProcessed Patient Number 447
#
# No.NoNoNoNo.No.Processed Patient Number 448
#
# NoNoNoNoNoNoNoProcessed Patient Number 449
#
# NoNoNoNo.Processed Patient Number 450
#
# NoNoNoNoProcessed Patient Number 451
#
# NoNoNoNoNoProcessed Patient Number 452
#
# NoNoNoProcessed Patient Number 453
#
# No.NoNoNo.Processed Patient Number 454
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 455
#
# NoNoNoNoProcessed Patient Number 456
#
# No.NoNoNoProcessed Patient Number 457
#
# NoNoNoNo.Processed Patient Number 458
#
# NoNoNoNoNoProcessed Patient Number 459
#
# NoNoNoNo.No.Processed Patient Number 460
#
# NoNoNoNoProcessed Patient Number 461
#
# NoNoNoNoNoProcessed Patient Number 462
#
# No.NoNoNo.No.NoNo.No.Processed Patient Number 463
#
# No.NoNoNoNoProcessed Patient Number 464
#
# YesYesNoNoYes.Processed Patient Number 465
#
# NoNo.NoNoNoNoNoNo.Processed Patient Number 466
#
# NoNoNoNoProcessed Patient Number 467
#
# NoNo.Processed Patient Number 468
#
# NoNoNoNo.Processed Patient Number 469
#
# No.NoNoNoNo.NoProcessed Patient Number 470
#
# NoNoNo.Processed Patient Number 471
#
# NoNoProcessed Patient Number 472
#
# YesYes.YesProcessed Patient Number 473
#
# NoNoNoNoNo.NoProcessed Patient Number 474
#
# No.No.NoNoNoProcessed Patient Number 475
#
# NoNoNoNoNoProcessed Patient Number 476
#
# No.NoProcessed Patient Number 477
#
# NoNoNoProcessed Patient Number 478
#
# NoNoNoNoNo.Processed Patient Number 479
#
# No.NoNo.Processed Patient Number 480
#
# NoNoNoNo.No.Processed Patient Number 481
#
# No.NoNoNo.Processed Patient Number 482
#
# No.NoNoNoNoProcessed Patient Number 483
#
# NoNoNoProcessed Patient Number 484
#
# NoNoNoNoProcessed Patient Number 485
#
# YesNo.YesNoNoNoNoProcessed Patient Number 486
#
# No.NoNoNoProcessed Patient Number 487
#
# NoNoNoNoNoNo.NoNoNoNoProcessed Patient Number 488
#
# NoNoNoNo.Processed Patient Number 489
#
# NoNo.NoNo.NoProcessed Patient Number 490
#
# NoNoNoProcessed Patient Number 491
#
# NoNo.NoNoNoProcessed Patient Number 492
#
# NoNoNoNoProcessed Patient Number 493
#
# NoNoNoProcessed Patient Number 494
#
# No.No.NoNo.NoNoNoNoProcessed Patient Number 495
#
# NoNoProcessed Patient Number 496
#
# YesNoNoNoNoProcessed Patient Number 497
#
# NoNoNoNoNoProcessed Patient Number 498
#
# NoNoNoProcessed Patient Number 499
#
# NoNoNoProcessed Patient Number 500
#
# No.NoNo.Processed Patient Number 501
#
# YesYesYesYesNo.Processed Patient Number 502
#
# No.NoNoNoNoProcessed Patient Number 503
#
# NoNoProcessed Patient Number 504
#
# NoNoNoNoNoProcessed Patient Number 505
#
# YesYesNoNoNo.Processed Patient Number 506
#
# NoNoNoProcessed Patient Number 507
#
# YesNo.NoProcessed Patient Number 508
#
# YesYes.YesYesYesYesNoYesProcessed Patient Number 509
#
# NoNoNo.NoNoProcessed Patient Number 510
#
# NoNoNoProcessed Patient Number 511
#
# No.NoNoNoNo.NoProcessed Patient Number 512
#
# NoNoNoNoProcessed Patient Number 513
#
# NoNoProcessed Patient Number 514
#
# NoNoNoNoProcessed Patient Number 515
#
# NoNo.NoNoProcessed Patient Number 516
#
# NoNo.Processed Patient Number 517
#
# NoNoNoProcessed Patient Number 518
#
# NoNoNoProcessed Patient Number 519
#
# NoNoNoProcessed Patient Number 520
#
# No.NoNoNoNoNoProcessed Patient Number 521
#
# NoNoNoNoNoProcessed Patient Number 522
#
# NoNoNoNoYesNo.Processed Patient Number 523
#
# NoNo.NoNoNoProcessed Patient Number 524
#
# NoNoNoNoProcessed Patient Number 525
#
# NoNoNoNoProcessed Patient Number 526
#
# NoNoNoProcessed Patient Number 527
#
# NoNoNoNoProcessed Patient Number 528
#
# NoNoNoNo.No.Processed Patient Number 529
#
# NoNoNo.No.Processed Patient Number 530
#
# NoNoNoProcessed Patient Number 531
#
# NoNoNo.Processed Patient Number 532
#
# NoNo.NoProcessed Patient Number 533
#
# NoNoNo.Processed Patient Number 534
#
# NoNoNoProcessed Patient Number 535
#
# NoNoProcessed Patient Number 536
#
# No.NoProcessed Patient Number 537
#
# No.NoNoNoNoNoProcessed Patient Number 538
#
# No.NoNoNoNoProcessed Patient Number 539
#
# NoNoNoProcessed Patient Number 540
#
# NoNoNoNoNoProcessed Patient Number 541
#
# No.NoNoNoNoProcessed Patient Number 542
#
# NoNoProcessed Patient Number 543
#
# NoNo.NoNoNoNoProcessed Patient Number 544
#
# NoNoNo.Processed Patient Number 545
#
# NoNoNoNo.Processed Patient Number 546
#
# No.NoNoNoNoNo.NoProcessed Patient Number 547
#
# NoNo.Processed Patient Number 548
#
# NoNoNo.Processed Patient Number 549
#
# NoNoNo.Processed Patient Number 550
#
# NoNo.NoNoProcessed Patient Number 551
#
# NoNoNoNoNoProcessed Patient Number 552
#
# No.NoNo.NoNoNoProcessed Patient Number 553
#
# NoNo.Processed Patient Number 554
#
# No.NoNo.NoNo.NoProcessed Patient Number 555
#
# NoYesNoNoNo.Processed Patient Number 556
#
# NoNoNoProcessed Patient Number 557
#
# No.NoNoNoNo.Processed Patient Number 558
#
# NoNo.No.Processed Patient Number 559
#
# NoNo.NoNoNoProcessed Patient Number 560
#
# NoNo.Processed Patient Number 561
#
# NoNoYesYesNoProcessed Patient Number 562
#
# No.NoNo.NoNo.NoProcessed Patient Number 563
#
# NoNoNoProcessed Patient Number 564
#
# NoNoNoNo.NoNo.Processed Patient Number 565
#
# No.NoNoProcessed Patient Number 566
#
# No.NoNoProcessed Patient Number 567
#
# No.NoNoProcessed Patient Number 568
#
# NoNoNo.NoProcessed Patient Number 569
#
# NoNoNoProcessed Patient Number 570
#
# No.NoNoNoNo.Processed Patient Number 571
#
# No.NoNo.NoNoNoProcessed Patient Number 572
#
# NoNoNoNoNo.Processed Patient Number 573
#
# NoNoNoProcessed Patient Number 574
#
# NoNoNoNoNoProcessed Patient Number 575
#
# No.NoNoNoNo.Processed Patient Number 576
#
# NoNo.No.Processed Patient Number 577
#
# No.NoNoProcessed Patient Number 578
#
# NoNoNoNoNoProcessed Patient Number 579
#
# YesNoNoNoYes.YesYesYesYesYesProcessed Patient Number 580
#
# No.NoNoNo.Processed Patient Number 581
#
# No.No.Processed Patient Number 582
#
# No.NoNo.No.No.Processed Patient Number 583
#
# NoNoNoProcessed Patient Number 584
#
# NoNoProcessed Patient Number 585
#
# No.NoNoNoNoProcessed Patient Number 586
#
# NoNo.NoNoNoNo.Processed Patient Number 587
#
# NoNoNo.NoProcessed Patient Number 588
#
# NoNoNoProcessed Patient Number 589
#
# NoNoNoNo.Processed Patient Number 590
#
# NoNoNo.NoNo.NoNoNoNoNoProcessed Patient Number 591
#
# NoNo.NoProcessed Patient Number 592
#
# NoYesNoNoProcessed Patient Number 593
#
# NoNoNo.Processed Patient Number 594
#
# NoNoNoNoNoNoProcessed Patient Number 595
#
# NoNoNoNoNoProcessed Patient Number 596
#
# NoNoNoNoProcessed Patient Number 597
#
# NoNo.Processed Patient Number 598
#
# No.No.NoNoNoProcessed Patient Number 599
#
# NoNo.NoProcessed Patient Number 600
#
# No.NoProcessed Patient Number 601
#
# NoNoNoNoProcessed Patient Number 602
#
# NoNoNo.NoNoNoProcessed Patient Number 603
#
# NoNoNoNoProcessed Patient Number 604
#
# NoNoNo.NoNoProcessed Patient Number 605
#
# NoNoNoNo.Processed Patient Number 606
#
# NoNoNoNoProcessed Patient Number 607
#
# NoNoNoNoProcessed Patient Number 608
#
# NoNoNoNoProcessed Patient Number 609
#
# NoNoNoProcessed Patient Number 610
#
# NoNoNoNoNo.NoNo.NoProcessed Patient Number 611
#
# NoNoNo.NoNoNoProcessed Patient Number 612
#
# NoNo.NoProcessed Patient Number 613
#
# No.NoNoNoNo.Processed Patient Number 614
#
# NoNoNoNoProcessed Patient Number 615
#
# NoNo.NoProcessed Patient Number 616
#
# NoNoProcessed Patient Number 617
#
# No.NoProcessed Patient Number 618
#
# No.No.NoProcessed Patient Number 619
#
# NoNoNo.NoNoNoNo.Processed Patient Number 620
#
# NoNoNoNoNoProcessed Patient Number 621
#
# NoNoNoNoNoProcessed Patient Number 622
#
# NoNoNoNoProcessed Patient Number 623
#
# NoNoNoNoNoNo.Processed Patient Number 624
#
# NoNoNoNoNo.NoProcessed Patient Number 625
#
# No.NoNo.No.NoProcessed Patient Number 626
#
# NoNoNoNoProcessed Patient Number 627
#
# NoNoYesYesNoProcessed Patient Number 628
#
# NoNoNo.Processed Patient Number 629
#
# NoNo.NoProcessed Patient Number 630
#
# No.NoProcessed Patient Number 631
#
# No.NoNoNoNoNoProcessed Patient Number 632
#
# NoNoNoNoNo.Processed Patient Number 633
#
# NoNoNoProcessed Patient Number 634
#
# YesNoNo.Processed Patient Number 635
#
# No.No.No.Processed Patient Number 636
#
# NoNo.NoProcessed Patient Number 637
#
# NoNo.No.NoNo.Processed Patient Number 638
#
# NoNo.NoNoNoNoNoNoNoProcessed Patient Number 639
#
# No.NoProcessed Patient Number 640
#
# No.No.NoNo.No.NoProcessed Patient Number 641
#
# No.No.NoNoProcessed Patient Number 642
#
# NoNoNoNoProcessed Patient Number 643
#
# NoNo.NoProcessed Patient Number 644
#
# No.No.NoProcessed Patient Number 645
#
# NoNoNoProcessed Patient Number 646
#
# No.NoNoNoNoProcessed Patient Number 647
#
# NoProcessed Patient Number 648
#
# NoNo.No.NoNoProcessed Patient Number 649
#
# No.NoNoNoNoProcessed Patient Number 650
#
# No.No.NoProcessed Patient Number 651
#
# YesNoNoNoNo.Processed Patient Number 652
#
# NoNoNoNoProcessed Patient Number 653
#
# NoNoNoNoProcessed Patient Number 654
#
# NoNoProcessed Patient Number 655
#
# No.NoNoYesNo.NoNoNoNo.NoNoNoNoNo.NoProcessed Patient Number 656
#
# NoNoNoNoProcessed Patient Number 657
#
# NoNoNoProcessed Patient Number 658
#
# NoNoProcessed Patient Number 659
#
# NoNoProcessed Patient Number 660
#
# NoNoNoNoProcessed Patient Number 661
#
# NoNoNoProcessed Patient Number 662
#
# NoNoNoNoProcessed Patient Number 663
#
# NoNoNoNoProcessed Patient Number 664
#
# NoNoNo.Processed Patient Number 665
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 666
#
# NoNoNoNoNoProcessed Patient Number 667
#
# No.NoNoNoNoNoNoProcessed Patient Number 668
#
# YesNoYesNoNoNoProcessed Patient Number 669
#
# YesNoYesYesProcessed Patient Number 670
#
# Yes.YesYesYes.Processed Patient Number 671
#
# NoNoNoNoNoNoNo.Processed Patient Number 672
#
# YesYesNoProcessed Patient Number 673
#
# NoNoNo.Processed Patient Number 674
#
# NoNo.NoNoNoNoNoProcessed Patient Number 675
#
# NoNoNoNoNo.Processed Patient Number 676
#
# YesNoNoProcessed Patient Number 677
#
# NoNoNoProcessed Patient Number 678
#
# NoNoNoNoNoProcessed Patient Number 679
#
# No.No.NoNo.No.No.Processed Patient Number 680
#
# NoNoNoNo.No.No.Processed Patient Number 681
#
# NoYesNoNoNo.Processed Patient Number 682
#
# NoNoNo.No.Processed Patient Number 683
#
# No.No.No.NoProcessed Patient Number 684
#
# NoNo.NoNoProcessed Patient Number 685
#
# No.NoNoNoNoProcessed Patient Number 686
#
# NoNoNoNoProcessed Patient Number 687
#
# No.NoNoNoNoYesNoNo.NoNoNoProcessed Patient Number 688
#
# No.NoNoProcessed Patient Number 689
#
# NoNoNoProcessed Patient Number 690
#
# NoNoNoYesNoNoNoProcessed Patient Number 691
#
# NoNoNoNoProcessed Patient Number 692
#
# YesNoNo.Processed Patient Number 693
#
# NoNoNoNoNoProcessed Patient Number 694
#
# NoNoNoNo.Processed Patient Number 695
#
# NoNoNoNoProcessed Patient Number 696
#
# No.NoNo.NoProcessed Patient Number 697
#
# YesNoNoNoNoNoNoNoProcessed Patient Number 698
#
# NoNoNo.NoNoProcessed Patient Number 699
#
# NoNoNoNoProcessed Patient Number 700
#
# NoNoNoNoNoNoNoProcessed Patient Number 701
#
# NoNoNo.NoNoNo.NoNoProcessed Patient Number 702
#
# NoNoNoProcessed Patient Number 703
#
# NoNoProcessed Patient Number 704
#
# YesYesYesNoProcessed Patient Number 705
#
# NoNoNoNo.Processed Patient Number 706
#
# NoNoNoNoProcessed Patient Number 707
#
# NoNoNoProcessed Patient Number 708
#
# No.NoNoNoNo.NoProcessed Patient Number 709
#
# NoNo.Processed Patient Number 710
#
# NoNoNoNo.NoProcessed Patient Number 711
#
# NoNoNo.Processed Patient Number 712
#
# NoNoNoNoNo.NoProcessed Patient Number 713
#
# NoNoNoNoProcessed Patient Number 714
#
# NoNo.No.No.NoNo.Processed Patient Number 715
#
# NoNoProcessed Patient Number 716
#
# NoNo.No.Processed Patient Number 717
#
# NoNo.NoProcessed Patient Number 718
#
# NoNoNoNoProcessed Patient Number 719
#
# NoNoNoNoNoNoProcessed Patient Number 720
#
# No.NoProcessed Patient Number 721
#
# NoNoNoNoProcessed Patient Number 722
#
# No.NoNoProcessed Patient Number 723
#
# No.NoNoNoNoProcessed Patient Number 724
#
# NoNoNoNoNoNoProcessed Patient Number 725
#
# NoNo.Processed Patient Number 726
#
# NoNoNoProcessed Patient Number 727
#
# No.NoNoNoNoProcessed Patient Number 728
#
# NoNoProcessed Patient Number 729
#
# No.NoNoNoNoNo.NoProcessed Patient Number 730
#
# No.NoNoNo.NoNoNo.No.Processed Patient Number 731
#
# NoNoNoNoProcessed Patient Number 732
#
# No.NoNo.No.Processed Patient Number 733
#
# NoNoNo.Processed Patient Number 734
#
# NoNoNoProcessed Patient Number 735
#
# No.NoNoProcessed Patient Number 736
#
# NoNoYesNoProcessed Patient Number 737
#
# NoNoProcessed Patient Number 738
#
# No.NoNoProcessed Patient Number 739
#
# NoNoProcessed Patient Number 740
#
# NoNo.No.NoNoNoNoNoNoProcessed Patient Number 741
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 742
#
# NoNoNoProcessed Patient Number 743
#
# NoNoNo.Processed Patient Number 744
#
# NoYesNoNoNoProcessed Patient Number 745
#
# NoNoNoNoNo.NoProcessed Patient Number 746
#
# NoNoNoProcessed Patient Number 747
#
# No.No.No.Processed Patient Number 748
#
# No.NoNoProcessed Patient Number 749
#
# NoNoProcessed Patient Number 750
#
# NoNoNoProcessed Patient Number 751
#
# NoNo.No.Processed Patient Number 752
#
# NoNoNoNoNoProcessed Patient Number 753
#
# NoNoProcessed Patient Number 754
#
# NoNo.Processed Patient Number 755
#
# YesNoProcessed Patient Number 756
#
# NoNoNoNoNoNoProcessed Patient Number 757
#
# NoNoProcessed Patient Number 758
#
# NoNoNoNoNoProcessed Patient Number 759
#
# NoNo.NoNoProcessed Patient Number 760
#
# NoNoProcessed Patient Number 761
#
# No.NoNoProcessed Patient Number 762
#
# NoNoProcessed Patient Number 763
#
# NoNoProcessed Patient Number 764
#
# NoYesNoNoNoNoNoNo.Processed Patient Number 765
#
# No.NoNoNoProcessed Patient Number 766
#
# No.NoNoNo.Processed Patient Number 767
#
# NoNoNoNoNoProcessed Patient Number 768
#
# NoNo.NoNo.Processed Patient Number 769
#
# NoNoNo.Processed Patient Number 770
#
# NoNoNoNoNoProcessed Patient Number 771
#
# NoNoNoNoNoProcessed Patient Number 772
#
# No.No.No.NoNoNo.Processed Patient Number 773
#
# NoNo.NoNoNoNoProcessed Patient Number 774
#
# NoNoNoProcessed Patient Number 775
#
# YesNoYesYesYesProcessed Patient Number 776
#
# NoNoNoNoProcessed Patient Number 777
#
# NoNoNoNoNoProcessed Patient Number 778
#
# NoNoNoNoProcessed Patient Number 779
#
# NoNoNoNo.NoProcessed Patient Number 780
#
# No.NoNoProcessed Patient Number 781
#
# NoNoNoNoNoNoNo.NoProcessed Patient Number 782
#
# YesNoYesYesYesYesYesNoYesProcessed Patient Number 783
#
# NoNoNoProcessed Patient Number 784
#
# No.No.NoProcessed Patient Number 785
#
# No.NoNoNo.NoNoNoProcessed Patient Number 786
#
# NoNo.NoProcessed Patient Number 787
#
# NoNoProcessed Patient Number 788
#
# YesYes.YesYesProcessed Patient Number 789
#
# NoNoNoNoNo.NoNoNoNoProcessed Patient Number 790
#
# NoNo.NoNoNoProcessed Patient Number 791
#
# No.NoProcessed Patient Number 792
#
# No.NoNoNoNoProcessed Patient Number 793
#
# NoNoNoNo.Processed Patient Number 794
#
# No.NoNoNo.Processed Patient Number 795
#
# NoNoNoProcessed Patient Number 796
#
# NoNoNo.No.NoProcessed Patient Number 797
#
# No.NoNoNoNoProcessed Patient Number 798
#
# NoNoNoNoNo.Processed Patient Number 799
#
# NoNoNo.NoProcessed Patient Number 800
#
# No.NoNoNoProcessed Patient Number 801
#
# No.NoNoNoProcessed Patient Number 802
#
# No.NoNo.NoYesYesYesProcessed Patient Number 803
#
# NoNo.NoNoNoNoNoProcessed Patient Number 804
#
# NoNoNo.Processed Patient Number 805
#
# NoNoNoNoProcessed Patient Number 806
#
# No.NoNoNo.Processed Patient Number 807
#
# NoNoNoProcessed Patient Number 808
#
# NoNo.NoProcessed Patient Number 809
#
# NoNoNo.No.Processed Patient Number 810
#
# No.No.NoNoProcessed Patient Number 811
#
# NoNoNoNoProcessed Patient Number 812
#
# NoNo.NoNoNoProcessed Patient Number 813
#
# No.NoNoNoNoNoProcessed Patient Number 814
#
# NoNoNo.Processed Patient Number 815
#
# NoNoNoProcessed Patient Number 816
#
# YesNoNo.Processed Patient Number 817
#
# NoProcessed Patient Number 818
#
# NoNoNoNoNo.Processed Patient Number 819
#
# NoNo.Processed Patient Number 820
#
# NoNoNoProcessed Patient Number 821
#
# NoNoNoNoProcessed Patient Number 822
#
# NoNoNoNoNoProcessed Patient Number 823
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 824
#
# YesYesYesYes.Processed Patient Number 825
#
# No.NoNoProcessed Patient Number 826
#
# NoNoNoNoNo.Processed Patient Number 827
#
# Yes.Yes.YesYesYesYesYesNoProcessed Patient Number 828
#
# No.NoNoNoNoProcessed Patient Number 829
#
# NoNoNoNoNoNoProcessed Patient Number 830
#
# NoNoProcessed Patient Number 831
#
# No.NoNoNoProcessed Patient Number 832
#
# NoNoNoProcessed Patient Number 833
#
# No.No.Processed Patient Number 834
#
# NoNoNoNoNoNo.NoProcessed Patient Number 835
#
# NoNo.NoNo.NoProcessed Patient Number 836
#
# NoNoProcessed Patient Number 837
#
# NoNoNoProcessed Patient Number 838
#
# No.NoNo.Processed Patient Number 839
#
# No.NoNo.NoProcessed Patient Number 840
#
# NoNoNoProcessed Patient Number 841
#
# NoNo.Processed Patient Number 842
#
# NoNoNo.NoNoNoProcessed Patient Number 843
#
# YesProcessed Patient Number 844
#
# NoNoProcessed Patient Number 845
#
# NoNoNo.NoNoProcessed Patient Number 846
#
# NoNoNoNoNo.NoProcessed Patient Number 847
#
# YesYesNo.NoNoProcessed Patient Number 848
#
# No.No.NoNo.NoProcessed Patient Number 849
#
# NoNo.NoNoNo.Processed Patient Number 850
#
# NoNoNoProcessed Patient Number 851
#
# No.NoNoNoNo.NoNo.NoNoNoNoNoNoNo.Processed Patient Number 852
#
# NoProcessed Patient Number 853
#
# NoNoNoNoProcessed Patient Number 854
#
# NoNoProcessed Patient Number 855
#
# NoNoNoProcessed Patient Number 856
#
# NoNo.NoProcessed Patient Number 857
#
# YesProcessed Patient Number 858
#
# NoNoNoNoNoNoProcessed Patient Number 859
#
# NoNoNoNoNoNo.Processed Patient Number 860
#
# NoNoNoNoNo.Processed Patient Number 861
#
# NoNoNoNoNoProcessed Patient Number 862
#
# NoNoNo.Processed Patient Number 863
#
# No.NoNoNoNoProcessed Patient Number 864
#
# NoNo.NoProcessed Patient Number 865
#
# NoNoNoNo.NoNo.Processed Patient Number 866
#
# NoNoNoProcessed Patient Number 867
#
# NoNoNoProcessed Patient Number 868
#
# NoNoNo.No.NoNo.NoNoNo.Processed Patient Number 869
#
# NoNoNoProcessed Patient Number 870
#
# NoNoNoNoNoNoNoNo.Processed Patient Number 871
#
# NoNoProcessed Patient Number 872
#
# NoNoNo.Processed Patient Number 873
#
# NoNo.No.Processed Patient Number 874
#
# NoNoProcessed Patient Number 875
#
# No.NoNoNo.No.Processed Patient Number 876
#
# NoNoNoNoNoNo.Processed Patient Number 877
#
# NoNoNo.Processed Patient Number 878
#
# Yes.YesNoNoNo.Processed Patient Number 879
#
# NoNo.No.Processed Patient Number 880
#
# No.NoNoNo.NoNoNoProcessed Patient Number 881
#
# NoNoNoNoNoProcessed Patient Number 882
#
# NoNoNoNoNoProcessed Patient Number 883
#
# NoNoNoProcessed Patient Number 884
#
# NoNoNoNoNoProcessed Patient Number 885
#
# No.NoProcessed Patient Number 886
#
# No.NoNoProcessed Patient Number 887
#
# NoNoNoProcessed Patient Number 888
#
# NoNoNoNo.Processed Patient Number 889
#
# NoNoNo.NoProcessed Patient Number 890
#
# NoNoNoNo.No.Processed Patient Number 891
#
# NoNoNoProcessed Patient Number 892
#
# NoNoNo.NoNo.NoProcessed Patient Number 893
#
# No.NoNoNoProcessed Patient Number 894
#
# NoNoNo.Processed Patient Number 895
#
# NoNoNoProcessed Patient Number 896
#
# YesNoNoProcessed Patient Number 897
#
# No.NoNoNoNoNoProcessed Patient Number 898
#
# NoNoNoNo.NoProcessed Patient Number 899
#
# NoNoNoNoNoProcessed Patient Number 900
#
# No.NoNo.No.NoProcessed Patient Number 901
#
# NoNoNoNoNoProcessed Patient Number 902
#
# NoNoNoNoNoNoProcessed Patient Number 903
#
# NoNoProcessed Patient Number 904
#
# NoNoNo.Processed Patient Number 905
#
# NoNoNoNoNoNoProcessed Patient Number 906
#
# NoNo.NoNo.NoNo.Processed Patient Number 907
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 908
#
# NoNoNoNoNoNo.Processed Patient Number 909
#
# YesNoNo.No.Processed Patient Number 910
#
# NoNoNoNoNoNoNoProcessed Patient Number 911
#
# NoNoNoProcessed Patient Number 912
#
# NoNoNoNoProcessed Patient Number 913
#
# No.Processed Patient Number 914
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 915
#
# NoNoNoProcessed Patient Number 916
#
# NoNo.Processed Patient Number 917
#
# NoNoProcessed Patient Number 918
#
# No.NoNoProcessed Patient Number 919
#
# NoNo.NoNoNoNoProcessed Patient Number 920
#
# NoNoNo.Processed Patient Number 921
#
# NoNoNoProcessed Patient Number 922
#
# NoNoNoNoNoNoProcessed Patient Number 923
#
# NoNoProcessed Patient Number 924
#
# NoNoNoProcessed Patient Number 925
#
# NoNoNoNoProcessed Patient Number 926
#
# NoNo.NoNoProcessed Patient Number 927
#
# NoNoNoProcessed Patient Number 928
#
# NoNoNo.No.Processed Patient Number 929
#
# No.No.NoNoNo.Processed Patient Number 930
#
# No.No.NoProcessed Patient Number 931
#
# NoNoNoNoProcessed Patient Number 932
#
# NoNo.No.Processed Patient Number 933
#
# NoNoProcessed Patient Number 934
#
# NoNoProcessed Patient Number 935
#
# NoNoNoNo.No.NoNo.NoProcessed Patient Number 936
#
# NoNoNoNoProcessed Patient Number 937
#
# NoNo.NoNo.NoProcessed Patient Number 938
#
# No.NoNoNoNoProcessed Patient Number 939
#
# No.NoNoProcessed Patient Number 940
#
# No.NoNoNoNoProcessed Patient Number 941
#
# NoNoNoNoNoNoProcessed Patient Number 942
#
# NoNoNoNoNo.NoProcessed Patient Number 943
#
# No.NoNoProcessed Patient Number 944
#
# No.NoNoNoNoNoNoNoNoNoNo.Processed Patient Number 945
#
# NoNoNoNoNoProcessed Patient Number 946
#
# NoNoNoNoNo.Processed Patient Number 947
#
# NoNoNoNoProcessed Patient Number 948
#
# NoNoNoNoNoNoProcessed Patient Number 949
#
# NoNoNo.Processed Patient Number 950
#
# NoNoNoNoNo.Processed Patient Number 951
#
# NoNoProcessed Patient Number 952
#
# NoNoNoNoNo.NoNoProcessed Patient Number 953
#
# No.YesNoNoProcessed Patient Number 954
#
# No.NoNoNoProcessed Patient Number 955
#
# NoNoNoNoNoNoProcessed Patient Number 956
#
# No.No.NoNoNoNoNoNoNo.NoNoNoNoNoProcessed Patient Number 957
#
# No.No.NoNoNo.Processed Patient Number 958
#
# No.NoNoProcessed Patient Number 959
#
# NoNoNo.Processed Patient Number 960
#
# No.NoNoNoNoNo.NoProcessed Patient Number 961
#
# No.NoNoNoProcessed Patient Number 962
#
# NoNo.No.No.Processed Patient Number 963
#
# NoNoNoNoProcessed Patient Number 964
#
# NoNoNoProcessed Patient Number 965
#
# NoNoNoNoNoNoProcessed Patient Number 966
#
# NoNoNoNoNoProcessed Patient Number 967
#
# No.No.NoProcessed Patient Number 968
#
# YesNoNo.Processed Patient Number 969
#
# NoNoNoNoProcessed Patient Number 970
#
# No.NoNoNoNoNoProcessed Patient Number 971
#
# NoNoNoNoNo.Processed Patient Number 972
#
# YesNoNoNoNoNoNo.Processed Patient Number 973
#
# NoNoNoNoNoProcessed Patient Number 974
#
# NoNoNoNoNoProcessed Patient Number 975
#
# NoNo.NoProcessed Patient Number 976
#
# NoNoNoProcessed Patient Number 977
#
# NoNoNo.Processed Patient Number 978
#
# NoNoNoNoNoProcessed Patient Number 979
#
# NoNo.NoNoNoNoProcessed Patient Number 980
#
# NoNoNoNoNoProcessed Patient Number 981
#
# YesNoYesYesYesNoProcessed Patient Number 982
#
# NoNo.No.Processed Patient Number 983
#
# YesNoYesYesProcessed Patient Number 984
#
# NoNo.NoNo.NoProcessed Patient Number 985
#
# NoNoNoNoProcessed Patient Number 986
#
# NoYesNoNoProcessed Patient Number 987
#
# NoNoNoNoProcessed Patient Number 988
#
# NoNo.NoNoProcessed Patient Number 989
#
# NoNoProcessed Patient Number 990
#
# NoNoNoProcessed Patient Number 991
#
# No.NoNoNo.Processed Patient Number 992
#
# No.NoNoNoNoNoNoProcessed Patient Number 993
#
# NoNoNo.Processed Patient Number 994
#
# NoNoNoNoNoNo.Processed Patient Number 995
#
# NoNoNoProcessed Patient Number 996
#
# NoProcessed Patient Number 997
#
# NoNoNoNoProcessed Patient Number 998
#
# No.NoNo.Processed Patient Number 999
#
# YesNoNoProcessed Patient Number 1000
#
# NoNo.NoProcessed Patient Number 1001
#
# No.NoNoNoNoNoProcessed Patient Number 1002
#
# NoProcessed Patient Number 1003
#
# NoNoNoNoProcessed Patient Number 1004
#
# NoNoNoNoNo.Processed Patient Number 1005
#
# No.NoNoNoProcessed Patient Number 1006
#
# No.NoNoNoNoNoNoNoNo.NoNoNoProcessed Patient Number 1007
#
# NoNoNoNoNoProcessed Patient Number 1008
#
# NoNoNo.No.Processed Patient Number 1009
#
# No.NoNoNoProcessed Patient Number 1010
#
# No.NoNoNoNo.No.Processed Patient Number 1011
#
# NoNoNoNoNoNo.Processed Patient Number 1012
#
# NoNoNoNoNoNo.Processed Patient Number 1013
#
# NoNoNoNo.Processed Patient Number 1014
#
# No.NoNoProcessed Patient Number 1015
#
# NoNo.No.NoNoNoNoNo.Processed Patient Number 1016
#
# No.NoNoProcessed Patient Number 1017
#
# NoNoNoNoProcessed Patient Number 1018
#
# YesYes.YesYes.YesNoYes.NoProcessed Patient Number 1019
#
# NoNoNoProcessed Patient Number 1020
#
# NoNoNoProcessed Patient Number 1021
#
# NoNoNoNoNoProcessed Patient Number 1022
#
# YesNo.NoYesNoNoNoProcessed Patient Number 1023
#
# NoNoNoNoNoNoProcessed Patient Number 1024
#
# NoNoNo.NoNoProcessed Patient Number 1025
#
# NoNoProcessed Patient Number 1026
#
# NoNoNoNoNo.Processed Patient Number 1027
#
# No.Yes.NoNoNoNoProcessed Patient Number 1028
#
# NoNo.Processed Patient Number 1029
#
# NoNoNo.Processed Patient Number 1030
#
# NoNoNoNoProcessed Patient Number 1031
#
# No.NoNoNo.Processed Patient Number 1032
#
# NoNoNoNoNoNoProcessed Patient Number 1033
#
# NoNoNo.NoNoNoNo.NoProcessed Patient Number 1034
#
# YesYesNoProcessed Patient Number 1035
#
# NoNoNo.NoNoNoNoProcessed Patient Number 1036
#
# NoNoNoNoProcessed Patient Number 1037
#
# NoNoNoNoNo.NoNo.Processed Patient Number 1038
#
# NoNoNoNo.Processed Patient Number 1039
#
# No.NoProcessed Patient Number 1040
#
# NoNoNoNoNoProcessed Patient Number 1041
#
# No.NoNoProcessed Patient Number 1042
#
# No.NoNoNoNoNo.Processed Patient Number 1043
#
# NoNoProcessed Patient Number 1044
#
# NoNoNoNoNoNoNoNoNo.NoProcessed Patient Number 1045
#
# NoNoNoNoNoNoNoNo.Processed Patient Number 1046
#
# NoNoNoProcessed Patient Number 1047
#
# NoNoNoProcessed Patient Number 1048
#
# No.NoNoNo.Processed Patient Number 1049
#
# NoNoNo.Processed Patient Number 1050
#
# No.NoNoProcessed Patient Number 1051
#
# NoNoNoProcessed Patient Number 1052
#
# No.NoNoNoNoNoNo.Processed Patient Number 1053
#
# No.NoNo.NoProcessed Patient Number 1054
#
# NoNoNo.Processed Patient Number 1055
#
# NoNoNoNoNo.Processed Patient Number 1056
#
# NoNoNoNoNo.Processed Patient Number 1057
#
# NoNoNoProcessed Patient Number 1058
#
# NoNo.Processed Patient Number 1059
#
# NoNoNoProcessed Patient Number 1060
#
# No.NoNoNo.NoNo.NoProcessed Patient Number 1061
#
# NoNoNoNoNoProcessed Patient Number 1062
#
# NoNoNoProcessed Patient Number 1063
#
# NoNoNoNo.Processed Patient Number 1064
#
# YesYesNoNo.Yes.NoProcessed Patient Number 1065
#
# NoNoNoNoProcessed Patient Number 1066
#
# NoNoNoNoNoNoNoNo.Processed Patient Number 1067
#
# NoNo.NoNoProcessed Patient Number 1068
#
# NoNoNoProcessed Patient Number 1069
#
# NoNoNoNoNoProcessed Patient Number 1070
#
# NoNoNoNo.Processed Patient Number 1071
#
# NoNoNoNoProcessed Patient Number 1072
#
# NoNoNo.NoNo.NoNoNoProcessed Patient Number 1073
#
# NoNoNoNoYesNoProcessed Patient Number 1074
#
# No.NoProcessed Patient Number 1075
#
# NoNoNoProcessed Patient Number 1076
#
# NoNo.No.No.Processed Patient Number 1077
#
# NoNoNoProcessed Patient Number 1078
#
# No.NoNoNoProcessed Patient Number 1079
#
# NoNo.NoNoNoNoProcessed Patient Number 1080
#
# No.NoNoProcessed Patient Number 1081
#
# NoNoNoProcessed Patient Number 1082
#
# NoNo.NoNoNo.NoProcessed Patient Number 1083
#
# NoNo.NoProcessed Patient Number 1084
#
# NoNoNoNo.NoNoNoNoNoNo.NoProcessed Patient Number 1085
#
# YesYesYesNoYes.NoProcessed Patient Number 1086
#
# No.NoNoProcessed Patient Number 1087
#
# No.NoNoNo.Processed Patient Number 1088
#
# No.No.Processed Patient Number 1089
#
# NoNoNoNo.NoNoNoNoProcessed Patient Number 1090
#
# No.NoNoNoNo.NoNoProcessed Patient Number 1091
#
# No.No.NoNoNoNoNoProcessed Patient Number 1092
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 1093
#
# No.NoNoNoProcessed Patient Number 1094
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 1095
#
# NoNoProcessed Patient Number 1096
#
# NoNoNoProcessed Patient Number 1097
#
# NoNoNoNoProcessed Patient Number 1098
#
# NoNo.Processed Patient Number 1099
#
# NoNoNoProcessed Patient Number 1100
#
# No.NoNoNoNoNoNo.Processed Patient Number 1101
#
# NoNoNoNoProcessed Patient Number 1102
#
# No.No.NoNoNoNoNo.NoProcessed Patient Number 1103
#
# NoNoNoProcessed Patient Number 1104
#
# NoNoNoNoProcessed Patient Number 1105
#
# NoNoNoNoNoProcessed Patient Number 1106
#
# NoNoNo.Processed Patient Number 1107
#
# NoNoNoNoProcessed Patient Number 1108
#
# NoNoNoNoNoNoNoNo.NoProcessed Patient Number 1109
#
# NoNoNoNoNo.Processed Patient Number 1110
#
# NoNoNoProcessed Patient Number 1111
#
# No.NoNoProcessed Patient Number 1112
#
# NoNoProcessed Patient Number 1113
#
# NoNoNoNoNoProcessed Patient Number 1114
#
# No.No.NoProcessed Patient Number 1115
#
# NoNoNoNoProcessed Patient Number 1116
#
# No.NoNoProcessed Patient Number 1117
#
# NoNoNoNoProcessed Patient Number 1118
#
# NoNoNo.Processed Patient Number 1119
#
# NoNoProcessed Patient Number 1120
#
# NoNoProcessed Patient Number 1121
#
# No.NoNoNoNoNo.NoNoNoNoNoProcessed Patient Number 1122
#
# No.NoNoNoNoProcessed Patient Number 1123
#
# No.NoNoNo.Processed Patient Number 1124
#
# NoNoNoNoNoNoProcessed Patient Number 1125
#
# NoNoNoNoProcessed Patient Number 1126
#
# NoNoNoNoNoProcessed Patient Number 1127
#
# NoNoNoNo.Processed Patient Number 1128
#
# No.NoNoNoNoProcessed Patient Number 1129
#
# NoNoNo.Processed Patient Number 1130
#
# NoNoNoProcessed Patient Number 1131
#
# NoNoNoNoProcessed Patient Number 1132
#
# NoNoProcessed Patient Number 1133
#
# NoNoNo.NoProcessed Patient Number 1134
#
# NoNoNoNo.Processed Patient Number 1135
#
# No.NoNoProcessed Patient Number 1136
#
# No.NoNoNoProcessed Patient Number 1137
#
# No.NoNoNoNoProcessed Patient Number 1138
#
# No.NoNo.Processed Patient Number 1139
#
# NoNoNoNoProcessed Patient Number 1140
#
# NoNoNoNoNoNo.Processed Patient Number 1141
#
# NoYesYesProcessed Patient Number 1142
#
# No.NoProcessed Patient Number 1143
#
# NoNoNoNoProcessed Patient Number 1144
#
# NoNoNoNo.Processed Patient Number 1145
#
# NoNoNoNoNoNoProcessed Patient Number 1146
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1147
#
# NoNoNoNoProcessed Patient Number 1148
#
# NoNoNoProcessed Patient Number 1149
#
# YesNo.YesNoProcessed Patient Number 1150
#
# NoNoNo.Processed Patient Number 1151
#
# NoNoNoNo.Processed Patient Number 1152
#
# NoNoNo.NoProcessed Patient Number 1153
#
# No.No.NoNoNoNoNoNoProcessed Patient Number 1154
#
# NoNoNo.NoNoProcessed Patient Number 1155
#
# NoYesNoNo.NoProcessed Patient Number 1156
#
# NoNoProcessed Patient Number 1157
#
# No.No.NoNoNo.No.NoProcessed Patient Number 1158
#
# NoNoNoProcessed Patient Number 1159
#
# NoNoNoNoNo.Processed Patient Number 1160
#
# NoNoNoNoNoProcessed Patient Number 1161
#
# No.No.NoNoNoNo.NoProcessed Patient Number 1162
#
# NoNoNo.NoProcessed Patient Number 1163
#
# No.NoNoNoProcessed Patient Number 1164
#
# Yes.YesYes.YesProcessed Patient Number 1165
#
# NoNoNo.NoProcessed Patient Number 1166
#
# Yes.YesYesYesProcessed Patient Number 1167
#
# No.NoNo.NoProcessed Patient Number 1168
#
# NoNoNoNoNoNo.Processed Patient Number 1169
#
# NoNoNo.Processed Patient Number 1170
#
# NoNoNoProcessed Patient Number 1171
#
# NoYes.YesNoProcessed Patient Number 1172
#
# NoNoNoNo.NoProcessed Patient Number 1173
#
# No.NoProcessed Patient Number 1174
#
# NoNoNoNoProcessed Patient Number 1175
#
# No.No.NoNoNoNoNoNoNoNoNoNoNoProcessed Patient Number 1176
#
# YesNoNo.Processed Patient Number 1177
#
# NoNoNoNoProcessed Patient Number 1178
#
# No.No.NoProcessed Patient Number 1179
#
# NoNoNoNoNoNoProcessed Patient Number 1180
#
# NoNoNoProcessed Patient Number 1181
#
# NoNoYesNo.NoYesNoNoProcessed Patient Number 1182
#
# NoNo.Processed Patient Number 1183
#
# NoNoNoNoNoNoProcessed Patient Number 1184
#
# YesNoYesYesYesYesYes.Processed Patient Number 1185
#
# NoNoNoNoProcessed Patient Number 1186
#
# NoNoNoNoNoProcessed Patient Number 1187
#
# NoNoNoNoNoNo.Processed Patient Number 1188
#
# NoNoNoProcessed Patient Number 1189
#
# NoNoNo.Processed Patient Number 1190
#
# NoNoNo.NoNoProcessed Patient Number 1191
#
# NoNoNoNo.Processed Patient Number 1192
#
# No.NoNoNo.Processed Patient Number 1193
#
# NoNoYesNoNoNoProcessed Patient Number 1194
#
# NoNoNoNoProcessed Patient Number 1195
#
# NoNo.NoNo.NoNoNoNo.NoNoProcessed Patient Number 1196
#
# NoNoNoNoNo.No.Processed Patient Number 1197
#
# NoNoNoNoProcessed Patient Number 1198
#
# ...
#
# NoNoNoNoProcessed Patient Number 1628
#
# NoNo.NoNoNoProcessed Patient Number 1629
#
# NoNoNoNoNoProcessed Patient Number 1630
#
# Yes.NoNoNoNoProcessed Patient Number 1631
#
# No.NoNoNoProcessed Patient Number 1632
#
# NoNoNo.Processed Patient Number 1633
#
# NoNoNo.Processed Patient Number 1634
#
# NoNoNoNoNo.Processed Patient Number 1635
#
# NoNoNoNoProcessed Patient Number 1636
#
# NoNoNoNoProcessed Patient Number 1637
#
# NoNo.Processed Patient Number 1638
#
# NoNo.NoProcessed Patient Number 1639
#
# NoNoNo.NoProcessed Patient Number 1640
#
# NoNoProcessed Patient Number 1641
#
# YesYesYesYes.Processed Patient Number 1642
#
# No.NoNoNoProcessed Patient Number 1643
#
# No.NoNoNoNo.NoProcessed Patient Number 1644
#
# YesYesProcessed Patient Number 1645
#
# NoNoNoNoProcessed Patient Number 1646
#
# NoNoNo.No.Processed Patient Number 1647
#
# NoNo.NoNoProcessed Patient Number 1648
#
# NoNoNoProcessed Patient Number 1649
#
# NoNoNoNoNoProcessed Patient Number 1650
#
# No.NoNoNoNoNoNoProcessed Patient Number 1651
#
# YesNoNoNoProcessed Patient Number 1652
#
# NoNoNoNoNo.Processed Patient Number 1653
#
# NoNoProcessed Patient Number 1654
#
# No.NoNoNoNoYesNoProcessed Patient Number 1655
#
# NoNoNoNo.Processed Patient Number 1656
#
# NoNoNoNo.NoProcessed Patient Number 1657
#
# NoNoNoNoNoNoNoProcessed Patient Number 1658
#
# No.NoNoNoNoNoProcessed Patient Number 1659
#
# NoNoNoProcessed Patient Number 1660
#
# NoNoNoNoProcessed Patient Number 1661
#
# No.NoProcessed Patient Number 1662
#
# No.NoNoNoNoNoNoNo.Processed Patient Number 1663
#
# YesYes.NoProcessed Patient Number 1664
#
# NoNoNo.Processed Patient Number 1665
#
# NoNoNo.No.No.Processed Patient Number 1666
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1667
#
# No.No.NoProcessed Patient Number 1668
#
# NoNoNo.Processed Patient Number 1669
#
# NoNo.NoNoProcessed Patient Number 1670
#
# No.No.NoNoProcessed Patient Number 1671
#
# NoNoNoNoNoProcessed Patient Number 1672
#
# NoNo.NoNoNoNoNoNoProcessed Patient Number 1673
#
# NoNoNo.Processed Patient Number 1674
#
# NoNoNoNo.Processed Patient Number 1675
#
# NoNoNoNoProcessed Patient Number 1676
#
# NoNoNoNoProcessed Patient Number 1677
#
# NoNo.No.NoNoProcessed Patient Number 1678
#
# No.NoProcessed Patient Number 1679
#
# No.No.NoNo.Processed Patient Number 1680
#
# NoNo.NoNoProcessed Patient Number 1681
#
# YesNoNo.NoProcessed Patient Number 1682
#
# NoNoNoNoProcessed Patient Number 1683
#
# No.NoNoNo.Processed Patient Number 1684
#
# NoNoNoNoNoNoNo.Processed Patient Number 1685
#
# NoNo.No.NoNoProcessed Patient Number 1686
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 1687
#
# NoNo.Processed Patient Number 1688
#
# NoNoNoNoProcessed Patient Number 1689
#
# NoNoNo.NoNo.Processed Patient Number 1690
#
# NoNoNoNoProcessed Patient Number 1691
#
# NoNoYesNoNoNoNo.Processed Patient Number 1692
#
# NoNoNo.No.Processed Patient Number 1693
#
# NoNoNoProcessed Patient Number 1694
#
# No.NoNoProcessed Patient Number 1695
#
# No.NoProcessed Patient Number 1696
#
# No.NoNoProcessed Patient Number 1697
#
# NoNoNoProcessed Patient Number 1698
#
# NoNoProcessed Patient Number 1699
#
# YesYesYesYesProcessed Patient Number 1700
#
# No.No.No.Processed Patient Number 1701
#
# NoNoNoProcessed Patient Number 1702
#
# NoNo.NoNoNoNo.Processed Patient Number 1703
#
# NoNo.No.Processed Patient Number 1704
#
# NoNoNoNoNoProcessed Patient Number 1705
#
# NoNoNoProcessed Patient Number 1706
#
# NoNoNoNoNoNo.Processed Patient Number 1707
#
# NoNoNoNoNoYesProcessed Patient Number 1708
#
# YesNoNo.NoProcessed Patient Number 1709
#
# No.NoNoNo.Processed Patient Number 1710
#
# NoNoNoNoProcessed Patient Number 1711
#
# NoNo.NoNo.Processed Patient Number 1712
#
# NoNo.NoNo.Processed Patient Number 1713
#
# No.NoProcessed Patient Number 1714
#
# No.NoNoNo.Processed Patient Number 1715
#
# YesNoNoNoNo.Processed Patient Number 1716
#
# NoNoNoNo.Processed Patient Number 1717
#
# NoNoProcessed Patient Number 1718
#
# NoNo.Processed Patient Number 1719
#
# NoNoNoNoProcessed Patient Number 1720
#
# No.NoProcessed Patient Number 1721
#
# No.NoNo.NoNoNo.Processed Patient Number 1722
#
# No.NoNoNo.NoNoProcessed Patient Number 1723
#
# NoNoNoNoProcessed Patient Number 1724
#
# No.NoNoNo.Processed Patient Number 1725
#
# NoNo.NoNoProcessed Patient Number 1726
#
# NoNoNoNoProcessed Patient Number 1727
#
# NoNo.NoNoNo.Processed Patient Number 1728
#
# YesYesYesYes.Processed Patient Number 1729
#
# No.NoNoNoNoProcessed Patient Number 1730
#
# YesNoNoNoProcessed Patient Number 1731
#
# NoNoNoNoNoNoProcessed Patient Number 1732
#
# NoNoYesNoProcessed Patient Number 1733
#
# NoNo.Processed Patient Number 1734
#
# NoNoNo.No.Processed Patient Number 1735
#
# NoNoNoProcessed Patient Number 1736
#
# NoNoNoNo.Processed Patient Number 1737
#
# NoNoNoProcessed Patient Number 1738
#
# NoNoNoNoNoNoNoProcessed Patient Number 1739
#
# NoNoNoProcessed Patient Number 1740
#
# No.NoNoNoProcessed Patient Number 1741
#
# NoNoNoProcessed Patient Number 1742
#
# No.Processed Patient Number 1743
#
# NoNoProcessed Patient Number 1744
#
# No.YesNoNoProcessed Patient Number 1745
#
# NoNoProcessed Patient Number 1746
#
# NoNoNoProcessed Patient Number 1747
#
# NoNoNoNoNo.No.Processed Patient Number 1748
#
# NoNoNoNoProcessed Patient Number 1749
#
# No.NoProcessed Patient Number 1750
#
# NoNoNo.Processed Patient Number 1751
#
# NoNoNoNoNoNo.Processed Patient Number 1752
#
# NoNoNoProcessed Patient Number 1753
#
# NoNo.NoNo.NoNoProcessed Patient Number 1754
#
# NoNoNoNoNoProcessed Patient Number 1755
#
# NoNo.NoNoNo.NoProcessed Patient Number 1756
#
# NoNo.NoNoNoNo.NoNoNoNoNoNoProcessed Patient Number 1757
#
# NoNoNoNoNoProcessed Patient Number 1758
#
# No.NoNoNoNo.Processed Patient Number 1759
#
# YesNo.Processed Patient Number 1760
#
# NoNoNo.Processed Patient Number 1761
#
# NoNo.NoNo.No.No.Processed Patient Number 1762
#
# NoNoNoProcessed Patient Number 1763
#
# No.NoProcessed Patient Number 1764
#
# NoNoNoNoNoNo.Processed Patient Number 1765
#
# NoNoNoNo.Processed Patient Number 1766
#
# NoNoProcessed Patient Number 1767
#
# NoNoNoNo.Processed Patient Number 1768
#
# NoNo.NoNoNoProcessed Patient Number 1769
#
# NoNoNoNoNo.NoNo.Processed Patient Number 1770
#
# NoNoNoNoNoProcessed Patient Number 1771
#
# Yes.NoNo.NoProcessed Patient Number 1772
#
# NoYesYesNo.Processed Patient Number 1773
#
# No.NoNoNo.Processed Patient Number 1774
#
# NoNoNoNoNoNoProcessed Patient Number 1775
#
# NoNoNo.NoProcessed Patient Number 1776
#
# NoNo.NoProcessed Patient Number 1777
#
# NoNoProcessed Patient Number 1778
#
# NoNoNo.No.NoNoProcessed Patient Number 1779
#
# No.NoNoNo.Processed Patient Number 1780
#
# NoNoNoProcessed Patient Number 1781
#
# NoNoNoNoNo.Processed Patient Number 1782
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 1783
#
# YesNoNoNoNoNoProcessed Patient Number 1784
#
# No.NoNo.Processed Patient Number 1785
#
# NoNoNoNo.NoNoProcessed Patient Number 1786
#
# NoNoNoNoNoProcessed Patient Number 1787
#
# NoNo.NoNoProcessed Patient Number 1788
#
# NoNoNoProcessed Patient Number 1789
#
# NoNoYesYesYesNoNoYesProcessed Patient Number 1790
#
# No.NoNoNoProcessed Patient Number 1791
#
# YesNoNoProcessed Patient Number 1792
#
# No.NoNo.NoNoProcessed Patient Number 1793
#
# NoNo.No.Processed Patient Number 1794
#
# No.Processed Patient Number 1795
#
# No.NoNoNo.NoProcessed Patient Number 1796
#
# YesNoNo.Processed Patient Number 1797
#
# NoNoNoNoProcessed Patient Number 1798
#
# NoNoNoNoProcessed Patient Number 1799
#
# NoNoNo.NoNoNo.Processed Patient Number 1800
#
# NoNoNoNo.NoNoNoNoNoProcessed Patient Number 1801
#
# NoNoNoProcessed Patient Number 1802
#
# NoNo.NoNoNoNoNoProcessed Patient Number 1803
#
# NoNoNoProcessed Patient Number 1804
#
# NoNoNo.No.Processed Patient Number 1805
#
# No.NoNo.NoProcessed Patient Number 1806
#
# NoNoNo.No.NoProcessed Patient Number 1807
#
# NoNoNo.Processed Patient Number 1808
#
# NoNoProcessed Patient Number 1809
#
# NoNoProcessed Patient Number 1810
#
# NoNoNoProcessed Patient Number 1811
#
# NoNoNo.NoProcessed Patient Number 1812
#
# NoNoNo.Processed Patient Number 1813
#
# NoNoProcessed Patient Number 1814
#
# YesNoNoNoNo.No.Processed Patient Number 1815
#
# No.No.NoNoNoProcessed Patient Number 1816
#
# No.NoProcessed Patient Number 1817
#
# YesNoNoNoNoNo.NoNoNoProcessed Patient Number 1818
#
# YesNoNoProcessed Patient Number 1819
#
# NoNoNoProcessed Patient Number 1820
#
# NoNoNoNoNoProcessed Patient Number 1821
#
# NoNoNoNo.NoNo.Processed Patient Number 1822
#
# NoNoNoNoProcessed Patient Number 1823
#
# NoNoNoProcessed Patient Number 1824
#
# NoNoNo.Processed Patient Number 1825
#
# No.NoProcessed Patient Number 1826
#
# No.NoNoNoNoProcessed Patient Number 1827
#
# NoNoNoNo.Processed Patient Number 1828
#
# YesYesNo.NoProcessed Patient Number 1829
#
# No.No.NoNoNo.NoProcessed Patient Number 1830
#
# NoNoYesNoNoNoProcessed Patient Number 1831
#
# NoNoNoProcessed Patient Number 1832
#
# NoNoNoProcessed Patient Number 1833
#
# NoNoProcessed Patient Number 1834
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 1835
#
# NoNoNoProcessed Patient Number 1836
#
# Yes.YesYesProcessed Patient Number 1837
#
# No.NoNoProcessed Patient Number 1838
#
# NoNoNoYesNoNoProcessed Patient Number 1839
#
# NoNoProcessed Patient Number 1840
#
# NoNoNoNoNoProcessed Patient Number 1841
#
# NoNoNo.NoProcessed Patient Number 1842
#
# NoNoNoNo.NoNo.Processed Patient Number 1843
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 1844
#
# NoNoNoNoNoNo.Processed Patient Number 1845
#
# NoNoNoNoProcessed Patient Number 1846
#
# NoNoNoNoProcessed Patient Number 1847
#
# NoNoNoNoProcessed Patient Number 1848
#
# No.NoNoNo.Processed Patient Number 1849
#
# NoNoNoNoNoProcessed Patient Number 1850
#
# NoNoNo.Processed Patient Number 1851
#
# NoNoNoNoNoProcessed Patient Number 1852
#
# NoNoNoNoNoNo.Processed Patient Number 1853
#
# NoNoNoNoNoNoProcessed Patient Number 1854
#
# YesYesNoYesNoProcessed Patient Number 1855
#
# NoNoNoNoNoProcessed Patient Number 1856
#
# NoNoNoYesNo.Processed Patient Number 1857
#
# NoNoNoNo.Processed Patient Number 1858
#
# NoNoNoNoNoProcessed Patient Number 1859
#
# YesYesYesYesNo.Processed Patient Number 1860
#
# YesNoNo.Processed Patient Number 1861
#
# NoNoNoNoNoProcessed Patient Number 1862
#
# NoNoNo.NoNoNoNoProcessed Patient Number 1863
#
# NoNoNoProcessed Patient Number 1864
#
# NoNoNoNo.No.NoProcessed Patient Number 1865
#
# NoYesNoNoNoProcessed Patient Number 1866
#
# NoNoNoNo.No.Processed Patient Number 1867
#
# NoNoNoProcessed Patient Number 1868
#
# NoNoNoNoNoProcessed Patient Number 1869
#
# No.NoNoYes.Processed Patient Number 1870
#
# NoNoNoProcessed Patient Number 1871
#
# YesNoNoProcessed Patient Number 1872
#
# NoNoNoNoProcessed Patient Number 1873
#
# NoNoNoProcessed Patient Number 1874
#
# NoNoNoNo.Processed Patient Number 1875
#
# NoNoNo.No.NoProcessed Patient Number 1876
#
# No.NoNo.Processed Patient Number 1877
#
# YesNoNoProcessed Patient Number 1878
#
# NoNoNoNoProcessed Patient Number 1879
#
# No.NoNoNoNoNoProcessed Patient Number 1880
#
# NoNoNoNoNoProcessed Patient Number 1881
#
# NoNoNoNoProcessed Patient Number 1882
#
# NoNo.NoNoNoProcessed Patient Number 1883
#
# NoNo.No.NoNoNoNoProcessed Patient Number 1884
#
# NoNoNoNo.NoProcessed Patient Number 1885
#
# No.NoNoProcessed Patient Number 1886
#
# NoNoNoNoProcessed Patient Number 1887
#
# NoNoNoNoNoProcessed Patient Number 1888
#
# NoNo.NoNoNoProcessed Patient Number 1889
#
# NoNoNoNo.Processed Patient Number 1890
#
# NoNoProcessed Patient Number 1891
#
# NoProcessed Patient Number 1892
#
# NoNoNoNo.NoProcessed Patient Number 1893
#
# NoNoNoNoProcessed Patient Number 1894
#
# NoNo.YesNo.Processed Patient Number 1895
#
# NoNoNoNo.No.Processed Patient Number 1896
#
# NoNoProcessed Patient Number 1897
#
# NoNoNoNoProcessed Patient Number 1898
#
# NoNoNoNoNo.Processed Patient Number 1899
#
# YesYesYes.NoNoProcessed Patient Number 1900
#
# YesYesYesYesYesNoYesProcessed Patient Number 1901
#
# No.No.NoNoNoNoNoNoProcessed Patient Number 1902
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1903
#
# NoNoNoProcessed Patient Number 1904
#
# YesNoProcessed Patient Number 1905
#
# YesNoYesNoYesYes.YesNoProcessed Patient Number 1906
#
# No.NoNoProcessed Patient Number 1907
#
# No.NoNoNo.Processed Patient Number 1908
#
# No.NoNoProcessed Patient Number 1909
#
# NoNoNoNoNo.No.Processed Patient Number 1910
#
# NoNoNoNoProcessed Patient Number 1911
#
# NoNoNoNo.NoNoProcessed Patient Number 1912
#
# No.NoNoNoProcessed Patient Number 1913
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 1914
#
# NoYesNoNoNoProcessed Patient Number 1915
#
# No.Processed Patient Number 1916
#
# NoNoNoNoNo.Processed Patient Number 1917
#
# No.No.NoProcessed Patient Number 1918
#
# No.NoProcessed Patient Number 1919
#
# NoNoNoNoNoProcessed Patient Number 1920
#
# NoNoNoNoNoNoProcessed Patient Number 1921
#
# NoNoNoNoProcessed Patient Number 1922
#
# No.NoNoNoNoNo.NoNoNoNoNo.Processed Patient Number 1923
#
# NoNo.Processed Patient Number 1924
#
# NoNo.NoProcessed Patient Number 1925
#
# No.No.NoNoNoProcessed Patient Number 1926
#
# NoNoProcessed Patient Number 1927
#
# NoNoNoNoNoNoNo.Processed Patient Number 1928
#
# NoNoNo.Processed Patient Number 1929
#
# NoNoNoProcessed Patient Number 1930
#
# NoNo.NoNoProcessed Patient Number 1931
#
# NoNoNoNoNo.Processed Patient Number 1932
#
# No.NoNoNoNoNoProcessed Patient Number 1933
#
# NoNoNoNo.NoProcessed Patient Number 1934
#
# No.NoNoYesNoNoProcessed Patient Number 1935
#
# No.NoProcessed Patient Number 1936
#
# NoNoNoNoNoNoNo.Processed Patient Number 1937
#
# NoNoNoProcessed Patient Number 1938
#
# NoYesNo.NoNoProcessed Patient Number 1939
#
# NoNoNoNoNoNoProcessed Patient Number 1940
#
# NoNoProcessed Patient Number 1941
#
# NoNoNoProcessed Patient Number 1942
#
# NoNoProcessed Patient Number 1943
#
# NoNoNo.NoProcessed Patient Number 1944
#
# No.YesNoNoProcessed Patient Number 1945
#
# YesNoNoNoNoProcessed Patient Number 1946
#
# No.NoNoNoNoProcessed Patient Number 1947
#
# NoNoNo.Processed Patient Number 1948
#
# NoNoProcessed Patient Number 1949
#
# NoNoNo.NoNoNoNoProcessed Patient Number 1950
#
# NoNoNoNoProcessed Patient Number 1951
#
# Yes.No.Processed Patient Number 1952
#
# YesYesYesYes.NoProcessed Patient Number 1953
#
# NoNoNo.Processed Patient Number 1954
#
# NoNo.NoProcessed Patient Number 1955
#
# NoNo.NoProcessed Patient Number 1956
#
# No.NoProcessed Patient Number 1957
#
# NoNoNoNoNoNoProcessed Patient Number 1958
#
# NoNoProcessed Patient Number 1959
#
# NoNoNoNoProcessed Patient Number 1960
#
# No.NoNoNoNoProcessed Patient Number 1961
#
# No.NoNoNoProcessed Patient Number 1962
#
# No.NoNoNoProcessed Patient Number 1963
#
# NoNoProcessed Patient Number 1964
#
# Yes.YesYesYesProcessed Patient Number 1965
#
# NoYesNoNoNo.Processed Patient Number 1966
#
# NoNoProcessed Patient Number 1967
#
# No.NoNo.NoNoProcessed Patient Number 1968
#
# NoNoNoProcessed Patient Number 1969
#
# NoNoNoNoNoNo.NoNoNoProcessed Patient Number 1970
#
# No.NoNo.NoProcessed Patient Number 1971
#
# NoNoNoProcessed Patient Number 1972
#
# NoNoNoProcessed Patient Number 1973
#
# No.NoNoNoNoProcessed Patient Number 1974
#
# No.No.NoNo.No.Processed Patient Number 1975
#
# NoNoNoNoNoNoNoNo.Processed Patient Number 1976
#
# NoNoNoNo.Processed Patient Number 1977
#
# NoNoNoNoProcessed Patient Number 1978
#
# NoNoNoProcessed Patient Number 1979
#
# NoNoNo.Processed Patient Number 1980
#
# NoNoNoNo.NoNoNo.Processed Patient Number 1981
#
# No.NoNoNo.NoProcessed Patient Number 1982
#
# YesNoYesProcessed Patient Number 1983
#
# NoNo.NoNoNo.NoNo.No.Processed Patient Number 1984
#
# No.NoNoProcessed Patient Number 1985
#
# YesNoProcessed Patient Number 1986
#
# No.NoNo.NoNoNoProcessed Patient Number 1987
#
# NoNoNo.Processed Patient Number 1988
#
# NoNoNoNoNoProcessed Patient Number 1989
#
# Yes.Yes.Processed Patient Number 1990
#
# NoNoNoNo.No.Processed Patient Number 1991
#
# NoNoNoNoProcessed Patient Number 1992
#
# NoNoNoNoNoNo.Processed Patient Number 1993
#
# NoNoNo.NoProcessed Patient Number 1994
#
# NoNoNoNoNo.Processed Patient Number 1995
#
# NoNo.No.Processed Patient Number 1996
#
# NoNo.NoNoNo.Processed Patient Number 1997
#
# NoNoProcessed Patient Number 1998
#
# NoNo.NoNoNoProcessed Patient Number 1999
#
# NoProcessed Patient Number 2000
#
# NoNoNoProcessed Patient Number 2001
#
# NoYesNoNoNo.Processed Patient Number 2002
#
# NoNo.No.NoNo.Processed Patient Number 2003
#
# NoNoYesNo.NoProcessed Patient Number 2004
#
# NoNoNoProcessed Patient Number 2005
#
# NoNo.Processed Patient Number 2006
#
# NoNoNoNo.No.Processed Patient Number 2007
#
# NoNoNo.NoNoNoNoProcessed Patient Number 2008
#
# NoNoNoNo.NoProcessed Patient Number 2009
#
# NoNoNoNoProcessed Patient Number 2010
#
# YesNoNo.NoNoNoNoProcessed Patient Number 2011
#
# Yes.YesNoNoNoNo.Processed Patient Number 2012
#
# NoNoNoNoProcessed Patient Number 2013
#
# NoNoNo.Processed Patient Number 2014
#
# No.NoNoNoNo.NoNo.NoProcessed Patient Number 2015
#
# NoNoProcessed Patient Number 2016
#
# No.NoNoNoProcessed Patient Number 2017
#
# NoNoNoNo.Processed Patient Number 2018
#
# NoNoNoNoNo.NoProcessed Patient Number 2019
#
# No.No.NoProcessed Patient Number 2020
