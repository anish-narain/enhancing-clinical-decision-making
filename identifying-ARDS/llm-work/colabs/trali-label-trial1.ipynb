# %% [markdown]
# # Dependencies

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# Inside terminal run the following:
#
# ```
# ollama serve &
# ollama run llama3
# ```

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.4-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain-0.2.3-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 56.7 MB/s eta 0:00:00
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain_core-0.2.5-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 15.1 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain_community)
#   Downloading langsmith-0.1.75-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 6.7 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.0->langchain_community)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.3)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 6.9 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain_community)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, typing-inspect, marshmallow, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.6 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.3 langchain-core-0.2.5 langchain-text-splitters-0.2.1 langchain_community-0.2.4 langsmith-0.1.75 marshmallow-3.21.3 mypy-extensions-1.0.0 orjson-3.10.3 packaging-23.2 typing-inspect-0.9.0

# %%
# Load Google Drive because it stores /content/drive/My Drive/ards-cohort-notes/ards-cohort-notes.csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
import pandas as pd
import time
import random
import csv
from langchain_community.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# # Functions to load data, specify LLM prompt, and perform LLM inference

# %%
def load_data(file_path):
    df = pd.read_csv(file_path)
    df.fillna('', inplace=True)
    return df

def select_random_start(num_rows, min_rows=15):
    if num_rows < min_rows:
        raise ValueError(f"The dataset must contain at least {min_rows} rows to process.")
    return random.randint(0, num_rows - min_rows)

def create_prompt_template():
    return PromptTemplate(
        template=(
            "Context: You are a clinician receiving chunks of clinical text for patients in an ICU. Please do the reviewing as quickly as possible.\n"
            "Task: Determine if the patient suffered from transfusion-related acute lung injury (TRALI).\n"
            "Instructions: Answer with 'Yes' or 'No'. If there is not enough information, answer 'No'.\n"
            "Discharge Text:\n{discharge_text}\n\n"
            "Query: Does the chunk of text mention that the patient suffered from transfusion-related acute lung injury (TRALI)? Answer strictly in 'Yes' or 'No'."
        ),
        input_variables=["discharge_text"]
    )

def chunk_text(text, chunk_size, overlap):
    start = 0
    chunks = []
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

def check_for_trali(discharge_text, llm, prompt_template, chunk_size, chunk_overlap):
    chunks = chunk_text(discharge_text, chunk_size, chunk_overlap)
    results = []
    for chunk in chunks:
        prompt = prompt_template.format(discharge_text=chunk)
        try:
            response = llm.invoke(prompt)
            results.append(response.strip())
        except Exception as e:
            results.append(f"Error invoking model: {e}")
    trali_mentions = [res for res in results if "Yes" in res]
    if trali_mentions:
        return "Yes", trali_mentions[0], len(discharge_text) # Return trali result, explanation, and length of discharge_text
    else:
        return "No", results[0] if results else "No sufficient data", len(discharge_text) # Return trali result, explanation, and length of discharge_text

def process_patients(df, start_index, num_patients, llm, prompt_template, chunk_size, chunk_overlap, output_csv_file, progress_report_file):
    processing_time = []
    with open(output_csv_file, 'a', newline='') as csvfile, open(progress_report_file, 'a') as report_file:
        # Open the CSV file for writing
        fieldnames = ['hadm_id', 'discharge_text_length', 'trali_detected', 'time_taken']
        # Define the column names
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        # Only write header if the file is empty
        if csvfile.tell() == 0:
            writer.writeheader()  # Write the header row

        for i in range(start_index, start_index + num_patients):
            current_hadm_id = df['hadm_id'].values[i]
            start_time = time.time()
            data = df[df['hadm_id'] == current_hadm_id]
            if data.empty:
                result = f"No data found for hadm_id: {current_hadm_id}"
            else:
                discharge_text = data['discharge_text'].values[0]
                trali_result, explanation, discharge_text_length = check_for_trali(discharge_text, llm, prompt_template, chunk_size, chunk_overlap)
                end_time = time.time()
                elapsed_time = end_time - start_time
                minutes, seconds = divmod(elapsed_time, 60)
                processing_time.append(elapsed_time)
                # Write data to CSV file
                writer.writerow({
                    'hadm_id': current_hadm_id,
                    'discharge_text_length': discharge_text_length,
                    'trali_detected': trali_result,
                    'time_taken': round(elapsed_time)
                })
                csvfile.flush()  # Flush the buffer to ensure data is written

                # Write data to progress report file
                report_file.write(f"Patient Number: {i}, HADM ID: {current_hadm_id}, Discharge Text Length: {discharge_text_length}, TRALI Detected: {trali_result}, Time Taken: {round(elapsed_time)}\n")
                report_file.flush()  # Flush the buffer to ensure data is written

                print(f"Processed Patient Number {i}\n")

# %% [markdown]
# # Main (calls all the functions above)

# %%
def main(file_path, model_name, chunk_size, chunk_overlap, output_csv_file, progress_report_file, num_patients):
    df = load_data(file_path)
    #start_index = select_random_start(len(df))
    start_index = 199
    prompt_template = create_prompt_template()
    llm = Ollama(model=model_name, callback_manager=CallbackManager([StreamingStdOutCallbackHandler()]))
    process_patients(df, start_index, num_patients, llm, prompt_template, chunk_size, chunk_overlap, output_csv_file, progress_report_file)

if __name__ == "__main__":
    main(
        file_path='/content/drive/My Drive/ards-cohort-notes/ards-cohort-notes.csv',
        model_name="llama3",
        chunk_size=4096,
        chunk_overlap=100,
        output_csv_file='trali-trial-2020.csv',  # Change the output file name to a CSV file
        progress_report_file='trali-trial-2020.txt',  # Path to the progress report file
        num_patients = 1822
    )
# Out:
# NoNoNoNo.Processed Patient Number 199
#
# NoNoNoNoNoProcessed Patient Number 200
#
# NoNoNo.Processed Patient Number 201
#
# YesNoProcessed Patient Number 202
#
# NoNoNoNo.Processed Patient Number 203
#
# No.NoNo.No.No.Processed Patient Number 204
#
# NoNoProcessed Patient Number 205
#
# NoNoNoNoProcessed Patient Number 206
#
# NoNoYesNoNoProcessed Patient Number 207
#
# NoNoNoNo.Processed Patient Number 208
#
# NoNoNoProcessed Patient Number 209
#
# NoNoNoNoNoNoNo.Processed Patient Number 210
#
# YesNoNoNoNoNo.Processed Patient Number 211
#
# NoNo.NoNoProcessed Patient Number 212
#
# No.NoNoNoNoNoNoProcessed Patient Number 213
#
# NoNoNo.No.NoNoProcessed Patient Number 214
#
# No.NoNoNoNoNoProcessed Patient Number 215
#
# NoNo.No.NoNo.No.Processed Patient Number 216
#
# NoNoNoNoProcessed Patient Number 217
#
# No.No.YesNoProcessed Patient Number 218
#
# NoYesProcessed Patient Number 219
#
# NoNoNoNoProcessed Patient Number 220
#
# No.NoNoProcessed Patient Number 221
#
# NoNoNoProcessed Patient Number 222
#
# NoNoNoNoNo.Processed Patient Number 223
#
# No.NoNoNoNo.Processed Patient Number 224
#
# NoNoNo.NoProcessed Patient Number 225
#
# NoNo.Processed Patient Number 226
#
# NoNoNoProcessed Patient Number 227
#
# No.NoNoNoProcessed Patient Number 228
#
# No.No.No.No.Processed Patient Number 229
#
# NoNoProcessed Patient Number 230
#
# No.NoNoNo.No.Processed Patient Number 231
#
# NoNoNoNoProcessed Patient Number 232
#
# No.NoNoNo.Processed Patient Number 233
#
# NoNoNo.NoNoProcessed Patient Number 234
#
# No.After reviewing the provided chunks of clinical text, I found no mentions of "transfusion-related acute lung injury" (TRALI) in any of them. Therefore, my answer is:
#
# NoNoNoNoNo.No.Processed Patient Number 235
#
# NoNoNoNo.Processed Patient Number 236
#
# NoNoNo.Processed Patient Number 237
#
# NoNoNoProcessed Patient Number 238
#
# YesNoNoNoProcessed Patient Number 239
#
# NoNo.NoProcessed Patient Number 240
#
# NoNoProcessed Patient Number 241
#
# NoNoNoNoProcessed Patient Number 242
#
# NoNoNoNo.NoProcessed Patient Number 243
#
# NoNoNoNo.NoNo.Processed Patient Number 244
#
# No.NoNoProcessed Patient Number 245
#
# NoNoNoNoProcessed Patient Number 246
#
# No.No.NoNoProcessed Patient Number 247
#
# No.NoNoProcessed Patient Number 248
#
# NoNoNoNoNoNo.NoProcessed Patient Number 249
#
# No.No.Processed Patient Number 250
#
# NoNo.No.NoProcessed Patient Number 251
#
# NoYesNoProcessed Patient Number 252
#
# NoNoNo.NoProcessed Patient Number 253
#
# No.NoNoYesNo.Processed Patient Number 254
#
# NoNoNoProcessed Patient Number 255
#
# NoNoNoNoNoNo.Processed Patient Number 256
#
# NoNoNoNoNoNoProcessed Patient Number 257
#
# NoNoNoNo.No.NoProcessed Patient Number 258
#
# NoNoNoProcessed Patient Number 259
#
# NoNoNoNo.NoProcessed Patient Number 260
#
# NoNoNoNoNoNoProcessed Patient Number 261
#
# NoYesNo.NoNoNo.Processed Patient Number 262
#
# NoNoNoNoNo.Processed Patient Number 263
#
# NoNo.NoNoProcessed Patient Number 264
#
# NoNo.NoProcessed Patient Number 265
#
# NoNo.No.Processed Patient Number 266
#
# NoNoNo.No.Processed Patient Number 267
#
# NoNoNoYesProcessed Patient Number 268
#
# No.NoNo.NoProcessed Patient Number 269
#
# NoNoNoProcessed Patient Number 270
#
# NoNoNoNoNoProcessed Patient Number 271
#
# No.NoProcessed Patient Number 272
#
# NoNoNoNoNoNoNoProcessed Patient Number 273
#
# NoNo.NoNoNoNoNoProcessed Patient Number 274
#
# NoNoNoNoNoNoProcessed Patient Number 275
#
# NoNoNoProcessed Patient Number 276
#
# No.No.NoNoNoNoProcessed Patient Number 277
#
# NoNo.NoProcessed Patient Number 278
#
# NoNo.NoProcessed Patient Number 279
#
# NoNoNoNo.Processed Patient Number 280
#
# NoNo.NoProcessed Patient Number 281
#
# NoNoNo.No.Processed Patient Number 282
#
# NoNoNoNoProcessed Patient Number 283
#
# YesNoNoProcessed Patient Number 284
#
# NoNoNoNoNoProcessed Patient Number 285
#
# No.Processed Patient Number 286
#
# No.NoNoNoProcessed Patient Number 287
#
# NoNoNoProcessed Patient Number 288
#
# NoNo.NoNo.NoProcessed Patient Number 289
#
# NoNoNoNoNoProcessed Patient Number 290
#
# NoNo.NoNo.YesNoNoProcessed Patient Number 291
#
# No.NoNoNo.Processed Patient Number 292
#
# NoNo.NoProcessed Patient Number 293
#
# NoNoNoNo.No.Processed Patient Number 294
#
# NoNoNoNoProcessed Patient Number 295
#
# NoNoProcessed Patient Number 296
#
# NoNo.NoProcessed Patient Number 297
#
# NoNoNoProcessed Patient Number 298
#
# NoNo.NoNoNoProcessed Patient Number 299
#
# No.NoNoNo.NoNoNoNo.Processed Patient Number 300
#
# NoNo.NoProcessed Patient Number 301
#
# NoNo.NoNo.NoProcessed Patient Number 302
#
# No.No.Processed Patient Number 303
#
# NoNoProcessed Patient Number 304
#
# NoNoNoNoProcessed Patient Number 305
#
# No.NoNoNoNoNoProcessed Patient Number 306
#
# NoYesProcessed Patient Number 307
#
# NoNoNoNoNoNoNoNoNoNoProcessed Patient Number 308
#
# No.Processed Patient Number 309
#
# NoNoNo.Processed Patient Number 310
#
# NoNoProcessed Patient Number 311
#
# NoNo.No.Processed Patient Number 312
#
# No.NoNoNo.Processed Patient Number 313
#
# NoNoNoProcessed Patient Number 314
#
# NoNoNoProcessed Patient Number 315
#
# No.NoNoNoProcessed Patient Number 316
#
# NoNoNoProcessed Patient Number 317
#
# NoNoYesNoNo.Processed Patient Number 318
#
# NoNo.No.NoNoNoNoNo.Processed Patient Number 319
#
# No.NoNoNoProcessed Patient Number 320
#
# No.NoNoNoNoNoNoNoNo.Processed Patient Number 321
#
# NoNoNoNoProcessed Patient Number 322
#
# No.Processed Patient Number 323
#
# YesNoNoNoProcessed Patient Number 324
#
# NoNoNo.NoProcessed Patient Number 325
#
# NoNoNoNo.NoNoNoNoProcessed Patient Number 326
#
# No.No.NoNo.NoProcessed Patient Number 327
#
# NoNoNoNo.NoProcessed Patient Number 328
#
# NoNoNoNo.Processed Patient Number 329
#
# NoNo.No.NoNo.NoProcessed Patient Number 330
#
# NoNoProcessed Patient Number 331
#
# No.NoNoProcessed Patient Number 332
#
# NoNo.NoNoNoNoNoProcessed Patient Number 333
#
# No.NoNoNoProcessed Patient Number 334
#
# NoNoNoNoNoNoNoNoNo.Processed Patient Number 335
#
# NoNoNoProcessed Patient Number 336
#
# YesNoNoNoNoNoNoProcessed Patient Number 337
#
# NoNoNo.Processed Patient Number 338
#
# NoNoNo.NoNo.No.Processed Patient Number 339
#
# NoNoNoProcessed Patient Number 340
#
# NoYesNoProcessed Patient Number 341
#
# No.NoNoNo.Processed Patient Number 342
#
# NoNoNoNo.NoProcessed Patient Number 343
#
# NoNoYesProcessed Patient Number 344
#
# NoNo.NoNoNoNoNo.Processed Patient Number 345
#
# NoNoProcessed Patient Number 346
#
# No.NoNo.NoNoProcessed Patient Number 347
#
# NoNoNoNoNoNo.NoProcessed Patient Number 348
#
# NoNoProcessed Patient Number 349
#
# No.NoNoNoNoNoProcessed Patient Number 350
#
# No.No.NoProcessed Patient Number 351
#
# NoNoNoNoNoProcessed Patient Number 352
#
# No.Processed Patient Number 353
#
# NoNoNoNoProcessed Patient Number 354
#
# No.NoNo.NoNo.NoProcessed Patient Number 355
#
# NoNoNoNo.No.NoNo.NoNoNoProcessed Patient Number 356
#
# NoNoProcessed Patient Number 357
#
# No.No.Processed Patient Number 358
#
# NoNoNoNoProcessed Patient Number 359
#
# NoNoNoNoNoProcessed Patient Number 360
#
# NoNoNoNoNoNoNoNoNoNoProcessed Patient Number 361
#
# No.NoNoProcessed Patient Number 362
#
# No.NoNo.Processed Patient Number 363
#
# NoNoNoNoProcessed Patient Number 364
#
# NoNoNoProcessed Patient Number 365
#
# YesNoNoProcessed Patient Number 366
#
# NoNoNo.NoNo.No.Processed Patient Number 367
#
# NoNoNo.NoProcessed Patient Number 368
#
# No.NoNoProcessed Patient Number 369
#
# No.NoNoNoProcessed Patient Number 370
#
# NoNoNoProcessed Patient Number 371
#
# NoNoNoProcessed Patient Number 372
#
# No.NoNoNoNoProcessed Patient Number 373
#
# NoNoNoNoNoProcessed Patient Number 374
#
# NoNoNoNo.Processed Patient Number 375
#
# NoNoNoNoNoProcessed Patient Number 376
#
# NoNoNo.Processed Patient Number 377
#
# YesNoNoNoNoNoProcessed Patient Number 378
#
# NoNoNo.NoNoNoNo.Processed Patient Number 379
#
# NoNoNoNo.NoProcessed Patient Number 380
#
# NoNoNoNo.NoProcessed Patient Number 381
#
# NoNo.No.No.NoNoNoNoNoNoNo.Processed Patient Number 382
#
# No.NoNoNoProcessed Patient Number 383
#
# No.NoNoNoNoProcessed Patient Number 384
#
# NoNo.NoNoProcessed Patient Number 385
#
# NoNoNo.NoNoNoNoNoProcessed Patient Number 386
#
# NoNo.NoProcessed Patient Number 387
#
# No.NoNoNoProcessed Patient Number 388
#
# NoNoNo.Processed Patient Number 389
#
# No.No.No.NoNoNoProcessed Patient Number 390
#
# No.NoNoProcessed Patient Number 391
#
# NoNo.Processed Patient Number 392
#
# No.NoNoProcessed Patient Number 393
#
# NoNoNoProcessed Patient Number 394
#
# NoNoNoYesNoProcessed Patient Number 395
#
# NoNoNoNoNoProcessed Patient Number 396
#
# NoNo.NoNoProcessed Patient Number 397
#
# No.NoPlt NoNoNoNoProcessed Patient Number 398
#
# NoNoNoNoNoProcessed Patient Number 399
#
# No.NoNoProcessed Patient Number 400
#
# No.NoNoProcessed Patient Number 401
#
# NoNoNoNoNoProcessed Patient Number 402
#
# No.NoNoProcessed Patient Number 403
#
# No.NoNoNoNo.Processed Patient Number 404
#
# No.No.No.NoProcessed Patient Number 405
#
# NoNo.Processed Patient Number 406
#
# NoNoNoNoProcessed Patient Number 407
#
# NoNoNoNoNoNoProcessed Patient Number 408
#
# NoNoNoProcessed Patient Number 409
#
# NoNoNoProcessed Patient Number 410
#
# No.NoNoProcessed Patient Number 411
#
# No.NoNoNoNoNoProcessed Patient Number 412
#
# NoNoNoNo.NoProcessed Patient Number 413
#
# YesNoNoProcessed Patient Number 414
#
# NoNo.NoNoNoNo.NoNo.Processed Patient Number 415
#
# NoNoNoNo.Processed Patient Number 416
#
# No.No.NoNoProcessed Patient Number 417
#
# NoNoNoNoProcessed Patient Number 418
#
# YesNo.NoNoNo.Processed Patient Number 419
#
# NoNoNoNoProcessed Patient Number 420
#
# NoNoNoNoNoNoProcessed Patient Number 421
#
# No.No.NoNoNoNo.Processed Patient Number 422
#
# NoNo.NoNoNoNo.Processed Patient Number 423
#
# NoNo.NoNoNoProcessed Patient Number 424
#
# NoNoNoNoNo.NoProcessed Patient Number 425
#
# NoNo.NoProcessed Patient Number 426
#
# NoNoNoNoProcessed Patient Number 427
#
# NoNoNoNoNoProcessed Patient Number 428
#
# NoNoNoNoProcessed Patient Number 429
#
# No.No.NoNoNoNoProcessed Patient Number 430
#
# NoNoProcessed Patient Number 431
#
# NoNoNo.No.NoProcessed Patient Number 432
#
# No.No.NoProcessed Patient Number 433
#
# No.NoNo.NoProcessed Patient Number 434
#
# No.NoProcessed Patient Number 435
#
# NoNo.No.NoNoProcessed Patient Number 436
#
# NoNo.No.NoNo.Processed Patient Number 437
#
# No.NoNo.NoProcessed Patient Number 438
#
# NoNoNo.NoNo.Processed Patient Number 439
#
# NoNoProcessed Patient Number 440
#
# NoNoNoNo.NoProcessed Patient Number 441
#
# No.NoNoProcessed Patient Number 442
#
# NoNoNoNo.NoProcessed Patient Number 443
#
# No.No.NoYesNoProcessed Patient Number 444
#
# No.NoNo.Processed Patient Number 445
#
# NoNoNoNoProcessed Patient Number 446
#
# No.No.NoNoNoProcessed Patient Number 447
#
# NoNoNoNoNo.No.Processed Patient Number 448
#
# NoNoNoNoNoNo.NoProcessed Patient Number 449
#
# NoNoNoNoProcessed Patient Number 450
#
# NoNoNoNoProcessed Patient Number 451
#
# NoNoNoNoNoProcessed Patient Number 452
#
# No.No.NoProcessed Patient Number 453
#
# NoNoNo.NoProcessed Patient Number 454
#
# No.NoNoNoNoYesNoNoNoProcessed Patient Number 455
#
# NoNoNo.NoProcessed Patient Number 456
#
# NoNoNoNo.Processed Patient Number 457
#
# NoNoNoNo.Processed Patient Number 458
#
# NoNoNoNoNoProcessed Patient Number 459
#
# NoNoNo.No.No.Processed Patient Number 460
#
# No.NoNoNoProcessed Patient Number 461
#
# NoNoNoNo.NoProcessed Patient Number 462
#
# No.NoNo.No.No.No.NoNo.Processed Patient Number 463
#
# NoNo.NoNoNoProcessed Patient Number 464
#
# NoNoNoYesNoProcessed Patient Number 465
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 466
#
# NoNo.NoNoProcessed Patient Number 467
#
# NoNoProcessed Patient Number 468
#
# NoNoNoNoProcessed Patient Number 469
#
# No.No.NoNo.NoNoProcessed Patient Number 470
#
# NoNoNoProcessed Patient Number 471
#
# No.NoProcessed Patient Number 472
#
# No.NoNoProcessed Patient Number 473
#
# No.NoNoNoNoNoProcessed Patient Number 474
#
# No.No.NoNoNoProcessed Patient Number 475
#
# YesNoNo.NoNoProcessed Patient Number 476
#
# No.NoProcessed Patient Number 477
#
# NoNoNoProcessed Patient Number 478
#
# NoYesNoNo.NoProcessed Patient Number 479
#
# No.NoNo.Processed Patient Number 480
#
# NoNoNoNo.No.Processed Patient Number 481
#
# No.NoNoNo.Processed Patient Number 482
#
# No.NoNoNoNoProcessed Patient Number 483
#
# NoNoNoProcessed Patient Number 484
#
# NoNoYesNo.Processed Patient Number 485
#
# NoNo.No.No.NoNoNoProcessed Patient Number 486
#
# NoNoNoNoProcessed Patient Number 487
#
# NoNoNoNoNo.No.NoNoNoNoProcessed Patient Number 488
#
# No.NoNoNo.Processed Patient Number 489
#
# NoNo.NoNoNoProcessed Patient Number 490
#
# NoNoNoProcessed Patient Number 491
#
# No.NoNoNo.NoProcessed Patient Number 492
#
# No.NoNoNoProcessed Patient Number 493
#
# NoNoNoProcessed Patient Number 494
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 495
#
# NoNoProcessed Patient Number 496
#
# NoNoNoNoNoProcessed Patient Number 497
#
# NoNo.NoNoNo.Processed Patient Number 498
#
# NoNo.No.Processed Patient Number 499
#
# NoNoNoProcessed Patient Number 500
#
# NoNoNoProcessed Patient Number 501
#
# No.NoNoNoNoProcessed Patient Number 502
#
# NoNo.NoNoNoProcessed Patient Number 503
#
# No.NoProcessed Patient Number 504
#
# No.NoNoNoNoProcessed Patient Number 505
#
# NoNoNoNoNoProcessed Patient Number 506
#
# NoNo.No.Processed Patient Number 507
#
# No.NoNoProcessed Patient Number 508
#
# NoNo.NoNoNoNoNoNoProcessed Patient Number 509
#
# NoNoNo.NoNo.Processed Patient Number 510
#
# NoNo.NoProcessed Patient Number 511
#
# No.NoNoNoNoNoProcessed Patient Number 512
#
# NoNo.NoNoProcessed Patient Number 513
#
# NoNoProcessed Patient Number 514
#
# No.NoNoNo.Processed Patient Number 515
#
# NoNo.NoNo.Processed Patient Number 516
#
# No.NoProcessed Patient Number 517
#
# NoNoNoProcessed Patient Number 518
#
# NoNoNoProcessed Patient Number 519
#
# NoNoNoProcessed Patient Number 520
#
# No.NoNo.NoNoNoProcessed Patient Number 521
#
# NoNo.NoNoNo.Processed Patient Number 522
#
# No.No.NoNoNo.No.Processed Patient Number 523
#
# NoNoNo.NoNoProcessed Patient Number 524
#
# NoNo.NoNo.Processed Patient Number 525
#
# NoNo.NoNo.Processed Patient Number 526
#
# NoNo.NoProcessed Patient Number 527
#
# NoNoNoNoProcessed Patient Number 528
#
# NoNoNoNoNoProcessed Patient Number 529
#
# No.No.NoNo.Processed Patient Number 530
#
# NoNoNoProcessed Patient Number 531
#
# NoNoNo.Processed Patient Number 532
#
# NoNoNoProcessed Patient Number 533
#
# NoNoNoProcessed Patient Number 534
#
# YesNoNoProcessed Patient Number 535
#
# NoNoProcessed Patient Number 536
#
# No.NoProcessed Patient Number 537
#
# NoNoNoNoNoNoProcessed Patient Number 538
#
# NoNoNoNoNoProcessed Patient Number 539
#
# NoNoNoProcessed Patient Number 540
#
# NoNo.NoYesNo.Processed Patient Number 541
#
# NoNoNoNoNoProcessed Patient Number 542
#
# NoNoProcessed Patient Number 543
#
# No.No.No.NoNoNoProcessed Patient Number 544
#
# NoNoYesProcessed Patient Number 545
#
# NoNoNoNoProcessed Patient Number 546
#
# NoNo.NoNo.NoNoNoProcessed Patient Number 547
#
# NoNoProcessed Patient Number 548
#
# No.NoNoProcessed Patient Number 549
#
# No.NoNo.Processed Patient Number 550
#
# NoYesNoNoProcessed Patient Number 551
#
# No.NoNoNo.NoProcessed Patient Number 552
#
# No.No.No.NoNo.NoProcessed Patient Number 553
#
# NoNoProcessed Patient Number 554
#
# NoNoNo.NoNoNo.Processed Patient Number 555
#
# NoNoNo.NoNo.Processed Patient Number 556
#
# NoNoNoProcessed Patient Number 557
#
# NoNoNoNoNoProcessed Patient Number 558
#
# NoNo.No.Processed Patient Number 559
#
# No.NoNoNoNoProcessed Patient Number 560
#
# NoNoProcessed Patient Number 561
#
# NoNo.No.NoNoProcessed Patient Number 562
#
# No.I can do that!
#
# After reviewing the chunks of clinical text, I did not find any mentions of transfusion-related acute lung injury (TRALI) in this dataset. Therefore, my answer is:
#
# **No**
#
# Please let me know if you have any further queries!No.No.YesNoProcessed Patient Number 563
#
# No.NoNoProcessed Patient Number 564
#
# NoNoNoNo.NoNoProcessed Patient Number 565
#
# NoNo.NoProcessed Patient Number 566
#
# No.No.NoProcessed Patient Number 567
#
# No.NoNoProcessed Patient Number 568
#
# No.NoNo.NoProcessed Patient Number 569
#
# NoNo.NoProcessed Patient Number 570
#
# NoNoNoNoNoProcessed Patient Number 571
#
# No.NoNo.NoNoNo.Processed Patient Number 572
#
# NoNoNoNoNo.Processed Patient Number 573
#
# NoNoNoProcessed Patient Number 574
#
# NoNo.NoNoNoProcessed Patient Number 575
#
# NoNoNo.NoNo.Processed Patient Number 576
#
# NoNoNoProcessed Patient Number 577
#
# NoNoNoProcessed Patient Number 578
#
# NoNoNoNoNoProcessed Patient Number 579
#
# NoNoNo.NoNoNoNoNoNoNo.Processed Patient Number 580
#
# No.NoNoNoProcessed Patient Number 581
#
# NoNo.Processed Patient Number 582
#
# No.No.No.No.NoProcessed Patient Number 583
#
# NoNo.NoProcessed Patient Number 584
#
# NoNoProcessed Patient Number 585
#
# NoNo.NoNoNoProcessed Patient Number 586
#
# NoNo.NoNoNo.No.Processed Patient Number 587
#
# NoNoNoNoProcessed Patient Number 588
#
# No.NoNoProcessed Patient Number 589
#
# NoNoYesNoProcessed Patient Number 590
#
# NoNo.NoNoNo.NoNoNoNoNoProcessed Patient Number 591
#
# NoNo.No.Processed Patient Number 592
#
# NoNoNoNoProcessed Patient Number 593
#
# NoNoNo.Processed Patient Number 594
#
# NoNoNoNoNoNoProcessed Patient Number 595
#
# NoNoNoNoNoProcessed Patient Number 596
#
# NoNoNo.NoProcessed Patient Number 597
#
# NoNoProcessed Patient Number 598
#
# No.NoNoNo.NoProcessed Patient Number 599
#
# No.No.NoProcessed Patient Number 600
#
# No.NoProcessed Patient Number 601
#
# NoNoNoNoProcessed Patient Number 602
#
# YesNoNo.No.NoNoProcessed Patient Number 603
#
# No.NoNoNo.Processed Patient Number 604
#
# No.NoNoNo.No.Processed Patient Number 605
#
# YesNoNo.No.Processed Patient Number 606
#
# NoNoNoNoProcessed Patient Number 607
#
# NoNoNoNo.Processed Patient Number 608
#
# NoNoNoNoProcessed Patient Number 609
#
# NoNoNoProcessed Patient Number 610
#
# NoNo.No.NoNo.NoNoNoProcessed Patient Number 611
#
# NoNoNoNo.NoNoProcessed Patient Number 612
#
# NoNo.NoProcessed Patient Number 613
#
# YesNoNoNoNoProcessed Patient Number 614
#
# NoNoNoNoProcessed Patient Number 615
#
# NoNo.NoProcessed Patient Number 616
#
# NoNoProcessed Patient Number 617
#
# No.NoProcessed Patient Number 618
#
# No.No.No.Processed Patient Number 619
#
# NoNo.No.NoNoNo.NoProcessed Patient Number 620
#
# NoNoNo.No.NoProcessed Patient Number 621
#
# No.No.NoNoNoProcessed Patient Number 622
#
# NoNoNoNoProcessed Patient Number 623
#
# No.No.NoNoNoNoProcessed Patient Number 624
#
# NoNo.NoNoNo.No.Processed Patient Number 625
#
# NoNoNo.No.No.Processed Patient Number 626
#
# NoNoNoNoProcessed Patient Number 627
#
# No.NoNoNoNoProcessed Patient Number 628
#
# NoNoNoProcessed Patient Number 629
#
# No.NoNo.Processed Patient Number 630
#
# NoNoProcessed Patient Number 631
#
# NoNoNoNoNoNoProcessed Patient Number 632
#
# No.NoNo.NoNoProcessed Patient Number 633
#
# NoNoNo.Processed Patient Number 634
#
# NoNoNo.Processed Patient Number 635
#
# NoNo.No.Processed Patient Number 636
#
# NoNoNoProcessed Patient Number 637
#
# NoNoNoNoNoProcessed Patient Number 638
#
# NoNo.No.NoNoNoNoNoNoProcessed Patient Number 639
#
# NoNoProcessed Patient Number 640
#
# NoNo.NoNoNo.NoProcessed Patient Number 641
#
# NoNoNoNoProcessed Patient Number 642
#
# NoNoNo.NoProcessed Patient Number 643
#
# NoNoNoProcessed Patient Number 644
#
# No.No.NoProcessed Patient Number 645
#
# NoNoNoProcessed Patient Number 646
#
# No.NoNo.No.No.Processed Patient Number 647
#
# No.Processed Patient Number 648
#
# NoNoNo.NoNoProcessed Patient Number 649
#
# YesNoNoNoNoProcessed Patient Number 650
#
# No.NoNoProcessed Patient Number 651
#
# NoNo.NoNoNoProcessed Patient Number 652
#
# NoNoNo.No.Processed Patient Number 653
#
# No.NoNo.No.Processed Patient Number 654
#
# NoNoProcessed Patient Number 655
#
# NoNoNoNoNoNoNoNoNoNoNoNoNoNoNoProcessed Patient Number 656
#
# NoNo.NoNoProcessed Patient Number 657
#
# NoNo.No.Processed Patient Number 658
#
# NoNo.Processed Patient Number 659
#
# NoNo.Processed Patient Number 660
#
# NoNoNoNoProcessed Patient Number 661
#
# No.NoNo.Processed Patient Number 662
#
# NoNoNo.NoProcessed Patient Number 663
#
# NoNoNoNoProcessed Patient Number 664
#
# NoNo.No.Processed Patient Number 665
#
# NoYesNoNoNoNo.NoNoProcessed Patient Number 666
#
# No.NoNoNo.NoProcessed Patient Number 667
#
# NoNoNoNoNoNoNoProcessed Patient Number 668
#
# NoNoNoNoNoNoProcessed Patient Number 669
#
# NoNoNoNoProcessed Patient Number 670
#
# NoNoNoNoProcessed Patient Number 671
#
# NoNoNoNo.NoNoNo.Processed Patient Number 672
#
# No.NoNoProcessed Patient Number 673
#
# NoNoNoProcessed Patient Number 674
#
# NoNoNoNoNoNoNoProcessed Patient Number 675
#
# NoNoNoNoNoProcessed Patient Number 676
#
# NoNoNoProcessed Patient Number 677
#
# NoNoNoProcessed Patient Number 678
#
# YesNoNoNoNoProcessed Patient Number 679
#
# NoNo.NoNoNoNoProcessed Patient Number 680
#
# No.NoNo.NoNoNoProcessed Patient Number 681
#
# No.NoNoNoNoProcessed Patient Number 682
#
# NoNoNo.NoProcessed Patient Number 683
#
# No.NoNo.NoProcessed Patient Number 684
#
# NoNoNoNoProcessed Patient Number 685
#
# No.No.NoNo.No.Processed Patient Number 686
#
# NoNoNoNoProcessed Patient Number 687
#
# NoNoNoNoNoNoNoNo.NoNoNo.Processed Patient Number 688
#
# NoNoNoProcessed Patient Number 689
#
# YesNoNoProcessed Patient Number 690
#
# NoNoNoNo.NoNo.No.Processed Patient Number 691
#
# NoNoNoNoProcessed Patient Number 692
#
# YesNoNoProcessed Patient Number 693
#
# NoNoNoNoNoProcessed Patient Number 694
#
# NoNo.NoNoProcessed Patient Number 695
#
# NoNoNoNoProcessed Patient Number 696
#
# NoNoNo.NoProcessed Patient Number 697
#
# NoNoNoNoNoNoNo.NoProcessed Patient Number 698
#
# NoNoNoNoNoProcessed Patient Number 699
#
# NoNoNoNoProcessed Patient Number 700
#
# No.NoNoNoNoNo.NoProcessed Patient Number 701
#
# No.No.No.NoNoNoNoNo.Processed Patient Number 702
#
# NoNoNoProcessed Patient Number 703
#
# NoNoProcessed Patient Number 704
#
# NoNoNoNoProcessed Patient Number 705
#
# NoNo.NoNo.Processed Patient Number 706
#
# NoNoNo.NoProcessed Patient Number 707
#
# NoNoNoProcessed Patient Number 708
#
# No.NoNo.No.No.NoProcessed Patient Number 709
#
# NoNo.Processed Patient Number 710
#
# NoNoNoNoNoProcessed Patient Number 711
#
# NoNoNoProcessed Patient Number 712
#
# No.NoNoNoNo.No.Processed Patient Number 713
#
# No.NoNoNoProcessed Patient Number 714
#
# NoNoNo.No.NoNo.Processed Patient Number 715
#
# NoNoProcessed Patient Number 716
#
# No.NoNoProcessed Patient Number 717
#
# NoNo.NoProcessed Patient Number 718
#
# NoNoNoNoProcessed Patient Number 719
#
# No.NoNo.NoNoNo.Processed Patient Number 720
#
# NoNoProcessed Patient Number 721
#
# NoNoNoNoProcessed Patient Number 722
#
# NoNoNoProcessed Patient Number 723
#
# NoNoNoNoNoProcessed Patient Number 724
#
# NoNoNoNoNoNoProcessed Patient Number 725
#
# NoNo.Processed Patient Number 726
#
# NoNo.NoProcessed Patient Number 727
#
# NoNoNoNoNoProcessed Patient Number 728
#
# No.NoProcessed Patient Number 729
#
# NoNoNoNoNoNo.NoProcessed Patient Number 730
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 731
#
# NoNo.No.No.Processed Patient Number 732
#
# No.No.NoNoProcessed Patient Number 733
#
# NoNoNo.Processed Patient Number 734
#
# NoYesNoProcessed Patient Number 735
#
# NoNoNoProcessed Patient Number 736
#
# YesNo.NoNoProcessed Patient Number 737
#
# NoNo.Processed Patient Number 738
#
# NoNoNo.Processed Patient Number 739
#
# NoNoProcessed Patient Number 740
#
# No.No.NoNo.NoNoNoNoNoProcessed Patient Number 741
#
# No.NoNoNoNoNo.NoNoProcessed Patient Number 742
#
# NoNoNoProcessed Patient Number 743
#
# NoNoNoProcessed Patient Number 744
#
# YesNo.NoNoNoProcessed Patient Number 745
#
# No.NoNoNoNo.No.Processed Patient Number 746
#
# NoNoNoProcessed Patient Number 747
#
# NoNo.YesProcessed Patient Number 748
#
# No.NoNoProcessed Patient Number 749
#
# NoNoProcessed Patient Number 750
#
# NoNoNoProcessed Patient Number 751
#
# No.NoNo.Processed Patient Number 752
#
# NoNoNoNoNoProcessed Patient Number 753
#
# No.NoProcessed Patient Number 754
#
# No.NoProcessed Patient Number 755
#
# No.No.Processed Patient Number 756
#
# No.NoNoNo.No.NoProcessed Patient Number 757
#
# NoNoProcessed Patient Number 758
#
# NoNoNoNoNoProcessed Patient Number 759
#
# NoNoNoNoProcessed Patient Number 760
#
# NoNoProcessed Patient Number 761
#
# No.NoNoProcessed Patient Number 762
#
# NoNo.Processed Patient Number 763
#
# NoNoProcessed Patient Number 764
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 765
#
# No.NoNoNoProcessed Patient Number 766
#
# No.NoNo.NoProcessed Patient Number 767
#
# NoNoNoNo.NoProcessed Patient Number 768
#
# NoNoNoNoProcessed Patient Number 769
#
# NoNoNoProcessed Patient Number 770
#
# NoNoNoNoNo.Processed Patient Number 771
#
# NoNoNoNo.NoProcessed Patient Number 772
#
# No.NoNo.NoNoNoProcessed Patient Number 773
#
# No.No.NoNoNoNoProcessed Patient Number 774
#
# NoNo.NoProcessed Patient Number 775
#
# YesNoNoNo.NoProcessed Patient Number 776
#
# NoNoNoNoProcessed Patient Number 777
#
# NoNoNoNo.No.Processed Patient Number 778
#
# NoNoNoNoProcessed Patient Number 779
#
# No.NoNoNoNoProcessed Patient Number 780
#
# NoNoNoProcessed Patient Number 781
#
# NoNo.No.NoNoNoNoNo.Processed Patient Number 782
#
# NoNoNo.NoNoNoNoNoNo.Processed Patient Number 783
#
# NoNoNo.Processed Patient Number 784
#
# No.NoNoProcessed Patient Number 785
#
# NoNoNoNo.NoNoNoProcessed Patient Number 786
#
# NoNo.NoProcessed Patient Number 787
#
# NoNo.Processed Patient Number 788
#
# NoNo.NoNoProcessed Patient Number 789
#
# NoNo.NoNoNo.NoNoNoNoProcessed Patient Number 790
#
# NoNo.NoNoNo.Processed Patient Number 791
#
# No.NoProcessed Patient Number 792
#
# No.NoNoNo.NoProcessed Patient Number 793
#
# YesNoNoNoProcessed Patient Number 794
#
# No.NoNoNo.Processed Patient Number 795
#
# NoNoNoProcessed Patient Number 796
#
# NoNoNo.No.NoProcessed Patient Number 797
#
# NoNoNoNo.NoProcessed Patient Number 798
#
# YesNoNoNoNo.Processed Patient Number 799
#
# NoNoNo.NoProcessed Patient Number 800
#
# NoNo.No.NoProcessed Patient Number 801
#
# No.NoNoNoProcessed Patient Number 802
#
# No.No.No.No.NoNo.NoProcessed Patient Number 803
#
# NoNo.NoNoNoNoNoProcessed Patient Number 804
#
# NoNo.NoProcessed Patient Number 805
#
# NoNoNoNoProcessed Patient Number 806
#
# NoNoYesNo.Processed Patient Number 807
#
# NoNoNoProcessed Patient Number 808
#
# NoNo.NoProcessed Patient Number 809
#
# NoNoNoNo.Processed Patient Number 810
#
# NoNoNoNo.Processed Patient Number 811
#
# No.No.NoNo.Processed Patient Number 812
#
# NoNoNoNoNoProcessed Patient Number 813
#
# NoNo.NoNoNo.NoProcessed Patient Number 814
#
# NoNoNoProcessed Patient Number 815
#
# NoNoNoProcessed Patient Number 816
#
# NoNoNo.Processed Patient Number 817
#
# NoProcessed Patient Number 818
#
# NoNoNo.NoNoProcessed Patient Number 819
#
# No.NoProcessed Patient Number 820
#
# NoNo.NoProcessed Patient Number 821
#
# YesNo.NoNoProcessed Patient Number 822
#
# NoNoNoNoNoProcessed Patient Number 823
#
# No.No.NoNo.NoNoNoNoProcessed Patient Number 824
#
# NoNoNo.NoProcessed Patient Number 825
#
# No.NoNoProcessed Patient Number 826
#
# NoNoNoNoNo.Processed Patient Number 827
#
# NoNo.NoNoNoNoNo.No.Processed Patient Number 828
#
# No.No.NoNoNoProcessed Patient Number 829
#
# NoNoNoNoNo.NoProcessed Patient Number 830
#
# NoNoProcessed Patient Number 831
#
# NoNoNo.NoProcessed Patient Number 832
#
# NoNoNoProcessed Patient Number 833
#
# NoNoProcessed Patient Number 834
#
# NoNoNoNoNoNo.No.Processed Patient Number 835
#
# NoNo.NoNoNo.Processed Patient Number 836
#
# NoNo.Processed Patient Number 837
#
# NoNoNoProcessed Patient Number 838
#
# NoNo.NoProcessed Patient Number 839
#
# No.NoNoNoProcessed Patient Number 840
#
# NoNo.NoProcessed Patient Number 841
#
# NoNoProcessed Patient Number 842
#
# No.NoNoNoNoNoProcessed Patient Number 843
#
# No.Processed Patient Number 844
#
# NoNoProcessed Patient Number 845
#
# NoNoNoNoNoProcessed Patient Number 846
#
# NoNoNo.NoNoNoProcessed Patient Number 847
#
# NoNo.NoNoNo.Processed Patient Number 848
#
# No.No.NoNoNoProcessed Patient Number 849
#
# No.NoNoNoNoProcessed Patient Number 850
#
# NoNoNoProcessed Patient Number 851
#
# No.NoNoNoNoNoNo.NoNoNo.NoNoNoNoProcessed Patient Number 852
#
# No.Processed Patient Number 853
#
# NoNoNoNoProcessed Patient Number 854
#
# NoNoProcessed Patient Number 855
#
# NoNoNo.Processed Patient Number 856
#
# NoNoNoProcessed Patient Number 857
#
# NoProcessed Patient Number 858
#
# NoNoNo.NoNo.NoProcessed Patient Number 859
#
# NoNoYesNoNoNoProcessed Patient Number 860
#
# No.No.NoNoNo.Processed Patient Number 861
#
# YesNoNoNoNoProcessed Patient Number 862
#
# NoNoNoProcessed Patient Number 863
#
# NoNoNoNoNoProcessed Patient Number 864
#
# NoNoNo.Processed Patient Number 865
#
# NoNoNoNoNoNoProcessed Patient Number 866
#
# NoNo.NoProcessed Patient Number 867
#
# No.NoNoProcessed Patient Number 868
#
# YesNoNoNo.NoNoNoNoNo.Processed Patient Number 869
#
# No.No.NoProcessed Patient Number 870
#
# NoNoNo.NoNoNoNo.NoProcessed Patient Number 871
#
# NoNoProcessed Patient Number 872
#
# No.NoNoProcessed Patient Number 873
#
# No.Yes.NoProcessed Patient Number 874
#
# YesNo.Processed Patient Number 875
#
# NoNoNo.NoNoProcessed Patient Number 876
#
# NoNoNoNoNoNo.Processed Patient Number 877
#
# NoNoNo.Processed Patient Number 878
#
# No.NoNoNoNoProcessed Patient Number 879
#
# NoNo.NoProcessed Patient Number 880
#
# No.NoNo.No.No.NoNoProcessed Patient Number 881
#
# YesNo.NoNoNoProcessed Patient Number 882
#
# No.No.NoNoNoProcessed Patient Number 883
#
# NoNo.NoProcessed Patient Number 884
#
# NoNo.NoNo.NoProcessed Patient Number 885
#
# NoNoProcessed Patient Number 886
#
# No.NoNoProcessed Patient Number 887
#
# No.NoNoProcessed Patient Number 888
#
# NoNoNoNoProcessed Patient Number 889
#
# NoNoNoNoProcessed Patient Number 890
#
# NoNoNoNoNoProcessed Patient Number 891
#
# No.NoNo.Processed Patient Number 892
#
# NoNoNoNo.NoNoProcessed Patient Number 893
#
# NoNoNo.NoProcessed Patient Number 894
#
# NoNo.NoProcessed Patient Number 895
#
# NoNoNo.Processed Patient Number 896
#
# NoNoNoProcessed Patient Number 897
#
# No.NoNoNoNoNoProcessed Patient Number 898
#
# NoNoNoNoNoProcessed Patient Number 899
#
# NoNoNoNoNo.Processed Patient Number 900
#
# No.NoNoNo.No.Processed Patient Number 901
#
# No.NoNoNoNoProcessed Patient Number 902
#
# No.NoNoNo.NoNoProcessed Patient Number 903
#
# No.No.Processed Patient Number 904
#
# NoNoNoProcessed Patient Number 905
#
# NoNoNoNo.NoNo.Processed Patient Number 906
#
# No.No.No.No.NoNoProcessed Patient Number 907
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 908
#
# NoNoNoNo.NoNoProcessed Patient Number 909
#
# No.NoNoNoProcessed Patient Number 910
#
# NoNoNoNoNoNoNoProcessed Patient Number 911
#
# NoNoNoProcessed Patient Number 912
#
# NoNoNoNoProcessed Patient Number 913
#
# No.Processed Patient Number 914
#
# NoNoNo.NoNoNoNoNo.Processed Patient Number 915
#
# NoNoNoProcessed Patient Number 916
#
# No.No.Processed Patient Number 917
#
# NoNoProcessed Patient Number 918
#
# NoNoNoProcessed Patient Number 919
#
# NoNo.NoNo.NoNoProcessed Patient Number 920
#
# NoNoNoProcessed Patient Number 921
#
# NoNoNoProcessed Patient Number 922
#
# No.NoYesNoNoNoProcessed Patient Number 923
#
# NoNoProcessed Patient Number 924
#
# NoNoNoProcessed Patient Number 925
#
# NoNoNoNoProcessed Patient Number 926
#
# NoNo.NoNoProcessed Patient Number 927
#
# NoNoNo.Processed Patient Number 928
#
# NoNoNo.No.Processed Patient Number 929
#
# NoNoNoNoNo.Processed Patient Number 930
#
# No.No.No.Processed Patient Number 931
#
# NoNo.NoNo.Processed Patient Number 932
#
# NoNo.NoProcessed Patient Number 933
#
# NoNoProcessed Patient Number 934
#
# NoNoProcessed Patient Number 935
#
# No.NoNoNoNo.No.No.NoProcessed Patient Number 936
#
# NoNo.NoNoProcessed Patient Number 937
#
# No.No.NoNoNoProcessed Patient Number 938
#
# NoNo.NoNoNoProcessed Patient Number 939
#
# NoNoNoProcessed Patient Number 940
#
# NoNoNoNo.No.Processed Patient Number 941
#
# No.NoNo.NoNo.No.Processed Patient Number 942
#
# NoNoNoNoNoNo.Processed Patient Number 943
#
# No.No.NoProcessed Patient Number 944
#
# YesNo.No.NoNoNoNoNoYesNoNoProcessed Patient Number 945
#
# No.No.No.NoNoProcessed Patient Number 946
#
# NoNoNoNoNoProcessed Patient Number 947
#
# NoNoNo.NoProcessed Patient Number 948
#
# No.NoNo.NoNo.NoProcessed Patient Number 949
#
# NoNoNoProcessed Patient Number 950
#
# NoNo.NoNoNoProcessed Patient Number 951
#
# NoNoProcessed Patient Number 952
#
# NoNoNoNo.NoNo.No.Processed Patient Number 953
#
# No.NoNoNo.Processed Patient Number 954
#
# NoNoNoNo.Processed Patient Number 955
#
# No.No.NoNoNoNoProcessed Patient Number 956
#
# No.NoNoNo.NoNoNoNoNoNoNoNoNoNoProcessed Patient Number 957
#
# NoNo.NoNo.No.Processed Patient Number 958
#
# NoNoNoProcessed Patient Number 959
#
# No.No.NoProcessed Patient Number 960
#
# No.NoNoNoNoNo.NoProcessed Patient Number 961
#
# No.NoNo.No.Processed Patient Number 962
#
# No.YesNoNoProcessed Patient Number 963
#
# No.NoNoNoProcessed Patient Number 964
#
# NoNoNoProcessed Patient Number 965
#
# NoNoNoNoNoNoProcessed Patient Number 966
#
# NoNoNoNoNoProcessed Patient Number 967
#
# NoNo.NoProcessed Patient Number 968
#
# NoNoNo.Processed Patient Number 969
#
# No.NoNo.NoProcessed Patient Number 970
#
# NoNoNoNoNoNoProcessed Patient Number 971
#
# No.NoNoNoNo.Processed Patient Number 972
#
# No.No.NoNoNoNo.NoProcessed Patient Number 973
#
# NoNo.NoNoNoProcessed Patient Number 974
#
# No.NoNo.NoNoProcessed Patient Number 975
#
# NoNoNoProcessed Patient Number 976
#
# NoNo.NoProcessed Patient Number 977
#
# No.No.NoProcessed Patient Number 978
#
# NoNoNoNoNoProcessed Patient Number 979
#
# NoNoNoNoNoNo.Processed Patient Number 980
#
# NoNoNoNoNoProcessed Patient Number 981
#
# No.NoNoNoNoNoProcessed Patient Number 982
#
# No.No.No.Processed Patient Number 983
#
# NoNoNoNoProcessed Patient Number 984
#
# NoNo.NoNoNoProcessed Patient Number 985
#
# NoNoNoNoProcessed Patient Number 986
#
# No.NoNoNoProcessed Patient Number 987
#
# NoNoNoNoProcessed Patient Number 988
#
# NoNo.No.NoProcessed Patient Number 989
#
# YesNoProcessed Patient Number 990
#
# NoNoNoProcessed Patient Number 991
#
# No.No.NoNoProcessed Patient Number 992
#
# NoNo.NoNoNoNoNo.Processed Patient Number 993
#
# No.NoNoProcessed Patient Number 994
#
# No.YesYesNo.NoNoProcessed Patient Number 995
#
# NoNoNo.Processed Patient Number 996
#
# NoProcessed Patient Number 997
#
# No.NoNoNoProcessed Patient Number 998
#
# NoNo.No.Processed Patient Number 999
#
# NoNoNoProcessed Patient Number 1000
#
# NoNoNoProcessed Patient Number 1001
#
# NoNoNoNo.NoNoProcessed Patient Number 1002
#
# No.Processed Patient Number 1003
#
# NoNoNoNoProcessed Patient Number 1004
#
# NoNoNoNoNoProcessed Patient Number 1005
#
# NoNoNo.NoProcessed Patient Number 1006
#
# NoNoNoNo.NoNoNoNoNoNoNoNo.Processed Patient Number 1007
#
# NoNo.NoNo.NoProcessed Patient Number 1008
#
# NoNoNo.NoProcessed Patient Number 1009
#
# No.NoNoNo.Processed Patient Number 1010
#
# NoNoNoNoNo.No.Processed Patient Number 1011
#
# NoNoNoNoNoNo.Processed Patient Number 1012
#
# NoNoNoNoNo.NoProcessed Patient Number 1013
#
# NoNoNoNoProcessed Patient Number 1014
#
# No.NoNoProcessed Patient Number 1015
#
# NoNo.No.No.NoNoNoNoProcessed Patient Number 1016
#
# NoNoNoProcessed Patient Number 1017
#
# NoNoNoNoProcessed Patient Number 1018
#
# NoNo.NoNo.NoNoNoNo.Processed Patient Number 1019
#
# NoNoNoProcessed Patient Number 1020
#
# No.NoNoProcessed Patient Number 1021
#
# NoNoNoNoNoProcessed Patient Number 1022
#
# NoNoNo.No.NoNoNo.Processed Patient Number 1023
#
# No.NoNoNoNoNoProcessed Patient Number 1024
#
# NoNoNoNoNoProcessed Patient Number 1025
#
# No.NoProcessed Patient Number 1026
#
# NoNoNoNoNoProcessed Patient Number 1027
#
# NoNo.NoNoNoNoProcessed Patient Number 1028
#
# No.NoProcessed Patient Number 1029
#
# NoNo.NoProcessed Patient Number 1030
#
# NoNoNo.NoProcessed Patient Number 1031
#
# NoNoNoNoProcessed Patient Number 1032
#
# NoNo.NoNoNoNoProcessed Patient Number 1033
#
# No.No.No.NoNoNoNo.NoProcessed Patient Number 1034
#
# NoNoYesProcessed Patient Number 1035
#
# NoNo.No.NoNoNoNoProcessed Patient Number 1036
#
# NoNo.NoNoProcessed Patient Number 1037
#
# NoNoNoNoNoNo.No.Processed Patient Number 1038
#
# NoNoYesNoProcessed Patient Number 1039
#
# No.NoProcessed Patient Number 1040
#
# No.NoNoNoNoProcessed Patient Number 1041
#
# No.NoNoProcessed Patient Number 1042
#
# NoNoNoNoNoNoProcessed Patient Number 1043
#
# NoNo.Processed Patient Number 1044
#
# No.NoNoNoNoNoNoNoNo.NoProcessed Patient Number 1045
#
# NoNoNoNoNoNoYesNo.Processed Patient Number 1046
#
# NoNo.NoProcessed Patient Number 1047
#
# NoNoNoProcessed Patient Number 1048
#
# No.NoNoNoProcessed Patient Number 1049
#
# NoNoNoProcessed Patient Number 1050
#
# NoNoNoProcessed Patient Number 1051
#
# NoNoNoProcessed Patient Number 1052
#
# No.NoNoNoNoNo.NoProcessed Patient Number 1053
#
# No.NoNoNoProcessed Patient Number 1054
#
# NoNoNo.Processed Patient Number 1055
#
# NoNo.NoNoNo.Processed Patient Number 1056
#
# NoNoNoNoNoProcessed Patient Number 1057
#
# NoNoNoProcessed Patient Number 1058
#
# No.No.Processed Patient Number 1059
#
# NoNoNoProcessed Patient Number 1060
#
# No.NoNoNo.NoNo.NoProcessed Patient Number 1061
#
# NoNoNoNoNoProcessed Patient Number 1062
#
# NoNoNoProcessed Patient Number 1063
#
# NoNoNoNoProcessed Patient Number 1064
#
# NoNo.NoNoNo.No.Processed Patient Number 1065
#
# NoNoNoNoProcessed Patient Number 1066
#
# NoNoNoNo.NoNoNoNoProcessed Patient Number 1067
#
# No.No.YesNoProcessed Patient Number 1068
#
# NoNoNoProcessed Patient Number 1069
#
# NoNoNoNoNoProcessed Patient Number 1070
#
# NoNoNoNo.Processed Patient Number 1071
#
# NoNo.NoNoProcessed Patient Number 1072
#
# NoNo.No.NoNo.No.NoNoProcessed Patient Number 1073
#
# NoNoNoNo.NoNoProcessed Patient Number 1074
#
# NoNoProcessed Patient Number 1075
#
# No.NoNoProcessed Patient Number 1076
#
# NoNo.NoNoProcessed Patient Number 1077
#
# NoNoNoProcessed Patient Number 1078
#
# NoNoNoNoProcessed Patient Number 1079
#
# NoNo.NoNoNo.NoProcessed Patient Number 1080
#
# NoNoNoProcessed Patient Number 1081
#
# NoNo.No.Processed Patient Number 1082
#
# NoNoNoNoNoNoProcessed Patient Number 1083
#
# No.No.No.Processed Patient Number 1084
#
# NoNo.No.No.NoNoNo.No.NoNo.NoProcessed Patient Number 1085
#
# NoNoNoNoNoNoProcessed Patient Number 1086
#
# YesYesNo.Processed Patient Number 1087
#
# NoNo.NoNoProcessed Patient Number 1088
#
# NoNoProcessed Patient Number 1089
#
# NoNoNoNoNo.NoNoNoProcessed Patient Number 1090
#
# No.NoNoNoNoNoNoProcessed Patient Number 1091
#
# NoNo.NoNoNoNoNoProcessed Patient Number 1092
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 1093
#
# NoNoNoNoProcessed Patient Number 1094
#
# NoNo.NoNoNoNoNoNoProcessed Patient Number 1095
#
# NoNoProcessed Patient Number 1096
#
# NoNo.No.Processed Patient Number 1097
#
# No.NoNoNo.Processed Patient Number 1098
#
# NoNoProcessed Patient Number 1099
#
# No.NoNoProcessed Patient Number 1100
#
# NoNoNoNoNoNoNoProcessed Patient Number 1101
#
# NoNoNoNoProcessed Patient Number 1102
#
# NoNoNoNoNoNoNo.NoProcessed Patient Number 1103
#
# NoNoNoProcessed Patient Number 1104
#
# NoNoNoNo.Processed Patient Number 1105
#
# NoNoNoNoNoProcessed Patient Number 1106
#
# NoNoNoProcessed Patient Number 1107
#
# No.No.NoNoProcessed Patient Number 1108
#
# No.No.NoNoNoNoNoNoNoProcessed Patient Number 1109
#
# NoNoNoNoNoProcessed Patient Number 1110
#
# NoNoNoProcessed Patient Number 1111
#
# NoNoNoProcessed Patient Number 1112
#
# NoNoProcessed Patient Number 1113
#
# NoNoNoNoNoProcessed Patient Number 1114
#
# No.NoNoProcessed Patient Number 1115
#
# NoNoNo.NoProcessed Patient Number 1116
#
# NoNoNoProcessed Patient Number 1117
#
# NoNoNoNoProcessed Patient Number 1118
#
# NoNoNoProcessed Patient Number 1119
#
# NoNo.Processed Patient Number 1120
#
# No.NoProcessed Patient Number 1121
#
# NoNoNo.NoNoNoNoNo.NoNoNoProcessed Patient Number 1122
#
# NoYesNoNoNoProcessed Patient Number 1123
#
# NoNoNoNoProcessed Patient Number 1124
#
# NoNo.NoNo.NoNoProcessed Patient Number 1125
#
# NoNoNoNoProcessed Patient Number 1126
#
# NoNoNoNoNo.Processed Patient Number 1127
#
# NoNoNoNoProcessed Patient Number 1128
#
# No.NoNoNoNoProcessed Patient Number 1129
#
# No.NoNoProcessed Patient Number 1130
#
# No.NoNo.Processed Patient Number 1131
#
# NoNoNoNoProcessed Patient Number 1132
#
# No.NoProcessed Patient Number 1133
#
# NoNoNoNoProcessed Patient Number 1134
#
# No.NoNoNo.Processed Patient Number 1135
#
# NoNoNoProcessed Patient Number 1136
#
# No.NoNoNoProcessed Patient Number 1137
#
# NoNoNoNoNoProcessed Patient Number 1138
#
# NoNoNoProcessed Patient Number 1139
#
# NoNo.No.NoProcessed Patient Number 1140
#
# NoNoNoNo.NoNoProcessed Patient Number 1141
#
# NoNoNo.Processed Patient Number 1142
#
# NoNo.Processed Patient Number 1143
#
# NoNoNoNoProcessed Patient Number 1144
#
# NoNoNoNo.Processed Patient Number 1145
#
# NoNoNoNoNoNoProcessed Patient Number 1146
#
# NoNoNoNoNoNo.No.Processed Patient Number 1147
#
# NoNoNoNo.Processed Patient Number 1148
#
# NoNoNo.Processed Patient Number 1149
#
# No.No.NoNoProcessed Patient Number 1150
#
# NoNoNo.Processed Patient Number 1151
#
# NoNo.NoNo.Processed Patient Number 1152
#
# No.NoNo.No.Processed Patient Number 1153
#
# NoNo.No.No.NoNo.NoNoProcessed Patient Number 1154
#
# No.No.No.NoNoProcessed Patient Number 1155
#
# NoNoNoNo.NoProcessed Patient Number 1156
#
# No.NoProcessed Patient Number 1157
#
# YesNoNoNoNoNo.NoProcessed Patient Number 1158
#
# No.NoNo.Processed Patient Number 1159
#
# NoYesNoNoNoProcessed Patient Number 1160
#
# NoNoNoNoNoProcessed Patient Number 1161
#
# No.YesNoNoNoNoNo.Processed Patient Number 1162
#
# NoNoNoNoProcessed Patient Number 1163
#
# No.NoNoNoProcessed Patient Number 1164
#
# NoNoNo.No.Processed Patient Number 1165
#
# NoNoNoNoProcessed Patient Number 1166
#
# No.NoNo.NoProcessed Patient Number 1167
#
# NoNo.NoNo.Processed Patient Number 1168
#
# NoNoNoNoNoNoProcessed Patient Number 1169
#
# No.NoNoProcessed Patient Number 1170
#
# No.NoNoProcessed Patient Number 1171
#
# NoNo.No.NoProcessed Patient Number 1172
#
# NoNoNoNoNoProcessed Patient Number 1173
#
# No.NoProcessed Patient Number 1174
#
# NoNo.NoNoProcessed Patient Number 1175
#
# NoNo.NoNoNoNoNoNoNoNoNoNoNo.Processed Patient Number 1176
#
# NoNo.NoProcessed Patient Number 1177
#
# NoNo.NoNo.Processed Patient Number 1178
#
# No.No.NoProcessed Patient Number 1179
#
# NoNoNoNoNoNoProcessed Patient Number 1180
#
# NoNoNoProcessed Patient Number 1181
#
# NoNoNoNoNo.NoNoNoProcessed Patient Number 1182
#
# NoNo.Processed Patient Number 1183
#
# No.No.NoNoNoNoProcessed Patient Number 1184
#
# No.NoNoNoNoNoNoProcessed Patient Number 1185
#
# No.No.NoNo.Processed Patient Number 1186
#
# NoNo.NoNoNoProcessed Patient Number 1187
#
# NoNoNo.NoNoNoProcessed Patient Number 1188
#
# NoNoNoProcessed Patient Number 1189
#
# NoNoNoProcessed Patient Number 1190
#
# NoNoNo.NoNoProcessed Patient Number 1191
#
# No.NoNoNoProcessed Patient Number 1192
#
# No.NoNoNo.Processed Patient Number 1193
#
# NoNoNoNo.No.No.Processed Patient Number 1194
#
# NoNoNoNo.Processed Patient Number 1195
#
# NoNo.No.No.NoNo.NoNo.NoNoProcessed Patient Number 1196
#
# NoNo.NoNoNoNoProcessed Patient Number 1197
#
# NoNoNo.NoProcessed Patient Number 1198
#
# NoNo.Processed Patient Number 1199
#
# No.NoNoNoNoNoProcessed Patient Number 1200
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1201
#
# NoNoNoNoNoNoProcessed Patient Number 1202
#
# No.NoNo.No.No.Processed Patient Number 1203
#
# No.NoNoNoNoNoProcessed Patient Number 1204
#
# NoNoNoNoProcessed Patient Number 1205
#
# NoNo.NoNoNoProcessed Patient Number 1206
#
# No.No.No.NoNoProcessed Patient Number 1207
#
# NoNo.NoNoProcessed Patient Number 1208
#
# No.NoNoNoNoProcessed Patient Number 1209
#
# NoNo.NoNoNoNoProcessed Patient Number 1210
#
# NoNoNoProcessed Patient Number 1211
#
# NoNoNoProcessed Patient Number 1212
#
# NoNoNo.NoNoNoNoNoProcessed Patient Number 1213
#
# NoNoNo.NoProcessed Patient Number 1214
#
# NoNoNoNoNoProcessed Patient Number 1215
#
# NoNoNo.NoNoNoProcessed Patient Number 1216
#
# NoNoNo.No.NoProcessed Patient Number 1217
#
# NoNoNoProcessed Patient Number 1218
#
# NoNoNoProcessed Patient Number 1219
#
# NoNoNoNo.Processed Patient Number 1220
#
# No.NoNoNoNo.Processed Patient Number 1221
#
# NoNoNoProcessed Patient Number 1222
#
# YesNoNoNoProcessed Patient Number 1223
#
# No.NoNoNoProcessed Patient Number 1224
#
# No.No.NoNoProcessed Patient Number 1225
#
# NoNoNoNoProcessed Patient Number 1226
#
# No.No.No.NoProcessed Patient Number 1227
#
# NoNo.NoNoNoNo.NoNoNoNo.Processed Patient Number 1228
#
# NoNoNoNoNoProcessed Patient Number 1229
#
# No.NoNoProcessed Patient Number 1230
#
# NoNoNo.Processed Patient Number 1231
#
# No.No.No.NoNoProcessed Patient Number 1232
#
# No.NoNo.NoProcessed Patient Number 1233
#
# NoNoNoNoNoNo.No.Processed Patient Number 1234
#
# NoNoNo.NoProcessed Patient Number 1235
#
# NoNoNoNoNo.Processed Patient Number 1236
#
# NoNo.NoNoNoProcessed Patient Number 1237
#
# NoNoNoNoNo.Processed Patient Number 1238
#
# No.NoNoProcessed Patient Number 1239
#
# NoNoNoNoProcessed Patient Number 1240
#
# No.NoNoNoNoProcessed Patient Number 1241
#
# NoNoNoNoProcessed Patient Number 1242
#
# NoNoNoNoNo.Processed Patient Number 1243
#
# NoNoNoNoNo.NoNoProcessed Patient Number 1244
#
# NoNoProcessed Patient Number 1245
#
# NoNoNoProcessed Patient Number 1246
#
# NoNoProcessed Patient Number 1247
#
# NoNoNoNoNoNoProcessed Patient Number 1248
#
# NoNoNoNo.Processed Patient Number 1249
#
# No.NoNoNoNoNoProcessed Patient Number 1250
#
# NoNoNoProcessed Patient Number 1251
#
# No.NoNo.NoNoNoNoNoNoProcessed Patient Number 1252
#
# No.NoNoNo.NoProcessed Patient Number 1253
#
# No.No.No.NoNoNo.NoProcessed Patient Number 1254
#
# No.NoProcessed Patient Number 1255
#
# No.NoProcessed Patient Number 1256
#
# NoNoNo.NoProcessed Patient Number 1257
#
# No.NoNoNoProcessed Patient Number 1258
#
# No.NoNoNoNoNoProcessed Patient Number 1259
#
# No.NoNoProcessed Patient Number 1260
#
# NoYes.NoNoNoNoNoProcessed Patient Number 1261
#
# No.NoNo.NoProcessed Patient Number 1262
#
# No.NoNoNoNoNoProcessed Patient Number 1263
#
# No.No.NoNoProcessed Patient Number 1264
#
# NoNoNoNoNoProcessed Patient Number 1265
#
# NoNo.NoProcessed Patient Number 1266
#
# NoNoNoNo.Processed Patient Number 1267
#
# No.NoNoNoProcessed Patient Number 1268
#
# NoNoNoNoProcessed Patient Number 1269
#
# NoNoNo.NoNoNoNoNoProcessed Patient Number 1270
#
# NoNoNoProcessed Patient Number 1271
#
# No.NoNoNoProcessed Patient Number 1272
#
# NoNo.No.NoNoProcessed Patient Number 1273
#
# NoNoNoNoNo.Processed Patient Number 1274
#
# NoNoNoProcessed Patient Number 1275
#
# NoNoProcessed Patient Number 1276
#
# NoNoNoNo.NoProcessed Patient Number 1277
#
# NoNo.NoNoNoNoNo.Processed Patient Number 1278
#
# NoNo.NoNoNoNoProcessed Patient Number 1279
#
# NoNoNoNo.Processed Patient Number 1280
#
# No.NoProcessed Patient Number 1281
#
# NoNoNo.Processed Patient Number 1282
#
# NoNoNo.NoProcessed Patient Number 1283
#
# NoNoNoProcessed Patient Number 1284
#
# NoNoNoProcessed Patient Number 1285
#
# NoNoNoNoNoProcessed Patient Number 1286
#
# NoNoProcessed Patient Number 1287
#
# No.NoNo.Processed Patient Number 1288
#
# No.NoNo.Processed Patient Number 1289
#
# NoNoNo.NoNoNoProcessed Patient Number 1290
#
# No.NoNoNoNoProcessed Patient Number 1291
#
# NoNoNo.NoNoProcessed Patient Number 1292
#
# No.NoNoNoNoNoNoProcessed Patient Number 1293
#
# No.No.NoNoNoProcessed Patient Number 1294
#
# NoNoNoProcessed Patient Number 1295
#
# No.NoNo.NoProcessed Patient Number 1296
#
# NoNoNo.Processed Patient Number 1297
#
# NoNo.No.No.Processed Patient Number 1298
#
# No.NoNoNo.NoProcessed Patient Number 1299
#
# No.NoNoNoNo.NoNoNoNoProcessed Patient Number 1300
#
# No.NoNoNoNoProcessed Patient Number 1301
#
# No.NoNoNoNo.Processed Patient Number 1302
#
# NoNoNoNoNoNoProcessed Patient Number 1303
#
# NoNoNoNoProcessed Patient Number 1304
#
# NoNoNoNoProcessed Patient Number 1305
#
# NoNoNoNoNoProcessed Patient Number 1306
#
# NoNoNoNoNo.Processed Patient Number 1307
#
# NoNoNoNoNoNoNoNoNoNoProcessed Patient Number 1308
#
# NoNoNoNoProcessed Patient Number 1309
#
# No.NoNo.NoNoNo.Processed Patient Number 1310
#
# NoNoNo.Processed Patient Number 1311
#
# NoNoProcessed Patient Number 1312
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 1313
#
# NoNo.NoNoProcessed Patient Number 1314
#
# NoNo.NoNoProcessed Patient Number 1315
#
# No.NoNo.No.Processed Patient Number 1316
#
# NoNo.Processed Patient Number 1317
#
# NoNo.NoNoNoNo.No.Processed Patient Number 1318
#
# No.No.NoNoNoProcessed Patient Number 1319
#
# NoNoNoNo.NoNoProcessed Patient Number 1320
#
# NoBased on the provided clinical text chunks, I can answer your query as follows:
#
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * No
# * NoNo.NoNoNoProcessed Patient Number 1321
#
# NoNo.NoNoNoProcessed Patient Number 1322
#
# NoNoNoProcessed Patient Number 1323
#
# No.NoNoNoProcessed Patient Number 1324
#
# NoNo.NoNo.NoNoNoNoProcessed Patient Number 1325
#
# NoNoNoProcessed Patient Number 1326
#
# NoNoNoNoNoProcessed Patient Number 1327
#
# No.NoNo.Processed Patient Number 1328
#
# No.NoNo.NoNoProcessed Patient Number 1329
#
# No.No.No.NoNoNoProcessed Patient Number 1330
#
# NoNo.No.NoProcessed Patient Number 1331
#
# No.NoNoNoNo.No.Processed Patient Number 1332
#
# No.No.No.NoNoProcessed Patient Number 1333
#
# NoNoNoNoNo.Processed Patient Number 1334
#
# No.NoNoNoProcessed Patient Number 1335
#
# No.NoNo.Processed Patient Number 1336
#
# No.No.NoNoProcessed Patient Number 1337
#
# No.NoNoNoProcessed Patient Number 1338
#
# No.NoNoNoNoNoNoNoNoNoNoNoProcessed Patient Number 1339
#
# NoNoNoNoProcessed Patient Number 1340
#
# NoNoNoNoNoProcessed Patient Number 1341
#
# NoNoNo.NoProcessed Patient Number 1342
#
# NoNoNoNoProcessed Patient Number 1343
#
# NoNoNoNo.Processed Patient Number 1344
#
# NoNoNoNo.NoProcessed Patient Number 1345
#
# NoNoNo.NoProcessed Patient Number 1346
#
# YesNoNoNo.NoProcessed Patient Number 1347
#
# NoNo.NoNoProcessed Patient Number 1348
#
# No.No.NoNo.NoProcessed Patient Number 1349
#
# No.NoNoNo.Processed Patient Number 1350
#
# NoNoNoProcessed Patient Number 1351
#
# NoNoNoNo.NoNo.NoNoProcessed Patient Number 1352
#
# NoNoYesNo.NoNoNoProcessed Patient Number 1353
#
# NoNoNoProcessed Patient Number 1354
#
# NoNoNoProcessed Patient Number 1355
#
# NoNoNoProcessed Patient Number 1356
#
# No.NoNoProcessed Patient Number 1357
#
# NoNo.NoNo.NoProcessed Patient Number 1358
#
# NoNoProcessed Patient Number 1359
#
# No.NoNoNoProcessed Patient Number 1360
#
# NoNoNoNo.NoProcessed Patient Number 1361
#
# No.NoNoNoProcessed Patient Number 1362
#
# No.YesProcessed Patient Number 1363
#
# NoNoNoNoNo.Processed Patient Number 1364
#
# NoNoNoNo.Processed Patient Number 1365
#
# NoNoNoProcessed Patient Number 1366
#
# NoNoNo.No.Processed Patient Number 1367
#
# NoNo.NoNo.NoNo.NoNoProcessed Patient Number 1368
#
# NoNoNoNo.NoNoProcessed Patient Number 1369
#
# NoNoNoNo.YesProcessed Patient Number 1370
#
# No.No.NoProcessed Patient Number 1371
#
# NoNoNo.NoProcessed Patient Number 1372
#
# NoNoNo.No.Processed Patient Number 1373
#
# NoNo.No.Processed Patient Number 1374
#
# NoNoNoNoNoProcessed Patient Number 1375
#
# NoNoNoNo.NoNo.NoProcessed Patient Number 1376
#
# NoNo.NoNoProcessed Patient Number 1377
#
# ...
#
# NoNoNoNoNoProcessed Patient Number 1629
#
# No.NoNoNo.NoProcessed Patient Number 1630
#
# NoNoNoNoNoProcessed Patient Number 1631
#
# NoNoNo.NoProcessed Patient Number 1632
#
# NoNoNoProcessed Patient Number 1633
#
# NoNoNoProcessed Patient Number 1634
#
# No.NoNoNo.No.Processed Patient Number 1635
#
# No.NoNoNoProcessed Patient Number 1636
#
# No.NoNoNoProcessed Patient Number 1637
#
# NoNo.Processed Patient Number 1638
#
# NoNo.NoProcessed Patient Number 1639
#
# NoNoNo.NoProcessed Patient Number 1640
#
# NoNo.Processed Patient Number 1641
#
# NoNoNoNoProcessed Patient Number 1642
#
# No.NoNo.NoProcessed Patient Number 1643
#
# No.NoNoNo.No.NoProcessed Patient Number 1644
#
# No.NoProcessed Patient Number 1645
#
# NoNo.NoNoProcessed Patient Number 1646
#
# NoNo.NoNo.Processed Patient Number 1647
#
# No.NoNoNoProcessed Patient Number 1648
#
# NoNoNoProcessed Patient Number 1649
#
# NoNoNoNoNoProcessed Patient Number 1650
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1651
#
# YesNoNoNo.Processed Patient Number 1652
#
# NoNoNoNoNoProcessed Patient Number 1653
#
# NoNoProcessed Patient Number 1654
#
# No.NoNoNoNoNoNoProcessed Patient Number 1655
#
# NoNoNoNoProcessed Patient Number 1656
#
# NoNoNoNo.NoProcessed Patient Number 1657
#
# No.NoNo.NoNo.NoNoProcessed Patient Number 1658
#
# NoNoNoNoNoNoProcessed Patient Number 1659
#
# No.NoNoProcessed Patient Number 1660
#
# No.NoNoNoProcessed Patient Number 1661
#
# NoNoProcessed Patient Number 1662
#
# No.NoNo.NoNoNoNoNo.Processed Patient Number 1663
#
# No.NoNoProcessed Patient Number 1664
#
# NoNoNoProcessed Patient Number 1665
#
# NoNoNoNoNoProcessed Patient Number 1666
#
# No.NoNoNoNoNoNoProcessed Patient Number 1667
#
# No.NoNo.Processed Patient Number 1668
#
# NoNo.NoProcessed Patient Number 1669
#
# No.NoNoNoProcessed Patient Number 1670
#
# No.No.NoNoProcessed Patient Number 1671
#
# NoNoNoNo.NoProcessed Patient Number 1672
#
# YesNoNoNoNoNoNo.NoProcessed Patient Number 1673
#
# NoNoNoProcessed Patient Number 1674
#
# No.NoNoNoProcessed Patient Number 1675
#
# NoNoNoNoProcessed Patient Number 1676
#
# NoNoNoNoProcessed Patient Number 1677
#
# NoNoNoNoYes.Processed Patient Number 1678
#
# No.No.Processed Patient Number 1679
#
# NoNo.NoNoProcessed Patient Number 1680
#
# No.NoNoNo.Processed Patient Number 1681
#
# No.NoNo.No.Processed Patient Number 1682
#
# NoNoNo.NoProcessed Patient Number 1683
#
# No.No.No.NoProcessed Patient Number 1684
#
# NoNoNoNo.NoNo.No.Processed Patient Number 1685
#
# NoNoNoNoNoProcessed Patient Number 1686
#
# No.NoNoNo.NoNoNoNoProcessed Patient Number 1687
#
# NoNoProcessed Patient Number 1688
#
# NoNoNoNoProcessed Patient Number 1689
#
# NoNoNoNoNoProcessed Patient Number 1690
#
# No.NoNoNoProcessed Patient Number 1691
#
# NoNo.No.NoNoNoNoProcessed Patient Number 1692
#
# No.NoNoNo.Processed Patient Number 1693
#
# NoNoNo.Processed Patient Number 1694
#
# No.NoNoProcessed Patient Number 1695
#
# NoNoProcessed Patient Number 1696
#
# No.NoNoProcessed Patient Number 1697
#
# NoNoNoProcessed Patient Number 1698
#
# NoNoProcessed Patient Number 1699
#
# NoNoNoNo.Processed Patient Number 1700
#
# No.No.NoProcessed Patient Number 1701
#
# YesNoNoProcessed Patient Number 1702
#
# NoNoNoNoNoNoProcessed Patient Number 1703
#
# NoNo.NoProcessed Patient Number 1704
#
# NoNoNoNoNoProcessed Patient Number 1705
#
# NoNoNo.Processed Patient Number 1706
#
# NoNoNo.No.NoNoProcessed Patient Number 1707
#
# No.NoNoYesNoNo.Processed Patient Number 1708
#
# No.NoNo.NoProcessed Patient Number 1709
#
# NoNoNoNo.Processed Patient Number 1710
#
# NoNoNoNoProcessed Patient Number 1711
#
# NoNoNoNo.Processed Patient Number 1712
#
# NoNoNoNoProcessed Patient Number 1713
#
# NoNoProcessed Patient Number 1714
#
# NoNoNo.No.Processed Patient Number 1715
#
# No.No.NoNoNoProcessed Patient Number 1716
#
# NoNoNoNoProcessed Patient Number 1717
#
# NoNoProcessed Patient Number 1718
#
# NoNoProcessed Patient Number 1719
#
# NoNoNoNo.Processed Patient Number 1720
#
# NoNoProcessed Patient Number 1721
#
# NoNoNoNoNoNo.Processed Patient Number 1722
#
# No.No.NoNo.NoNoProcessed Patient Number 1723
#
# NoNoNoNo.Processed Patient Number 1724
#
# No.NoNoNoProcessed Patient Number 1725
#
# No.NoNoNo.Processed Patient Number 1726
#
# YesNoNoNoProcessed Patient Number 1727
#
# No.NoNoNoNo.Processed Patient Number 1728
#
# NoNoNoNoProcessed Patient Number 1729
#
# No.NoNoNoNoProcessed Patient Number 1730
#
# NoNoNoNoProcessed Patient Number 1731
#
# NoNoNoNoNoNoProcessed Patient Number 1732
#
# NoNoNoNoProcessed Patient Number 1733
#
# NoNoProcessed Patient Number 1734
#
# NoNoNoNoProcessed Patient Number 1735
#
# NoNoNoProcessed Patient Number 1736
#
# NoNoNoNoProcessed Patient Number 1737
#
# No.NoNoProcessed Patient Number 1738
#
# No.NoNo.No.NoNoNoProcessed Patient Number 1739
#
# No.NoNoProcessed Patient Number 1740
#
# YesYes.No.No.Processed Patient Number 1741
#
# NoNo.No.Processed Patient Number 1742
#
# No.Processed Patient Number 1743
#
# NoNoProcessed Patient Number 1744
#
# NoNoNo.NoProcessed Patient Number 1745
#
# NoNo.Processed Patient Number 1746
#
# NoNo.NoProcessed Patient Number 1747
#
# YesNoNoNoNo.NoProcessed Patient Number 1748
#
# NoNoNoNoProcessed Patient Number 1749
#
# NoNoProcessed Patient Number 1750
#
# NoNoNoProcessed Patient Number 1751
#
# NoNoNo.No.NoNoProcessed Patient Number 1752
#
# No.NoNoProcessed Patient Number 1753
#
# No.No.NoNoNoNo.Processed Patient Number 1754
#
# No.No.NoNoNoProcessed Patient Number 1755
#
# NoNoNoNoNoNo.Processed Patient Number 1756
#
# No.No.NoNo.NoNo.No.NoNoNo.NoNoProcessed Patient Number 1757
#
# NoNoNo.YesNo.Processed Patient Number 1758
#
# NoNoNoNo.NoProcessed Patient Number 1759
#
# NoNo.Processed Patient Number 1760
#
# No.NoNo.Processed Patient Number 1761
#
# NoNoNoNoNoNo.Processed Patient Number 1762
#
# No.NoNoProcessed Patient Number 1763
#
# No.NoProcessed Patient Number 1764
#
# NoNo.NoNoNoNo.Processed Patient Number 1765
#
# No.NoNoNoProcessed Patient Number 1766
#
# No.NoProcessed Patient Number 1767
#
# NoNoNo.NoProcessed Patient Number 1768
#
# No.NoNoNoNo.Processed Patient Number 1769
#
# NoNo.NoNo.NoNoNoProcessed Patient Number 1770
#
# No.NoNo.NoNoProcessed Patient Number 1771
#
# NoNo.NoNoProcessed Patient Number 1772
#
# NoNo.NoNoProcessed Patient Number 1773
#
# NoNo.NoNoProcessed Patient Number 1774
#
# NoNoNo.NoNoNo.Processed Patient Number 1775
#
# No.No.NoNoProcessed Patient Number 1776
#
# NoNo.NoProcessed Patient Number 1777
#
# NoNo.Processed Patient Number 1778
#
# NoNoNoNoNo.NoProcessed Patient Number 1779
#
# NoNoNo.NoProcessed Patient Number 1780
#
# NoNoNoProcessed Patient Number 1781
#
# NoNo.NoNoNoProcessed Patient Number 1782
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 1783
#
# NoNoNoNoNoNoProcessed Patient Number 1784
#
# NoNoNoProcessed Patient Number 1785
#
# NoNoNoNo.No.No.Processed Patient Number 1786
#
# NoNoNoNoNoProcessed Patient Number 1787
#
# NoNoNoNoProcessed Patient Number 1788
#
# No.No.NoProcessed Patient Number 1789
#
# NoNoNo.No.NoNoNoNo.Processed Patient Number 1790
#
# No.NoNoNoProcessed Patient Number 1791
#
# NoNo.NoProcessed Patient Number 1792
#
# NoNoNo.NoNoProcessed Patient Number 1793
#
# YesNo.NoProcessed Patient Number 1794
#
# Yes.Processed Patient Number 1795
#
# NoNoNoNoNoProcessed Patient Number 1796
#
# NoNoNo.Processed Patient Number 1797
#
# NoNoNoNoProcessed Patient Number 1798
#
# No.NoNoNo.Processed Patient Number 1799
#
# No.NoNo.NoNo.No.Processed Patient Number 1800
#
# NoNoNo.No.NoNoNoNoNoProcessed Patient Number 1801
#
# NoNoNoProcessed Patient Number 1802
#
# NoNoNo.NoNoNoNoProcessed Patient Number 1803
#
# NoNoNoProcessed Patient Number 1804
#
# NoNoNo.NoProcessed Patient Number 1805
#
# NoNoNoNoProcessed Patient Number 1806
#
# NoNo.NoNoNo.Processed Patient Number 1807
#
# YesNoNoProcessed Patient Number 1808
#
# No.NoProcessed Patient Number 1809
#
# NoNoProcessed Patient Number 1810
#
# NoNoNoProcessed Patient Number 1811
#
# NoNoNo.NoProcessed Patient Number 1812
#
# YesNoNoProcessed Patient Number 1813
#
# NoNo.Processed Patient Number 1814
#
# No.NoNoNoNoNoProcessed Patient Number 1815
#
# No.NoNo.NoNoProcessed Patient Number 1816
#
# No.No.Processed Patient Number 1817
#
# No.NoNoNoNoNo.NoNoNoProcessed Patient Number 1818
#
# NoNoNoProcessed Patient Number 1819
#
# NoNoNoProcessed Patient Number 1820
#
# No.NoNoNoNoProcessed Patient Number 1821
#
# NoNoNoNoNoNoProcessed Patient Number 1822
#
# NoNoNoNoProcessed Patient Number 1823
#
# No.No.NoProcessed Patient Number 1824
#
# NoNoNo.Processed Patient Number 1825
#
# No.NoProcessed Patient Number 1826
#
# No.NoNoNoNoProcessed Patient Number 1827
#
# NoNoNoNoProcessed Patient Number 1828
#
# No.NoNo.NoProcessed Patient Number 1829
#
# No.No.NoNoNoNo.Processed Patient Number 1830
#
# NoNo.NoNoNoNoProcessed Patient Number 1831
#
# NoNoNoProcessed Patient Number 1832
#
# NoNoNo.Processed Patient Number 1833
#
# NoNo.Processed Patient Number 1834
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 1835
#
# NoNoNoProcessed Patient Number 1836
#
# No.NoNoProcessed Patient Number 1837
#
# No.NoNoProcessed Patient Number 1838
#
# No.NoNoNoNo.NoProcessed Patient Number 1839
#
# NoNoProcessed Patient Number 1840
#
# NoNoNoNoNo.Processed Patient Number 1841
#
# No.NoNo.NoProcessed Patient Number 1842
#
# NoNoNoNo.No.No.Processed Patient Number 1843
#
# No.NoNoNoNoNoNoNo.NoProcessed Patient Number 1844
#
# NoNoNoNoNoNoProcessed Patient Number 1845
#
# No.No.NoNoProcessed Patient Number 1846
#
# NoNoNoNo.Processed Patient Number 1847
#
# No.NoYesNoProcessed Patient Number 1848
#
# NoNoNoNoProcessed Patient Number 1849
#
# NoNoNoNoNoProcessed Patient Number 1850
#
# NoNoNoProcessed Patient Number 1851
#
# NoNoNoNoNo.Processed Patient Number 1852
#
# NoNo.NoNoNoNoProcessed Patient Number 1853
#
# No.No.NoNo.NoNoProcessed Patient Number 1854
#
# NoNoNoNo.No.Processed Patient Number 1855
#
# NoNoNoNoNoProcessed Patient Number 1856
#
# NoNoNo.NoNoProcessed Patient Number 1857
#
# No.No.No.No.Processed Patient Number 1858
#
# NoNoNoNoNo.Processed Patient Number 1859
#
# NoNoNoNoNo.Processed Patient Number 1860
#
# NoNoNoProcessed Patient Number 1861
#
# NoNoNoNoNoProcessed Patient Number 1862
#
# No.No. There is no mention of TRALI in this chunk of text.NoNoNoNoNoProcessed Patient Number 1863
#
# No.NoNoProcessed Patient Number 1864
#
# No.No.NoNoNoNo.Processed Patient Number 1865
#
# NoNoNoNoNoProcessed Patient Number 1866
#
# No.NoNoNo.No.Processed Patient Number 1867
#
# NoNoNoProcessed Patient Number 1868
#
# NoNoNoNoNoProcessed Patient Number 1869
#
# No.NoNoNoProcessed Patient Number 1870
#
# No.No.NoProcessed Patient Number 1871
#
# NoNoNoProcessed Patient Number 1872
#
# NoNoNo.No.Processed Patient Number 1873
#
# NoNoNoProcessed Patient Number 1874
#
# No.NoNoNoProcessed Patient Number 1875
#
# NoNoNoNoNoProcessed Patient Number 1876
#
# NoNoNo.Processed Patient Number 1877
#
# NoNoNoProcessed Patient Number 1878
#
# No.NoNoNoProcessed Patient Number 1879
#
# No.No.NoNo.No.NoProcessed Patient Number 1880
#
# NoNoNoNoNoProcessed Patient Number 1881
#
# NoNo.NoNoProcessed Patient Number 1882
#
# No.No.NoNo.No.Processed Patient Number 1883
#
# NoNoNoNoNo.NoNo.Processed Patient Number 1884
#
# NoNoNoYes.NoProcessed Patient Number 1885
#
# No.NoNoProcessed Patient Number 1886
#
# No.NoNo.NoProcessed Patient Number 1887
#
# No.NoNoNoNoProcessed Patient Number 1888
#
# NoNoNoNoNo.Processed Patient Number 1889
#
# NoNoNoNo.Processed Patient Number 1890
#
# NoNoProcessed Patient Number 1891
#
# NoProcessed Patient Number 1892
#
# No.NoNoNo.NoProcessed Patient Number 1893
#
# NoNoYesYesProcessed Patient Number 1894
#
# NoNoNoNoProcessed Patient Number 1895
#
# NoNoNoNo.YesProcessed Patient Number 1896
#
# NoNo.Processed Patient Number 1897
#
# NoNoNoNoProcessed Patient Number 1898
#
# NoNoNoNoNoProcessed Patient Number 1899
#
# No.No.No.NoNoProcessed Patient Number 1900
#
# NoNoNoNoNoNo.No.Processed Patient Number 1901
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 1902
#
# NoNoNoNoNoNoNoProcessed Patient Number 1903
#
# NoNoNoProcessed Patient Number 1904
#
# NoNo.Processed Patient Number 1905
#
# No.NoNoNoNo.NoNoNoProcessed Patient Number 1906
#
# YesYesYes.Processed Patient Number 1907
#
# No.NoNoNoProcessed Patient Number 1908
#
# NoNoNoProcessed Patient Number 1909
#
# NoNo.NoNoNo.NoProcessed Patient Number 1910
#
# NoNoNoNoProcessed Patient Number 1911
#
# NoNoNoNoNoNoProcessed Patient Number 1912
#
# NoNo.NoNoProcessed Patient Number 1913
#
# NoNoNo.NoNoNoNoNoProcessed Patient Number 1914
#
# NoNoNoNoNoProcessed Patient Number 1915
#
# No.Processed Patient Number 1916
#
# NoNo.NoNoNoProcessed Patient Number 1917
#
# No.No.NoProcessed Patient Number 1918
#
# NoNoProcessed Patient Number 1919
#
# No.NoNoNoNoProcessed Patient Number 1920
#
# NoNoNoNo.NoNo.Processed Patient Number 1921
#
# NoNoNoNoProcessed Patient Number 1922
#
# No.NoNoNoNo.NoNoNoNoNoNoProcessed Patient Number 1923
#
# NoNoProcessed Patient Number 1924
#
# NoNoNoProcessed Patient Number 1925
#
# Yes.No.NoNo.NoProcessed Patient Number 1926
#
# No.NoProcessed Patient Number 1927
#
# No.NoNoNoNoNo.No.Processed Patient Number 1928
#
# NoNoNoProcessed Patient Number 1929
#
# No.No.NoProcessed Patient Number 1930
#
# No.No.NoNoProcessed Patient Number 1931
#
# NoNoNoNoNo.Processed Patient Number 1932
#
# NoNo.NoNo.NoNoProcessed Patient Number 1933
#
# NoNoNoNoNoProcessed Patient Number 1934
#
# No.No.NoNoNoNoProcessed Patient Number 1935
#
# NoNo.Processed Patient Number 1936
#
# NoNoNoNoNoNoNo.Processed Patient Number 1937
#
# NoNoNoProcessed Patient Number 1938
#
# NoNoNoNoNo.Processed Patient Number 1939
#
# NoNoNoNoNoNoProcessed Patient Number 1940
#
# NoNoProcessed Patient Number 1941
#
# NoNoNo.Processed Patient Number 1942
#
# No.NoProcessed Patient Number 1943
#
# NoYes.NoNoProcessed Patient Number 1944
#
# NoNoNoNo.Processed Patient Number 1945
#
# YesNoYesYesNo.Processed Patient Number 1946
#
# NoNoNoNoNoProcessed Patient Number 1947
#
# NoNoNoProcessed Patient Number 1948
#
# NoNoProcessed Patient Number 1949
#
# NoNoNo.NoNoNoNoProcessed Patient Number 1950
#
# No.No.No.NoProcessed Patient Number 1951
#
# No.NoProcessed Patient Number 1952
#
# No.No.NoNo.NoProcessed Patient Number 1953
#
# NoNoNo.Processed Patient Number 1954
#
# No.NoNo.Processed Patient Number 1955
#
# NoNo.NoProcessed Patient Number 1956
#
# No.NoProcessed Patient Number 1957
#
# NoNo.NoNo.No.No.Processed Patient Number 1958
#
# NoNo.Processed Patient Number 1959
#
# NoNoNo.NoProcessed Patient Number 1960
#
# No.NoNoNoNo.Processed Patient Number 1961
#
# NoNo.NoNo.Processed Patient Number 1962
#
# NoNo.NoNoProcessed Patient Number 1963
#
# NoNoProcessed Patient Number 1964
#
# NoNo.NoNoProcessed Patient Number 1965
#
# No.NoNoNoNoProcessed Patient Number 1966
#
# NoNoProcessed Patient Number 1967
#
# No.No.NoNoNoProcessed Patient Number 1968
#
# NoNoNo.Processed Patient Number 1969
#
# NoNo.NoNoNoNoNoYesNo.Processed Patient Number 1970
#
# NoNoNoNoProcessed Patient Number 1971
#
# NoNoNo.Processed Patient Number 1972
#
# NoNo.NoProcessed Patient Number 1973
#
# No.NoNo.NoNoProcessed Patient Number 1974
#
# No.No.NoNo.NoProcessed Patient Number 1975
#
# No.NoNoNoNoNoNoNoProcessed Patient Number 1976
#
# NoNo.NoNoProcessed Patient Number 1977
#
# NoNoNo.NoProcessed Patient Number 1978
#
# NoNoNo.Processed Patient Number 1979
#
# No.NoNo.Processed Patient Number 1980
#
# NoNoNo.No.NoNoNoProcessed Patient Number 1981
#
# NoNo.NoNo.NoProcessed Patient Number 1982
#
# NoNoNoProcessed Patient Number 1983
#
# NoNo.NoNoNoNoNo.No.Processed Patient Number 1984
#
# No.NoNo.Processed Patient Number 1985
#
# NoNoProcessed Patient Number 1986
#
# No.NoNo.NoNoNoProcessed Patient Number 1987
#
# NoNoNoProcessed Patient Number 1988
#
# No.NoNo.NoNoProcessed Patient Number 1989
#
# NoNoProcessed Patient Number 1990
#
# NoNo.NoNoNo.Processed Patient Number 1991
#
# NoNo.No.NoProcessed Patient Number 1992
#
# No.NoNoNoNoNoProcessed Patient Number 1993
#
# No.NoNo.NoProcessed Patient Number 1994
#
# NoNo.NoNoNoProcessed Patient Number 1995
#
# NoNoNo.Processed Patient Number 1996
#
# NoNoNoNo.No.Processed Patient Number 1997
#
# NoNoProcessed Patient Number 1998
#
# NoNoYesNoNoProcessed Patient Number 1999
#
# NoProcessed Patient Number 2000
#
# NoNo.NoProcessed Patient Number 2001
#
# NoNoNoNoNoProcessed Patient Number 2002
#
# No.No.NoNoNoProcessed Patient Number 2003
#
# NoNoNoNoNoProcessed Patient Number 2004
#
# NoNo.No.Processed Patient Number 2005
#
# NoNoProcessed Patient Number 2006
#
# NoNoNoNo.NoProcessed Patient Number 2007
#
# No.NoYesNoNoNoNo.Processed Patient Number 2008
#
# NoNoNoNo.NoProcessed Patient Number 2009
#
# NoNo.NoNoProcessed Patient Number 2010
#
# NoNoNo.NoNoNoNoProcessed Patient Number 2011
#
# NoNo.NoNoNoNoProcessed Patient Number 2012
#
# No.NoNoNoProcessed Patient Number 2013
#
# NoNoNo.Processed Patient Number 2014
#
# NoNoNoNoNo.NoNo.NoProcessed Patient Number 2015
#
# NoNoProcessed Patient Number 2016
#
# NoNoNoNoProcessed Patient Number 2017
#
# NoYesYesNo.Processed Patient Number 2018
#
# NoNoNoNoNoNoProcessed Patient Number 2019
#
# No.NoNoProcessed Patient Number 2020
