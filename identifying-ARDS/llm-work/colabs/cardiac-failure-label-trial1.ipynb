# %% [markdown]
# # Dependencies

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# Inside terminal run the following:
#
# ```
# ollama serve &
# ollama run llama3
# ```

# %%
# !pip install langchain_community
# Out:
# Collecting langchain_community
#   Downloading langchain_community-0.2.4-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 33.9 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain_community)
#   Downloading dataclasses_json-0.6.6-py3-none-any.whl (28 kB)
# Collecting langchain<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain-0.2.3-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.0/974.0 kB 60.1 MB/s eta 0:00:00
# Collecting langchain-core<0.3.0,>=0.2.0 (from langchain_community)
#   Downloading langchain_core-0.2.5-py3-none-any.whl (314 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.7/314.7 kB 39.8 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain_community)
#   Downloading langsmith-0.1.75-py3-none-any.whl (124 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.9/124.9 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain_community) (8.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 8.1 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.0->langchain_community)
#   Downloading langchain_text_splitters-0.2.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.0->langchain_community) (2.7.3)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting packaging<24.0,>=23.2 (from langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.1 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain_community)
#   Downloading orjson-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 269.5 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain_community) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (4.12.1)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain_community) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.0->langchain_community)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.0->langchain_community) (2.18.4)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: packaging, orjson, mypy-extensions, jsonpointer, typing-inspect, marshmallow, jsonpatch, langsmith, dataclasses-json, langchain-core, langchain-text-splitters, langchain, langchain_community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.0
#     Uninstalling packaging-24.0:
#       Successfully uninstalled packaging-24.0
# Successfully installed dataclasses-json-0.6.6 jsonpatch-1.33 jsonpointer-2.4 langchain-0.2.3 langchain-core-0.2.5 langchain-text-splitters-0.2.1 langchain_community-0.2.4 langsmith-0.1.75 marshmallow-3.21.3 mypy-extensions-1.0.0 orjson-3.10.3 packaging-23.2 typing-inspect-0.9.0

# %%
# Load Google Drive because it stores /content/drive/My Drive/ards-cohort-notes/ards-cohort-notes.csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Imports

# %%
import pandas as pd
import time
import random
import csv
from langchain_community.llms import Ollama
from langchain.callbacks.manager import CallbackManager
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler
from langchain_core.prompts import PromptTemplate

# %% [markdown]
# # Functions to load data, specify LLM prompt, and perform LLM inference

# %%
def load_data(file_path):
    df = pd.read_csv(file_path)
    df.fillna('', inplace=True)
    return df

def select_random_start(num_rows, min_rows=15):
    if num_rows < min_rows:
        raise ValueError(f"The dataset must contain at least {min_rows} rows to process.")
    return random.randint(0, num_rows - min_rows)

def create_prompt_template(task):
    return PromptTemplate(
        template=(
            f"Context: You are a clinician receiving chunks of clinical text for patients in an ICU. Please do the reviewing as quickly as possible.\n"
            f"Task: Determine if the patient suffered from {task}.\n"
            f"Instructions: Answer with 'Yes' or 'No'. If there is not enough information, answer 'No'.\n"
            f"Text:\n{{text}}\n\n"
            f"Query: Does the chunk of text mention that the patient suffered from {task}? Answer strictly in 'Yes' or 'No'."
        ),
        input_variables=["text"]
    )

def chunk_text(text, chunk_size, overlap):
    start = 0
    chunks = []
    while start < len(text):
        end = start + chunk_size
        chunks.append(text[start:end])
        start += chunk_size - overlap
    return chunks

def check_for_condition(text, llm, prompt_template, chunk_size, chunk_overlap):
    chunks = chunk_text(text, chunk_size, chunk_overlap)
    results = []
    for chunk in chunks:
        prompt = prompt_template.format(text=chunk)
        try:
            response = llm.invoke(prompt)
            results.append(response.strip())
        except Exception as e:
            results.append(f"Error invoking model: {e}")
    condition_mentions = [res for res in results if "Yes" in res]
    if condition_mentions:
        return "Yes", condition_mentions[0], len(text)
    else:
        return "No", results[0] if results else "No sufficient data", len(text)

def process_patients(df, start_index, num_patients, llm, prompt_template_cardiac, prompt_template_discharge, chunk_size, chunk_overlap, output_csv_file, progress_report_file):
    processing_time = []
    with open(output_csv_file, 'a', newline='') as csvfile, open(progress_report_file, 'a') as report_file:
        fieldnames = ['hadm_id', 'text_length', 'cardiac_failure_detected', 'time_taken']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        if csvfile.tell() == 0:
            writer.writeheader()

        for i in range(start_index, start_index + num_patients):
            current_hadm_id = df['hadm_id'].values[i]
            start_time = time.time()
            data = df[df['hadm_id'] == current_hadm_id]
            if data.empty:
                result = f"No data found for hadm_id: {current_hadm_id}"
            else:
                ecd_combined_reports = data['ecd_combined_reports'].values[0]
                cardiac_failure_result, explanation, ecd_combined_reports_length = check_for_condition(ecd_combined_reports, llm, prompt_template_cardiac, chunk_size, chunk_overlap)

                if cardiac_failure_result == "No":
                    discharge_text = data['discharge_text'].values[0]
                    cardiac_failure_result, explanation, discharge_text_length = check_for_condition(discharge_text, llm, prompt_template_discharge, chunk_size, chunk_overlap)

                end_time = time.time()
                elapsed_time = end_time - start_time
                processing_time.append(elapsed_time)

                writer.writerow({
                    'hadm_id': current_hadm_id,
                    'text_length': max(ecd_combined_reports_length, len(discharge_text)),
                    'cardiac_failure_detected': cardiac_failure_result,
                    'time_taken': round(elapsed_time)
                })
                csvfile.flush()

                report_file.write(f"Patient Number: {i}, HADM ID: {current_hadm_id}, Text Length: {max(ecd_combined_reports_length, len(discharge_text))}, Cardiac Failure Detected: {cardiac_failure_result}, Time Taken: {round(elapsed_time)}\n")
                report_file.flush()

                print(f"Processed Patient Number {i}\n")

# %% [markdown]
# # Main (calls all the functions above)

# %%
def main(file_path, model_name, chunk_size, chunk_overlap, output_csv_file, progress_report_file, num_patients):
    df = load_data(file_path)
    start_index = 1160
    prompt_template_cardiac = create_prompt_template("cardiac failure")
    prompt_template_discharge = create_prompt_template("cardiac failure")
    llm = Ollama(model=model_name, callback_manager=CallbackManager([StreamingStdOutCallbackHandler()]))
    process_patients(df, start_index, num_patients, llm, prompt_template_cardiac, prompt_template_discharge, chunk_size, chunk_overlap, output_csv_file, progress_report_file)

if __name__ == "__main__":
    main(
        file_path='/content/drive/My Drive/ards-cohort-notes/ards-cohort-notes.csv',
        model_name="llama3",
        chunk_size=4096,
        chunk_overlap=100,
        output_csv_file='cardiac-failure-2020.csv',
        progress_report_file='cardiac-failure-2020.txt',
        num_patients = 861
    )
# Out:
# NoNo.NoYesYes.YesYesNo.Processed Patient Number 1160
#
# NoNo.YesYesNoYesYesProcessed Patient Number 1161
#
# No.Yes.No.YesNoNoNoNo.Processed Patient Number 1162
#
# No.YesNoNoNo.Processed Patient Number 1163
#
# NoNo.NoNoNoProcessed Patient Number 1164
#
# NoNo.NoNoNo.Processed Patient Number 1165
#
# No.YesYesYesNo.Processed Patient Number 1166
#
# NoNoNoNoNo.Processed Patient Number 1167
#
# No.YesNoNoNoProcessed Patient Number 1168
#
# NoNo.NoNoNoNoNo.Processed Patient Number 1169
#
# YesYesYesProcessed Patient Number 1170
#
# No.YesYesYesProcessed Patient Number 1171
#
# NoNoNoNoNoProcessed Patient Number 1172
#
# NoYesYes.NoYesNo.Processed Patient Number 1173
#
# NoYesYesProcessed Patient Number 1174
#
# NoNoNoNoProcessed Patient Number 1175
#
# NoNoNo.NoNoNoNo.NoNoNoNoNoNoNoProcessed Patient Number 1176
#
# No.NoNoNoProcessed Patient Number 1177
#
# NoNo.NoNo.YesNoProcessed Patient Number 1178
#
# NoNoNoProcessed Patient Number 1179
#
# NoNoNoNoNoNoNoProcessed Patient Number 1180
#
# NoNoNoNo.Processed Patient Number 1181
#
# NoYesNoYesNoNoYesNoNoProcessed Patient Number 1182
#
# NoNoNo.Processed Patient Number 1183
#
# NoNo.NoNoNoNoNo.Processed Patient Number 1184
#
# No.No.No.NoNoNoNoNoProcessed Patient Number 1185
#
# NoNoYesNoNo.Processed Patient Number 1186
#
# No.No.NoNoNoNoProcessed Patient Number 1187
#
# No.No.No.No.YesYesNoYesYesNo.Processed Patient Number 1188
#
# No.YesNoNoProcessed Patient Number 1189
#
# NoNoYesProcessed Patient Number 1190
#
# No.No.NoNoNo.NoProcessed Patient Number 1191
#
# No.YesYesYesYesProcessed Patient Number 1192
#
# No.YesNo.NoNoProcessed Patient Number 1193
#
# NoNo.NoNoNoNoNo.Processed Patient Number 1194
#
# No.NoNoNoNoProcessed Patient Number 1195
#
# NoNo.Yes.No.NoNo.YesNoYesNoNoNo.Processed Patient Number 1196
#
# No.YesYesYesYesNoYesProcessed Patient Number 1197
#
# NoYesYesNo.No.Processed Patient Number 1198
#
# NoYesNo.Processed Patient Number 1199
#
# No.No.NoYesNoYesYesNoNo.Processed Patient Number 1200
#
# No.NoNoYesNoNoNoNo.Processed Patient Number 1201
#
# No.No.NoYesYesYesYesNoYes.Processed Patient Number 1202
#
# NoNoNoNoNoNoProcessed Patient Number 1203
#
# NoNo.NoNoNoNoNoProcessed Patient Number 1204
#
# NoYesYes.YesNoProcessed Patient Number 1205
#
# No.NoYesNoYes.NoProcessed Patient Number 1206
#
# No.YesYes.NoYesNoProcessed Patient Number 1207
#
# NoYesYesYesNoProcessed Patient Number 1208
#
# No.NoYesNoNoNoProcessed Patient Number 1209
#
# NoNoNoNo.YesNo.NoNoProcessed Patient Number 1210
#
# NoYesNoNoProcessed Patient Number 1211
#
# NoNoNoNo.No.No.YesYesNo.Processed Patient Number 1212
#
# NoNo.NoNoNoNoNoNoNoProcessed Patient Number 1213
#
# NoNoYesNo.NoProcessed Patient Number 1214
#
# NoNoNoNoNoProcessed Patient Number 1215
#
# YesNoNoNoYesYesProcessed Patient Number 1216
#
# NoYes.YesNoNo.NoProcessed Patient Number 1217
#
# NoYesNoNo.Processed Patient Number 1218
#
# NoNo.NoNoProcessed Patient Number 1219
#
# No.YesYesYesNoProcessed Patient Number 1220
#
# NoNoNoNoNoNo.Processed Patient Number 1221
#
# NoYesYesYesProcessed Patient Number 1222
#
# No.NoNoNoNoProcessed Patient Number 1223
#
# NoNoNoNo.NoProcessed Patient Number 1224
#
# NoNo.No.NoNoProcessed Patient Number 1225
#
# NoYesYesNoNo.Processed Patient Number 1226
#
# NoNoNo.NoProcessed Patient Number 1227
#
# No.YesNoNoNo.NoNo.NoNoNoNoProcessed Patient Number 1228
#
# NoNo.NoNoNoNoProcessed Patient Number 1229
#
# NoNo.Yes.No.Processed Patient Number 1230
#
# NoNoYesNoNo.Processed Patient Number 1231
#
# No.NoNoNoNoNoProcessed Patient Number 1232
#
# No.YesNoYesNoProcessed Patient Number 1233
#
# NoYesYesNoYesYesYesYesProcessed Patient Number 1234
#
# NoNoNoNoNoProcessed Patient Number 1235
#
# NoNoNoNo.NoNoProcessed Patient Number 1236
#
# NoNoYesNoNo.NoProcessed Patient Number 1237
#
# No.No.NoNo.NoProcessed Patient Number 1238
#
# NoYes.NoNoProcessed Patient Number 1239
#
# No.YesYesNoNoProcessed Patient Number 1240
#
# NoNoYes.NoNoNoProcessed Patient Number 1241
#
# NoYesNoYesYesProcessed Patient Number 1242
#
# NoYesNo.NoNoNo.Processed Patient Number 1243
#
# No.No.YesYesYesYesYesYesNoProcessed Patient Number 1244
#
# No.YesNoProcessed Patient Number 1245
#
# No.YesYesNoProcessed Patient Number 1246
#
# No.NoNoProcessed Patient Number 1247
#
# NoNo.NoNo.YesYes.YesProcessed Patient Number 1248
#
# No.YesYesYesNo.Processed Patient Number 1249
#
# No.Yes.YesYesYesYesNoProcessed Patient Number 1250
#
# NoNoNoNoYes.Processed Patient Number 1251
#
# NoNo.NoNo.No.NoNoNoNoNoProcessed Patient Number 1252
#
# NoNo.NoYesNoNoProcessed Patient Number 1253
#
# No.No.NoYesYesNo.NoYesProcessed Patient Number 1254
#
# NoNoProcessed Patient Number 1255
#
# No.NoProcessed Patient Number 1256
#
# No.No.NoNoYesProcessed Patient Number 1257
#
# NoYes.YesYesNoProcessed Patient Number 1258
#
# NoNoNoNoNoNoNoProcessed Patient Number 1259
#
# No.YesNoNo.Processed Patient Number 1260
#
# NoYesNo.Processed Patient Number 1261
#
# No.NoNoNo.NoProcessed Patient Number 1262
#
# NoNo.NoNoYesYesNoProcessed Patient Number 1263
#
# YesYesYes.NoProcessed Patient Number 1264
#
# No.YesNoNoNoNoProcessed Patient Number 1265
#
# NoNoNo.YesProcessed Patient Number 1266
#
# NoYesNoYesNoProcessed Patient Number 1267
#
# No.YesNoNoNoProcessed Patient Number 1268
#
# No.No.NoNoNoProcessed Patient Number 1269
#
# No.YesYes.YesYesNoNoYesNoProcessed Patient Number 1270
#
# NoYesYesNoProcessed Patient Number 1271
#
# NoNoNoNoProcessed Patient Number 1272
#
# No.YesYesNo.YesNoProcessed Patient Number 1273
#
# NoNoNoNoNoProcessed Patient Number 1274
#
# NoNoNoNo.Processed Patient Number 1275
#
# NoYesNo.Processed Patient Number 1276
#
# No.YesNoNoNo.No.Processed Patient Number 1277
#
# NoNoNoNoNoNoNoNo.Processed Patient Number 1278
#
# No.YesNoNoNoNoNoProcessed Patient Number 1279
#
# NoYesNoNoNo.Processed Patient Number 1280
#
# NoNo.No.Processed Patient Number 1281
#
# NoYesYes.No.Processed Patient Number 1282
#
# NoNoNoNoNo.Processed Patient Number 1283
#
# NoYesNoNoProcessed Patient Number 1284
#
# No.No.YesNoProcessed Patient Number 1285
#
# NoNoNoNoNoNoProcessed Patient Number 1286
#
# NoNoProcessed Patient Number 1287
#
# NoNoNoNoProcessed Patient Number 1288
#
# NoYesNoYes.Processed Patient Number 1289
#
# NoNoNoNoNoNo.Processed Patient Number 1290
#
# No.Yes.NoNoNoYesProcessed Patient Number 1291
#
# NoNoNoNoNoNoProcessed Patient Number 1292
#
# NoYes.NoNoNoNoNoNo.Processed Patient Number 1293
#
# No.No.NoNoNoNoProcessed Patient Number 1294
#
# NoYesNoNoProcessed Patient Number 1295
#
# No.No.NoYesNoProcessed Patient Number 1296
#
# No.NoNo.No.Processed Patient Number 1297
#
# NoNo.NoNoProcessed Patient Number 1298
#
# YesProcessed Patient Number 1299
#
# No.NoNo.NoYesYesNoNo.YesYesYesNoYesProcessed Patient Number 1300
#
# No.YesYesNoNoNoProcessed Patient Number 1301
#
# No.Yes.NoNoYesYesProcessed Patient Number 1302
#
# NoYesYesYesYesYesYesProcessed Patient Number 1303
#
# NoYesYesNo.No.Processed Patient Number 1304
#
# NoNoYes.NoNoProcessed Patient Number 1305
#
# YesNoNoYesNo.Processed Patient Number 1306
#
# No.No.YesYesNoNoProcessed Patient Number 1307
#
# NoNo.No.No.YesNoNoNoNoNoNo.Processed Patient Number 1308
#
# NoNoNo.No.NoProcessed Patient Number 1309
#
# YesYesYesYes.YesNoProcessed Patient Number 1310
#
# No.YesYesNo.Processed Patient Number 1311
#
# NoYesProcessed Patient Number 1312
#
# No.YesNoNo.NoYesNoNoNoNo.Processed Patient Number 1313
#
# No.NoNo.NoNo.Processed Patient Number 1314
#
# NoYesNoYesYesProcessed Patient Number 1315
#
# NoNoNoNo.No.Processed Patient Number 1316
#
# NoYes.No.Processed Patient Number 1317
#
# NoYesYes.YesYesYesYesYes.Processed Patient Number 1318
#
# NoNo.No.NoNo.YesProcessed Patient Number 1319
#
# NoNoNoNoNoNoNoProcessed Patient Number 1320
#
# NoNoNoBased on the provided chunks of clinical text, I did not find any mentioning of "cardiac failure" in the given text. Therefore, my answer is:
#
# NoNoNoNo.NoProcessed Patient Number 1321
#
# NoNoNoNoNoNoProcessed Patient Number 1322
#
# YesYesNoProcessed Patient Number 1323
#
# No.Yes.NoNoNo.Processed Patient Number 1324
#
# NoNo.Yes.YesYesYesYesYesNoYesProcessed Patient Number 1325
#
# No.NoNoNo.Processed Patient Number 1326
#
# NoNoYesNoNoNoNo.Processed Patient Number 1327
#
# No.YesNoYesProcessed Patient Number 1328
#
# No.No.NoNoNoNo.Processed Patient Number 1329
#
# No.YesYesYesNoNoYesProcessed Patient Number 1330
#
# NoNoNoNoNoProcessed Patient Number 1331
#
# No.No.No.NoNoNo.No.Processed Patient Number 1332
#
# No.YesNoYesNo.YesProcessed Patient Number 1333
#
# No.YesNoNoYesNoProcessed Patient Number 1334
#
# NoNo.NoNoNoProcessed Patient Number 1335
#
# NoNo.NoNoProcessed Patient Number 1336
#
# No.YesYesYesYesProcessed Patient Number 1337
#
# NoNoNoNoNoProcessed Patient Number 1338
#
# No.Yes.No.YesYesYesNoYesYesYesYesYesYesProcessed Patient Number 1339
#
# NoNoNoNoNo.Processed Patient Number 1340
#
# No.NoNoNoNoNoProcessed Patient Number 1341
#
# No.No.NoNo.NoProcessed Patient Number 1342
#
# No.YesYesNoYesProcessed Patient Number 1343
#
# NoYesYesYesNo.Processed Patient Number 1344
#
# NoYesNoNoNo.NoProcessed Patient Number 1345
#
# NoNoYesNoNoProcessed Patient Number 1346
#
# NoNoNoNoNoNoProcessed Patient Number 1347
#
# NoYes.No.NoNoProcessed Patient Number 1348
#
# No.NoNoNoNoNoProcessed Patient Number 1349
#
# NoYesNoNoNoProcessed Patient Number 1350
#
# YesNoNoProcessed Patient Number 1351
#
# YesYesYesNo.NoYesYesYes.Processed Patient Number 1352
#
# No.NoNo.YesNoNoNoNo.No.NoProcessed Patient Number 1353
#
# No.YesYesYesProcessed Patient Number 1354
#
# NoNoNoProcessed Patient Number 1355
#
# NoNo.NoNo.Processed Patient Number 1356
#
# NoNoNoNoProcessed Patient Number 1357
#
# NoYesYesYesYesNoProcessed Patient Number 1358
#
# No.YesYesProcessed Patient Number 1359
#
# No.No.NoNoNo.NoProcessed Patient Number 1360
#
# No.YesYes.NoNoNoProcessed Patient Number 1361
#
# NoNo.No.No.NoYesYesYesNo.Processed Patient Number 1362
#
# NoYes.No.Processed Patient Number 1363
#
# No.Yes.NoNoNoNo.Processed Patient Number 1364
#
# No.NoNo.YesNoYesYesProcessed Patient Number 1365
#
# No.No.NoNoProcessed Patient Number 1366
#
# NoNoNoNo.NoProcessed Patient Number 1367
#
# No.NoYesYesYesNoNoNoNo.Processed Patient Number 1368
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1369
#
# YesYesYesYes.YesProcessed Patient Number 1370
#
# No.YesNoYes.Processed Patient Number 1371
#
# No.YesYesNoNo.Processed Patient Number 1372
#
# NoNoNoNo.No.Processed Patient Number 1373
#
# NoNoNo.Processed Patient Number 1374
#
# NoNoNo.NoYesYesProcessed Patient Number 1375
#
# No.NoNoNoNo.NoNoNoProcessed Patient Number 1376
#
# YesYesYesYes.Processed Patient Number 1377
#
# YesYesNo.NoProcessed Patient Number 1378
#
# No.NoNoNoProcessed Patient Number 1379
#
# No.YesNoNoProcessed Patient Number 1380
#
# NoYesNoNo.Processed Patient Number 1381
#
# NoNo.NoNoNoProcessed Patient Number 1382
#
# No.YesYesNo.Processed Patient Number 1383
#
# NoNoNo.NoNoNoNoYesNoNoNoNoProcessed Patient Number 1384
#
# NoYesNoNo.NoNoProcessed Patient Number 1385
#
# NoNo.YesProcessed Patient Number 1386
#
# No.YesNoProcessed Patient Number 1387
#
# No.NoNo.Processed Patient Number 1388
#
# No.YesYes.Processed Patient Number 1389
#
# No.Yes.NoYesNo.NoNoNoProcessed Patient Number 1390
#
# NoYesNoYesYesYesYesProcessed Patient Number 1391
#
# NoNoYesNoProcessed Patient Number 1392
#
# NoNo.No.No.NoYesNoNo.No.Processed Patient Number 1393
#
# No.NoNo.YesNoProcessed Patient Number 1394
#
# No.YesYesYesYesProcessed Patient Number 1395
#
# NoNo.YesNoYesNoProcessed Patient Number 1396
#
# NoNoYesNoNo.Processed Patient Number 1397
#
# NoYesYesYesYes.Processed Patient Number 1398
#
# NoYesNoNo.NoProcessed Patient Number 1399
#
# No.YesYesYesYes.Processed Patient Number 1400
#
# No.NoYesNoYesProcessed Patient Number 1401
#
# No.NoNoProcessed Patient Number 1402
#
# No.NoNoNoNoNoProcessed Patient Number 1403
#
# NoNo.NoNo.NoProcessed Patient Number 1404
#
# NoYesNoNoNoNoNo.No.Processed Patient Number 1405
#
# No.NoNoNoYesNoProcessed Patient Number 1406
#
# No.NoNoNoNoNoProcessed Patient Number 1407
#
# NoNo.No.Processed Patient Number 1408
#
# NoNoNoNo.Processed Patient Number 1409
#
# No.YesNo.NoNoNo.Processed Patient Number 1410
#
# No.NoNo.Processed Patient Number 1411
#
# NoNoNoYesNoNo.Processed Patient Number 1412
#
# NoNo.NoProcessed Patient Number 1413
#
# No.YesYes.YesYesYesProcessed Patient Number 1414
#
# NoYesYesYesNoProcessed Patient Number 1415
#
# No.YesYesYesYesNoNo.YesYesNoProcessed Patient Number 1416
#
# No.Yes.YesYesProcessed Patient Number 1417
#
# No.YesNo.NoProcessed Patient Number 1418
#
# No.NoNo.Processed Patient Number 1419
#
# NoNo.No.NoNoNoNoNoNoNoNo.Processed Patient Number 1420
#
# NoNoNo.No.NoNo.Processed Patient Number 1421
#
# No.YesYesProcessed Patient Number 1422
#
# NoYesYes.Processed Patient Number 1423
#
# No.YesNo.Processed Patient Number 1424
#
# NoNoNo.Processed Patient Number 1425
#
# NoNo.NoNo.No.YesNo.YesNoNo.NoNo.NoNoProcessed Patient Number 1426
#
# NoNo.NoNoNoNoProcessed Patient Number 1427
#
# No.NoNoNoNoNoNo.NoProcessed Patient Number 1428
#
# No.YesYesYes.NoProcessed Patient Number 1429
#
# NoNoNo.NoNoNoProcessed Patient Number 1430
#
# No.Yes.NoNoProcessed Patient Number 1431
#
# NoNoYesYesYesYesYesNo.Processed Patient Number 1432
#
# No.YesYesYesNoProcessed Patient Number 1433
#
# NoNo.No.YesNoNo.No.Processed Patient Number 1434
#
# NoNoNo.YesNoNoNoNoNoProcessed Patient Number 1435
#
# NoYesNo.Processed Patient Number 1436
#
# NoNoNoProcessed Patient Number 1437
#
# NoNoNoNoProcessed Patient Number 1438
#
# NoNoNoNoNo.Processed Patient Number 1439
#
# Yes.YesProcessed Patient Number 1440
#
# No.NoNoNoNo.Processed Patient Number 1441
#
# NoNoNoNoNo.NoProcessed Patient Number 1442
#
# NoNoNoNoNoProcessed Patient Number 1443
#
# NoNoYesNoNoNoProcessed Patient Number 1444
#
# NoYesNoNo.No.Processed Patient Number 1445
#
# NoNoNo.No.NoNoNoProcessed Patient Number 1446
#
# No.Yes.YesYes.NoNoProcessed Patient Number 1447
#
# NoNoNo.Processed Patient Number 1448
#
# No.NoNo.YesYesYesYesProcessed Patient Number 1449
#
# NoYesNoNoYesProcessed Patient Number 1450
#
# NoYesYesYesYesYesProcessed Patient Number 1451
#
# NoYesYes.Yes.YesProcessed Patient Number 1452
#
# NoYesYesYesNoProcessed Patient Number 1453
#
# NoNo.NoProcessed Patient Number 1454
#
# NoNo.No.Processed Patient Number 1455
#
# No.NoNoNoNo.Processed Patient Number 1456
#
# No.No.NoNo.Processed Patient Number 1457
#
# No.Yes.NoNo.NoYesNoNoNo.NoNoProcessed Patient Number 1458
#
# Yes.NoYesProcessed Patient Number 1459
#
# No.YesYesNoNoProcessed Patient Number 1460
#
# NoNoNo.Processed Patient Number 1461
#
# NoYesYesProcessed Patient Number 1462
#
# YesYesProcessed Patient Number 1463
#
# No.NoYesNo.YesNo.Processed Patient Number 1464
#
# No.YesYesYesNoProcessed Patient Number 1465
#
# No.No.YesYesYesNoYesProcessed Patient Number 1466
#
# No.NoNoNoProcessed Patient Number 1467
#
# NoYes.No.NoProcessed Patient Number 1468
#
# NoYesNoNo.NoNo.Processed Patient Number 1469
#
# No.YesYesNoNo.Processed Patient Number 1470
#
# No.YesYesNoYesYesProcessed Patient Number 1471
#
# NoYesNoNoNoNoNo.No.Processed Patient Number 1472
#
# NoYesYesYesYesProcessed Patient Number 1473
#
# No.NoNoProcessed Patient Number 1474
#
# NoYesYesYesNo.Processed Patient Number 1475
#
# YesYesProcessed Patient Number 1476
#
# No.YesYes.YesProcessed Patient Number 1477
#
# No.NoNoYesYesNoNo.Processed Patient Number 1478
#
# NoNoNo.Processed Patient Number 1479
#
# No.NoNoNoNoNoNoNoNoNo.No.Processed Patient Number 1480
#
# NoYesNoNoProcessed Patient Number 1481
#
# NoNoNo.Processed Patient Number 1482
#
# NoNo.NoNoNoNoProcessed Patient Number 1483
#
# NoYes.YesNoNo.Processed Patient Number 1484
#
# NoNoNoProcessed Patient Number 1485
#
# NoYesNoNoNo.Processed Patient Number 1486
#
# No.YesYesYesProcessed Patient Number 1487
#
# NoNo.NoNo.YesProcessed Patient Number 1488
#
# NoYesNoNoNoNoYesProcessed Patient Number 1489
#
# NoNoNoNoNoProcessed Patient Number 1490
#
# NoYesNoNoNoProcessed Patient Number 1491
#
# NoNoNoNoProcessed Patient Number 1492
#
# No.No.NoNoProcessed Patient Number 1493
#
# No.NoNoProcessed Patient Number 1494
#
# No.Yes.YesNoYesYesProcessed Patient Number 1495
#
# NoNoYesYesYesNo.YesYesNoYesProcessed Patient Number 1496
#
# NoNoNoNoNoNoProcessed Patient Number 1497
#
# No.YesNoYesYesNo.YesNoNoProcessed Patient Number 1498
#
# NoYesNoNoNoNoNoNoNoProcessed Patient Number 1499
#
# No.No.NoNoNo.Processed Patient Number 1500
#
# NoYesNo.Processed Patient Number 1501
#
# No.No.NoNoProcessed Patient Number 1502
#
# NoNoYesNo.NoProcessed Patient Number 1503
#
# No.NoNoNo.Processed Patient Number 1504
#
# NoNoNoNoYesProcessed Patient Number 1505
#
# No.No.Yes.YesYesNoNoNoProcessed Patient Number 1506
#
# NoNoNoNoProcessed Patient Number 1507
#
# No.NoYesYesYesProcessed Patient Number 1508
#
# NoYesNoNo.Processed Patient Number 1509
#
# YesYes.YesYesYesProcessed Patient Number 1510
#
# No.No.NoNo.NoNoNoYes.Processed Patient Number 1511
#
# No.No.Yes.YesYes.YesProcessed Patient Number 1512
#
# No.YesYesNoProcessed Patient Number 1513
#
# No.Yes.No.Processed Patient Number 1514
#
# No.YesNoYesYesProcessed Patient Number 1515
#
# NoNoNo.No.Processed Patient Number 1516
#
# No.No.YesYesYesYesYesProcessed Patient Number 1517
#
# NoYesNoNoNoNoProcessed Patient Number 1518
#
# No.YesNoYesNo.Processed Patient Number 1519
#
# NoYesNoProcessed Patient Number 1520
#
# NoYesNoNo.Processed Patient Number 1521
#
# NoYesNoNo.YesYesYesYesYesYesYesProcessed Patient Number 1522
#
# No.NoNoYesYesNo.YesNo.Processed Patient Number 1523
#
# NoYesYes.YesNoYesProcessed Patient Number 1524
#
# No.NoNoNoProcessed Patient Number 1525
#
# No.No.No.YesYes.NoNo.Processed Patient Number 1526
#
# NoNo.YesNoNo.Processed Patient Number 1527
#
# NoNoNoYesYesYesYesNo.Processed Patient Number 1528
#
# NoYesNoNo.Processed Patient Number 1529
#
# NoYesNo.NoNo.NoProcessed Patient Number 1530
#
# No.YesYesYesNo.Processed Patient Number 1531
#
# No.Yes.YesProcessed Patient Number 1532
#
# No.YesYesYes.Processed Patient Number 1533
#
# NoYesYesYesProcessed Patient Number 1534
#
# NoNo.YesNoNoNo.Processed Patient Number 1535
#
# NoYesYesYesYesProcessed Patient Number 1536
#
# NoNoNoNoNo.NoProcessed Patient Number 1537
#
# No.NoNoNo.Processed Patient Number 1538
#
# NoNo.YesYesYesNo.No.Processed Patient Number 1539
#
# NoNo.NoYesYesNoNoNoNo.NoProcessed Patient Number 1540
#
# NoYesNoProcessed Patient Number 1541
#
# NoNoNoNoProcessed Patient Number 1542
#
# No.YesYes.YesProcessed Patient Number 1543
#
# No.No.YesNoYesProcessed Patient Number 1544
#
# NoYesNoNoProcessed Patient Number 1545
#
# No.YesYesYesYesYesNoNoProcessed Patient Number 1546
#
# NoNo.NoNoProcessed Patient Number 1547
#
# No.YesYesNoProcessed Patient Number 1548
#
# No.YesNoNoNoProcessed Patient Number 1549
#
# NoYesYesYesNo.NoNoProcessed Patient Number 1550
#
# No.No.YesNoNo.No.Processed Patient Number 1551
#
# NoYesYesNo.Processed Patient Number 1552
#
# No.YesNoProcessed Patient Number 1553
#
# NoNoNoNoProcessed Patient Number 1554
#
# NoNoNoNoProcessed Patient Number 1555
#
# NoNoNoNoNoProcessed Patient Number 1556
#
# NoNoYesNo.NoProcessed Patient Number 1557
#
# NoNoNo.NoProcessed Patient Number 1558
#
# NoYesNo.NoNo.NoYesYesYesNoProcessed Patient Number 1559
#
# NoYesNoNoYesProcessed Patient Number 1560
#
# No.NoNoNo.Processed Patient Number 1561
#
# No.No.NoYesNoNoNoNo.No.NoProcessed Patient Number 1562
#
# No.YesYesYesYes.Processed Patient Number 1563
#
# YesNo.YesNo.Processed Patient Number 1564
#
# NoNo.NoNoNoProcessed Patient Number 1565
#
# NoYes.NoNoNoNo.NoNo.Processed Patient Number 1566
#
# NoYesNoNoNoNo.Processed Patient Number 1567
#
# NoNoNo.NoProcessed Patient Number 1568
#
# NoNo.NoNoNo.NoNo.Processed Patient Number 1569
#
# NoNoNoYesYesYesYesNoNo.NoYesNoProcessed Patient Number 1570
#
# NoNo.NoNoNo.Processed Patient Number 1571
#
# NoNoNoNo.NoProcessed Patient Number 1572
#
# No.No.NoNoNo.No.Processed Patient Number 1573
#
# No.YesNoNoNoNoNoProcessed Patient Number 1574
#
# No.NoNoNoNoProcessed Patient Number 1575
#
# NoYesProcessed Patient Number 1576
#
# NoNoNoYesNoYesProcessed Patient Number 1577
#
# No.NoNo.NoNoNoNo.Processed Patient Number 1578
#
# No.YesYesYesNoProcessed Patient Number 1579
#
# NoNoNo.Processed Patient Number 1580
#
# NoYesNoNoProcessed Patient Number 1581
#
# NoNoNoNoProcessed Patient Number 1582
#
# YesNoProcessed Patient Number 1583
#
# No.YesNo.YesYesYesProcessed Patient Number 1584
#
# NoNo.No.No.No.NoProcessed Patient Number 1585
#
# No.NoNoNo.Processed Patient Number 1586
#
# No.NoNoNoYesNoProcessed Patient Number 1587
#
# No.YesYesYesYes.Processed Patient Number 1588
#
# No.NoNo.YesYesProcessed Patient Number 1589
#
# No.YesNoNoProcessed Patient Number 1590
#
# NoYesNoProcessed Patient Number 1591
#
# No.NoNoNo.Processed Patient Number 1592
#
# YesNo.NoProcessed Patient Number 1593
#
# NoNoNoProcessed Patient Number 1594
#
# NoYesYesYesYesYesProcessed Patient Number 1595
#
# NoYesYesNoYesNo.NoProcessed Patient Number 1596
#
# No.NoNo.NoProcessed Patient Number 1597
#
# No.No.NoNoNoNoNo.NoYesNo.Processed Patient Number 1598
#
# NoYesNoNoProcessed Patient Number 1599
#
# NoNo.No.NoNoNoProcessed Patient Number 1600
#
# No.NoNoNoNoNoNoNoNo.Processed Patient Number 1601
#
# No.NoNo.NoNoProcessed Patient Number 1602
#
# No.Yes.NoNoProcessed Patient Number 1603
#
# No.YesNoProcessed Patient Number 1604
#
# YesNoNo.Processed Patient Number 1605
#
# No.NoNoYesProcessed Patient Number 1606
#
# No.No.NoNoNoNoProcessed Patient Number 1607
#
# NoNoNo.NoNoProcessed Patient Number 1608
#
# No.No.YesNoNoYesNoNoNo.NoNoNoProcessed Patient Number 1609
#
# YesYesYesYesProcessed Patient Number 1610
#
# No.NoNo.NoProcessed Patient Number 1611
#
# NoYes.NoNoProcessed Patient Number 1612
#
# No.NoPlt ___No.NoNoNoNoNoNoProcessed Patient Number 1613
#
# NoNoNo.Processed Patient Number 1614
#
# No.Yes.Yes.YesNoProcessed Patient Number 1615
#
# No.NoNo.NoYesNoNoNoProcessed Patient Number 1616
#
# No.NoNo.NoNoNoYesYesNo.YesProcessed Patient Number 1617
#
# NoYesNoNoNoNoNo.Processed Patient Number 1618
#
# NoNo.NoNoYesNoProcessed Patient Number 1619
#
# No.NoYesYesNo.Processed Patient Number 1620
#
# NoNoNoNoNoNoNoProcessed Patient Number 1621
#
# No.NoYesNoYesNoYesNoYesNoProcessed Patient Number 1622
#
# No.NoYesNoProcessed Patient Number 1623
#
# NoYesYesYes.Processed Patient Number 1624
#
# No.YesYes.Processed Patient Number 1625
#
# No.NoNoNoNoProcessed Patient Number 1626
#
# No.NoNoNoNoProcessed Patient Number 1627
#
# NoNo.NoYesYesYesNoProcessed Patient Number 1628
#
# NoYes.No.NoYes.YesProcessed Patient Number 1629
#
# NoYesProcessed Patient Number 1630
#
# No.No.NoNoNoNoProcessed Patient Number 1631
#
# YesYesNoNo.Processed Patient Number 1632
#
# NoYesNoYes.Processed Patient Number 1633
#
# NoYesYesYesProcessed Patient Number 1634
#
# NoYesNoNoNoNoProcessed Patient Number 1635
#
# NoNoNo.NoNoProcessed Patient Number 1636
#
# NoNoNoNo.NoProcessed Patient Number 1637
#
# NoNo.No.NoYesProcessed Patient Number 1638
#
# NoYesYesNo.Processed Patient Number 1639
#
# NoYesNo.YesYesProcessed Patient Number 1640
#
# NoYesNo.Processed Patient Number 1641
#
# NoNo.No.Yes.NoProcessed Patient Number 1642
#
# NoYesYesYesYesProcessed Patient Number 1643
#
# No.NoYesYesNo.NoProcessed Patient Number 1644
#
# NoNo.Processed Patient Number 1645
#
# No.YesNoNo.No.Processed Patient Number 1646
#
# NoYesYesNoNo.Processed Patient Number 1647
#
# NoNo.NoNoYesYesYesNoProcessed Patient Number 1648
#
# NoYes.NoYesProcessed Patient Number 1649
#
# No.No.No.NoNoNo.Processed Patient Number 1650
#
# NoYesNoNoNoNoNoNoProcessed Patient Number 1651
#
# NoYesYesNoNo.Processed Patient Number 1652
#
# No.No.NoNoNoNoNoProcessed Patient Number 1653
#
# NoNoNoProcessed Patient Number 1654
#
# Yes.NoYesYesYesNo.YesProcessed Patient Number 1655
#
# NoYesNo.NoNoProcessed Patient Number 1656
#
# NoYesYesYes.Yes.NoProcessed Patient Number 1657
#
# No.YesNoYes.NoNo.NoNoProcessed Patient Number 1658
#
# NoNo.NoNoNoNo.NoProcessed Patient Number 1659
#
# No.NoYesNo.Processed Patient Number 1660
#
# No.YesNoNo.No.Processed Patient Number 1661
#
# No.No.No.No.NoNoNoProcessed Patient Number 1662
#
# No.NoNoYesNoNoNoNo.Processed Patient Number 1663
#
# NoNoNoNoProcessed Patient Number 1664
#
# No.YesNoYesProcessed Patient Number 1665
#
# NoNoNoYesNoNo.Processed Patient Number 1666
#
# NoNo.NoYes.Yes.No.NoYesNo.NoProcessed Patient Number 1667
#
# No.Yes.YesYesProcessed Patient Number 1668
#
# NoYesYes.No.Processed Patient Number 1669
#
# No.Yes.NoYesYesProcessed Patient Number 1670
#
# No.YesNoYesNoProcessed Patient Number 1671
#
# No.YesNo.NoNoNoProcessed Patient Number 1672
#
# NoNoNoNoNoNoNoNoNoProcessed Patient Number 1673
#
# NoYesNo.YesProcessed Patient Number 1674
#
# No.YesNoProcessed Patient Number 1675
#
# NoNoYes.YesNoProcessed Patient Number 1676
#
# No.Yes.YesNoNo.Processed Patient Number 1677
#
# NoNo.NoNoYes.YesNo.Processed Patient Number 1678
#
# NoNo.Processed Patient Number 1679
#
# NoNo.No.No.NoProcessed Patient Number 1680
#
# NoNoYesNoNo.Processed Patient Number 1681
#
# No.NoYesNoNo.NoProcessed Patient Number 1682
#
# No.YesYesYesYesProcessed Patient Number 1683
#
# No.NoNoNo.NoProcessed Patient Number 1684
#
# No.NoNoNoNo.NoNo.No.Processed Patient Number 1685
#
# NoNo.No.NoNoNoNo.No.YesYesYes.YesYesProcessed Patient Number 1686
#
# NoNo.NoNoNoYesNoYesNo.Processed Patient Number 1687
#
# NoNoNoProcessed Patient Number 1688
#
# NoNoNoNo.No.Processed Patient Number 1689
#
# No.YesNoNoNoNo.Processed Patient Number 1690
#
# No.YesNoNoNoProcessed Patient Number 1691
#
# NoYesYesYes.YesNoYesYes.Processed Patient Number 1692
#
# NoYesYesNoNoProcessed Patient Number 1693
#
# NoNoNoNoProcessed Patient Number 1694
#
# NoNo.NoNo.Processed Patient Number 1695
#
# No.NoProcessed Patient Number 1696
#
# No.YesNoNo.Processed Patient Number 1697
#
# NoYesNoNoProcessed Patient Number 1698
#
# NoNoNoProcessed Patient Number 1699
#
# NoNoYesNoNo.Processed Patient Number 1700
#
# NoNoYesNo.Processed Patient Number 1701
#
# NoNoYesNoProcessed Patient Number 1702
#
# NoYesNoNoNoNoNo.Processed Patient Number 1703
#
# NoYesYesYesProcessed Patient Number 1704
#
# No.No.NoNoYesProcessed Patient Number 1705
#
# NoNoYesYesProcessed Patient Number 1706
#
# No.YesNo.NoNoYesNo.Processed Patient Number 1707
#
# NoNoNoNoNoNoNoProcessed Patient Number 1708
#
# No.YesNoNoNoProcessed Patient Number 1709
#
# No.YesYesYesNoProcessed Patient Number 1710
#
# No.YesYesYesYesProcessed Patient Number 1711
#
# NoNoYesYesNoProcessed Patient Number 1712
#
# No.YesYesNoNo.Processed Patient Number 1713
#
# NoYesNoProcessed Patient Number 1714
#
# NoNoNoNoNo.Processed Patient Number 1715
#
# No.NoNo.YesNoNoNoNo.Processed Patient Number 1716
#
# NoNoNoNoNoProcessed Patient Number 1717
#
# No.NoProcessed Patient Number 1718
#
# No.YesYesProcessed Patient Number 1719
#
# No.YesYesYesYesProcessed Patient Number 1720
#
# NoNoNo.Processed Patient Number 1721
#
# No.NoNoNoNoNoNoProcessed Patient Number 1722
#
# YesProcessed Patient Number 1723
#
# No.YesYesYesNo.Processed Patient Number 1724
#
# NoNo.NoNoNoProcessed Patient Number 1725
#
# No.YesYesYesYesProcessed Patient Number 1726
#
# NoYesNoNo.No.Processed Patient Number 1727
#
# NoNo.NoYesNoNo.Processed Patient Number 1728
#
# NoNoNo.NoNoProcessed Patient Number 1729
#
# No.Yes.YesYesYesYesProcessed Patient Number 1730
#
# No.YesNoYesNoProcessed Patient Number 1731
#
# No.YesYesYesYesYesYesProcessed Patient Number 1732
#
# NoYesNoYes.No.Processed Patient Number 1733
#
# NoNo.No.Processed Patient Number 1734
#
# No.NoNoNoNoProcessed Patient Number 1735
#
# NoYesYesNo.Processed Patient Number 1736
#
# NoYesYesYesYesProcessed Patient Number 1737
#
# NoNo.NoNoProcessed Patient Number 1738
#
# YesNoProcessed Patient Number 1739
#
# No.No.No.NoNoProcessed Patient Number 1740
#
# No.NoNoNoNo.Processed Patient Number 1741
#
# NoYesYes.YesProcessed Patient Number 1742
#
# No.No.Processed Patient Number 1743
#
# NoNoNoProcessed Patient Number 1744
#
# NoNo.NoNoNoProcessed Patient Number 1745
#
# No.YesYesProcessed Patient Number 1746
#
# NoYesNo.NoProcessed Patient Number 1747
#
# No.NoYesYesYesYesYesYesProcessed Patient Number 1748
#
# No.NoYesNoNoProcessed Patient Number 1749
#
# No.YesNoProcessed Patient Number 1750
#
# No.YesYesNoProcessed Patient Number 1751
#
# No.YesNoYesNo.NoNoProcessed Patient Number 1752
#
# No.NoNoNoProcessed Patient Number 1753
#
# YesYesYesYesNoNoProcessed Patient Number 1754
#
# NoNo.NoNo.NoNo.Processed Patient Number 1755
#
# No.No.YesNoNoNoProcessed Patient Number 1756
#
# NoNo.NoNoNoYesNoNoNoNoNoNoNoNoProcessed Patient Number 1757
#
# No.YesYesYesYesNoProcessed Patient Number 1758
#
# NoNoNoNo.NoNo.Processed Patient Number 1759
#
# NoYes.Processed Patient Number 1760
#
# NoYesNoNo.Processed Patient Number 1761
#
# NoNoNoYesNoNo.No.Processed Patient Number 1762
#
# No.No.NoNoProcessed Patient Number 1763
#
# NoYes.NoProcessed Patient Number 1764
#
# NoNoYesYesYes.YesYesNo.Processed Patient Number 1765
#
# NoYesYesNoNoProcessed Patient Number 1766
#
# NoYesNo.Processed Patient Number 1767
#
# NoNo.NoNo.No.NoProcessed Patient Number 1768
#
# NoNo.YesYesNoNoNoProcessed Patient Number 1769
#
# NoYesNo.No.NoNoNoNoProcessed Patient Number 1770
#
# NoNoNoNoNoProcessed Patient Number 1771
#
# No.NoNoNoNoProcessed Patient Number 1772
#
# NoYesNoNoNo.Processed Patient Number 1773
#
# NoNoNo.No.NoNoNoNo.YesYesYesYesProcessed Patient Number 1774
#
# NoNo.NoYesYesYesNoYes.Processed Patient Number 1775
#
# NoNoNoNoYesProcessed Patient Number 1776
#
# NoNoYes.NoProcessed Patient Number 1777
#
# No.YesNo.Processed Patient Number 1778
#
# No.NoNoNo.NoNoNoProcessed Patient Number 1779
#
# No.No.NoNoNoProcessed Patient Number 1780
#
# YesNoYesProcessed Patient Number 1781
#
# NoNoNoNoNoNo.Processed Patient Number 1782
#
# NoNo.NoNoNoNoNoNoNoProcessed Patient Number 1783
#
# No.YesNoNo.NoNoNoProcessed Patient Number 1784
#
# NoNoNoNoProcessed Patient Number 1785
#
# No.NoNoNoNo.NoNoProcessed Patient Number 1786
#
# No.YesNoYesYesYesProcessed Patient Number 1787
#
# NoYesYes.NoNoProcessed Patient Number 1788
#
# NoNoNoNoProcessed Patient Number 1789
#
# YesNoNoNoNoYesNoNoProcessed Patient Number 1790
#
# NoYes.YesYesYes.Processed Patient Number 1791
#
# NoNo.NoNo.No.Processed Patient Number 1792
#
# NoYesNoNoNoNoProcessed Patient Number 1793
#
# No.No.No.Processed Patient Number 1794
#
# NoNo.Processed Patient Number 1795
#
# No.YesYesYesYesNo.Processed Patient Number 1796
#
# No.YesYesYesProcessed Patient Number 1797
#
# No.No.YesYesYesYes.Processed Patient Number 1798
#
# NoYes.Yes.NoNoProcessed Patient Number 1799
#
# No.YesNoNo.YesNoNoProcessed Patient Number 1800
#
# No.NoNoNoNoNo.NoNo.NoNoNoProcessed Patient Number 1801
#
# No.NoNoNo.Processed Patient Number 1802
#
# No.No.YesNoYesYesYesYesYesProcessed Patient Number 1803
#
# No.No.YesNoYesProcessed Patient Number 1804
#
# NoNoNoNo.NoProcessed Patient Number 1805
#
# NoNoNoNo.YesProcessed Patient Number 1806
#
# NoYes.YesYesNoYes.Processed Patient Number 1807
#
# No.No.YesNoYes.Processed Patient Number 1808
#
# NoNoNo.Processed Patient Number 1809
#
# No.YesNo.Processed Patient Number 1810
#
# NoNoNoNoProcessed Patient Number 1811
#
# No.NoYesYesYesNo.Processed Patient Number 1812
#
# NoNoYesYesYes.Processed Patient Number 1813
#
# No.YesNoProcessed Patient Number 1814
#
# NoNoYesNoNoNoNo.Processed Patient Number 1815
#
# No.YesYesYesNoYesProcessed Patient Number 1816
#
# No.NoYesNo.Processed Patient Number 1817
#
# No.NoNoYesNo.NoNoYesNoYesProcessed Patient Number 1818
#
# No.NoNoNoProcessed Patient Number 1819
#
# NoYesNo.NoProcessed Patient Number 1820
#
# NoNoNoNo.No.No.Processed Patient Number 1821
#
# NoNo.YesNoYesNoNoProcessed Patient Number 1822
#
# NoYesYesYes.NoProcessed Patient Number 1823
#
# NoYes.YesYes.Processed Patient Number 1824
#
# NoNo.YesNoNoProcessed Patient Number 1825
#
# No.No.NoProcessed Patient Number 1826
#
# No.NoNoNoNoNoProcessed Patient Number 1827
#
# NoNoYesNoProcessed Patient Number 1828
#
# NoYesNoNo.No.Processed Patient Number 1829
#
# No.No.NoNo.No.YesNoNoNoProcessed Patient Number 1830
#
# NoYesYesNoNoNoYesProcessed Patient Number 1831
#
# NoNoYesNo.Processed Patient Number 1832
#
# NoYesYesNoProcessed Patient Number 1833
#
# NoNo.NoNo.Processed Patient Number 1834
#
# NoYesYesNo.YesYesNoYesNoProcessed Patient Number 1835
#
# NoYesYesNo.Processed Patient Number 1836
#
# No.NoNo.NoProcessed Patient Number 1837
#
# NoYesNoYesProcessed Patient Number 1838
#
# No.NoNoNoNoNoYesProcessed Patient Number 1839
#
# No.YesNoProcessed Patient Number 1840
#
# NoYesNoNoNoNo.Processed Patient Number 1841
#
# No.NoNoNoNoProcessed Patient Number 1842
#
# NoNoNoNoNo.NoNoProcessed Patient Number 1843
#
# NoNo.NoYesNo.NoNoNoNo.NoProcessed Patient Number 1844
#
# NoNoNoNoYesYesNo.Processed Patient Number 1845
#
# NoYesNo.NoNoProcessed Patient Number 1846
#
# NoYesNoNo.No.Processed Patient Number 1847
#
# NoYesNoNoNoProcessed Patient Number 1848
#
# NoNo.NoYesNoProcessed Patient Number 1849
#
# No.YesYesYesNoYes.Processed Patient Number 1850
#
# NoYesYesYesProcessed Patient Number 1851
#
# NoNo.No.Yes.YesYesNoProcessed Patient Number 1852
#
# NoNo.Yes.YesYesNoYes.Processed Patient Number 1853
#
# NoNoNoNoNoNoNoProcessed Patient Number 1854
#
# NoNoNoNoYesNoProcessed Patient Number 1855
#
# No.NoNoNoNoNoProcessed Patient Number 1856
#
# NoNo.NoNoNoYesProcessed Patient Number 1857
#
# No.Yes.NoYesNo.Processed Patient Number 1858
#
# No.NoNoNoNoNo.Processed Patient Number 1859
#
# No.YesNoNoNo.No.Processed Patient Number 1860
#
# No.NoYesNoProcessed Patient Number 1861
#
# NoYesNoNoNoNoProcessed Patient Number 1862
#
# No.YesNoYesYesYesYesNoProcessed Patient Number 1863
#
# No.NoNo.YesProcessed Patient Number 1864
#
# No.YesYesYesYesYesYesProcessed Patient Number 1865
#
# NoNoNoNo.NoNoProcessed Patient Number 1866
#
# NoYesYesNoYesNo.Processed Patient Number 1867
#
# NoYesNoNo.Processed Patient Number 1868
#
# NoYesYesYesYesYesProcessed Patient Number 1869
#
# NoNoNoNoNoProcessed Patient Number 1870
#
# NoNoNoNoNoNo.NoProcessed Patient Number 1871
#
# NoYesNoYesProcessed Patient Number 1872
#
# NoYesNoNoNoProcessed Patient Number 1873
#
# NoYes.YesNoProcessed Patient Number 1874
#
# NoYesNoNoNo.Processed Patient Number 1875
#
# No.YesNoYesNoNoProcessed Patient Number 1876
#
# No.YesNoNo.Processed Patient Number 1877
#
# No.No.No.YesNoProcessed Patient Number 1878
#
# No.YesYesYesYes.Processed Patient Number 1879
#
# No.Yes.No.YesNoNoNoProcessed Patient Number 1880
#
# NoYesNoNoNoNoProcessed Patient Number 1881
#
# No.No.NoYesYesProcessed Patient Number 1882
#
# No.YesYesYesYesNoProcessed Patient Number 1883
#
# No.YesYesNoYesNoNoNo.Processed Patient Number 1884
#
# NoYesNoNoNo.NoProcessed Patient Number 1885
#
# NoNoNoNoProcessed Patient Number 1886
#
# NoNo.NoNo.YesNoNoProcessed Patient Number 1887
#
# No.NoNoNoNoNoProcessed Patient Number 1888
#
# NoNoNoNoNoNo.Processed Patient Number 1889
#
# NoNoNoNo.Processed Patient Number 1890
#
# NoNo.No.Processed Patient Number 1891
#
# NoNoProcessed Patient Number 1892
#
# NoYes.YesYesYesYesProcessed Patient Number 1893
#
# NoNoNoNo.NoProcessed Patient Number 1894
#
# NoNo.No.YesNo.Processed Patient Number 1895
#
# No.NoYesYesYesYesProcessed Patient Number 1896
#
# No.No.Yes.Processed Patient Number 1897
#
# NoNoNoYesNoYesYesProcessed Patient Number 1898
#
# No.NoNoNoYesNoProcessed Patient Number 1899
#
# NoYesNoYesNoNoProcessed Patient Number 1900
#
# NoNoNoNoNoNoNo.NoProcessed Patient Number 1901
#
# No.NoNoNoNoNoNoNoNo.Processed Patient Number 1902
#
# No.No.NoNoNoNoNo.No.Processed Patient Number 1903
#
# No.NoYesYesYesProcessed Patient Number 1904
#
# NoNoYesProcessed Patient Number 1905
#
# NoYesYesYesNoYesNo.YesNoProcessed Patient Number 1906
#
# No.No.YesNo.Processed Patient Number 1907
#
# NoNo.NoNoNoProcessed Patient Number 1908
#
# NoYesYesNoProcessed Patient Number 1909
#
# NoNoNoYesNoYes.NoProcessed Patient Number 1910
#
# NoNoNoNoNoProcessed Patient Number 1911
#
# NoYesYesNoNoNoNo.Processed Patient Number 1912
#
# No.NoNo.YesNoProcessed Patient Number 1913
#
# No.Yes.NoNoNoNoNoNoNoProcessed Patient Number 1914
#
# NoNoNoNoNoNoProcessed Patient Number 1915
#
# No.YesProcessed Patient Number 1916
#
# NoNoNoNoNoNoProcessed Patient Number 1917
#
# NoNoNo.NoProcessed Patient Number 1918
#
# NoNo.NoProcessed Patient Number 1919
#
# NoYesNoYesYesNoProcessed Patient Number 1920
#
# No.YesNoNo.NoNo.No.Processed Patient Number 1921
#
# NoYesYesNoNoProcessed Patient Number 1922
#
# NoYesNoNoNoNo.NoNoYesNoNoNoProcessed Patient Number 1923
#
# No.NoYes.Processed Patient Number 1924
#
# NoYesNo.No.Processed Patient Number 1925
#
# No.No.No.NoNoNoProcessed Patient Number 1926
#
# No.YesNoProcessed Patient Number 1927
#
# YesYesNoNoYesNoNoProcessed Patient Number 1928
#
# NoNoNoNo.Processed Patient Number 1929
#
# No.YesYesNo.Processed Patient Number 1930
#
# No.No.No.NoNoProcessed Patient Number 1931
#
# No.NoNo.NoNoNo.Processed Patient Number 1932
#
# NoYesYesYesYesYesYesProcessed Patient Number 1933
#
# No.YesYesYesYesYes.Processed Patient Number 1934
#
# No.NoNONo.NoNoYesProcessed Patient Number 1935
#
# NoYesYesProcessed Patient Number 1936
#
# NoNoNoNoNoNoNoNoProcessed Patient Number 1937
#
# No.NoNoNoProcessed Patient Number 1938
#
# YesNoNoNoNoProcessed Patient Number 1939
#
# No.NoYesNoYesYesYesYesProcessed Patient Number 1940
#
# NoYesNoProcessed Patient Number 1941
#
# NoNoNoNoProcessed Patient Number 1942
#
# NoYesNoProcessed Patient Number 1943
#
# NoNoNoNoNoProcessed Patient Number 1944
#
# NoNoNoNoNo.Processed Patient Number 1945
#
# NoNo.NoNoNoNo.Processed Patient Number 1946
#
# NoYesNoNoNoNoProcessed Patient Number 1947
#
# NoYesNoNoProcessed Patient Number 1948
#
# YesNo.Processed Patient Number 1949
#
# NoNoNoNoNoNoNo.NoProcessed Patient Number 1950
#
# No.NoYesNoNoProcessed Patient Number 1951
#
# No.Yes.No.Processed Patient Number 1952
#
# No.NoNoNo.NoNoProcessed Patient Number 1953
#
# NoYesYesNoProcessed Patient Number 1954
#
# No.NoYesYesProcessed Patient Number 1955
#
# No.YesNo.NoProcessed Patient Number 1956
#
# No.Yes.No.Processed Patient Number 1957
#
# NoNoNoNo.NoNo.NoProcessed Patient Number 1958
#
# NoNo.NoProcessed Patient Number 1959
#
# NoNoNoNoProcessed Patient Number 1960
#
# NoYesYesNoYesNo.Processed Patient Number 1961
#
# YesYesYesYesProcessed Patient Number 1962
#
# NoNoNo.NoNoProcessed Patient Number 1963
#
# No.NoNo.Processed Patient Number 1964
#
# NoNo.NoNoNo.Processed Patient Number 1965
#
# NoNoNo.NoNoNoNoProcessed Patient Number 1966
#
# NoNoYesProcessed Patient Number 1967
#
# No.No.NoNo.NoNoProcessed Patient Number 1968
#
# NoNoNoNoProcessed Patient Number 1969
#
# No.NoNo.NoNoYesNo.YesNoNoProcessed Patient Number 1970
#
# NoNo.YesNoYesProcessed Patient Number 1971
#
# NoYesYesYesProcessed Patient Number 1972
#
# NoNoNoNoProcessed Patient Number 1973
#
# No.Yes.YesNo.YesYesProcessed Patient Number 1974
#
# No.YesNoNoYes.NoProcessed Patient Number 1975
#
# NoNoNoNoNoYesYesNoProcessed Patient Number 1976
#
# No.YesNo.YesNo.Processed Patient Number 1977
#
# NoNoNoNoProcessed Patient Number 1978
#
# NoYesYesNoProcessed Patient Number 1979
#
# NoYesNoNo.Processed Patient Number 1980
#
# No.No.No.NoNoNo.NoNo.NoProcessed Patient Number 1981
#
# No.Yes.YesYesNoNoProcessed Patient Number 1982
#
# NoNoNoNoProcessed Patient Number 1983
#
# NoNoNo.NoNo.NoNoNo.No.Processed Patient Number 1984
#
# NoNo.NoNoProcessed Patient Number 1985
#
# NoYesYesProcessed Patient Number 1986
#
# NoNo.NoYes.NoNoNoProcessed Patient Number 1987
#
# YesYesYesProcessed Patient Number 1988
#
# NoYes.No.YesYesNoProcessed Patient Number 1989
#
# NoYes.No.Processed Patient Number 1990
#
# NoYesYesYesYesNo.Processed Patient Number 1991
#
# NoNoNo.No.No.NoYesNoProcessed Patient Number 1992
#
# NoNoYesNoNoNo.NoNoProcessed Patient Number 1993
#
# NoNo.YesProcessed Patient Number 1994
#
# YesYesYesYesYesProcessed Patient Number 1995
#
# No.NoNoNo.Processed Patient Number 1996
#
# NoYesNo.YesYesYesProcessed Patient Number 1997
#
# NoYesNo.Processed Patient Number 1998
#
# No.NoYesNoNo.NoProcessed Patient Number 1999
#
# NoNo.Processed Patient Number 2000
#
# No.NoNo.NoProcessed Patient Number 2001
#
# NoNoNoYesYesNoProcessed Patient Number 2002
#
# No.Yes.No.No.YesNoProcessed Patient Number 2003
#
# NoNo.YesNoNoNoProcessed Patient Number 2004
#
# No.YesNo.No.Processed Patient Number 2005
#
# No.YesNo.Processed Patient Number 2006
#
# NoYesNoNoNoYesProcessed Patient Number 2007
#
# YesYesYes.NoNoNoNoProcessed Patient Number 2008
#
# NoNo.NoNoNoNoProcessed Patient Number 2009
#
# No.NoNo.NoNoProcessed Patient Number 2010
#
# NoYesNoYes.YesNoNoNoProcessed Patient Number 2011
#
# No.NoNoNo.YesNoYes.YesProcessed Patient Number 2012
#
# NoYesYesYesNo.Processed Patient Number 2013
#
# No.Yes.NoNo.Processed Patient Number 2014
#
# NoNoNo.YesNoNo.YesNo.YesProcessed Patient Number 2015
#
# No.YesYesProcessed Patient Number 2016
#
# NoYesYesYesYesProcessed Patient Number 2017
#
# No.YesYesNoNo.Processed Patient Number 2018
#
# NoYesYesYesYesYesNoProcessed Patient Number 2019
#
# No.No.NoNoProcessed Patient Number 2020
