# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, roc_auc_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Initialise GPU

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Data Loading and Pre-processing

# %%
# Class for pre-processing the data
class MIMICDataProcessor:
    def __init__(self, file_path, batch_size=64):
        self.file_path = file_path
        self.batch_size = batch_size
        self.scaler = StandardScaler()

        # Load and preprocess the data
        self.df = pd.read_csv(file_path)
        # Replace all missing values with 0
        self.df.fillna(0, inplace=True)

        # Features
        self.X = self.df[['upper_respiratory_infections', 'influenza_pneumonia', 'acute_lower_respiratory_infections', 'chronic_lower_respiratory_diseases',
                          'lung_diseases_due_to_external_agents', 'other_respiratory_diseases', 'InvasiveVent', 'SupplementalOxygen', 'HFNC',
                          'NonInvasiveVent', 'Tracheostomy', 'None', 'avg_uo_24hr', 'avg_creatinine_max', 'max_renal_uo_24hr', 'max_renal_creatinine_max',
                          'avg_pao2fio2ratio_novent', 'avg_pao2fio2ratio_vent', 'max_respiration_pao2fio2ratio_novent', 'max_respiration_pao2fio2ratio_vent', 'avg_gcs_min', 'max_cns_gcs_min',
                          'sofa_score', 'suspected_infection', 'one_vasopressor', 'multi_vasopressor']]

        # Concepts
        self.C = self.df[['c_rsp_mod', 'c_rsp_svr', 'c_vent_low', 'c_vent_moderate', 'c_vent_high', 'c_max_renf_moderate', 'c_max_renf_severe',
                          'c_avg_renf_moderate', 'c_avg_renf_severe', 'c_max_respf_moderate', 'c_max_respf_severe', 'c_avg_respf_moderate',
                          'c_avg_respf_severe', 'c_max_cnsf_moderate', 'c_max_cnsf_severe', 'c_avg_cnsf_moderate', 'c_avg_cnsf_severe',
                          'c_sepsis3', 'c_shock']]

        # Label
        self.Y = self.df['ARDS']


        # Convert to tensors
        self.X_tensor = torch.tensor(self.X.values, dtype=torch.float32)
        self.C_tensor = torch.tensor(self.C.values, dtype=torch.float32)
        self.Y_tensor = torch.tensor(self.Y.values, dtype=torch.float32)

        # Normalize the features
        self.X_scaled = self.scaler.fit_transform(self.X)
        self.X_tensor_scaled = torch.tensor(self.X_scaled, dtype=torch.float32)

    def get_features(self):
        return self.X.columns.tolist()

    def get_concepts(self):
        return self.C.columns.tolist()

    def get_labels(self):
        return self.Y.columns.tolist()

    # Dataset class needed to provide the __getitem__ method for DataLoader
    class MIMICDataset(Dataset):
        def __init__(self, x, c, y):
            self.x = x
            self.c = c
            self.y = y

        def __len__(self):
            return len(self.y)

        def __getitem__(self, idx):
            return self.x[idx], self.c[idx], self.y[idx]

    def create_dataloaders(self):
        # Split the data into temporary (80%) and test (20%) sets
        X_temp, X_test, C_temp, C_test, Y_temp, Y_test = train_test_split(
            self.X_tensor_scaled, self.C_tensor, self.Y_tensor, test_size=0.20, random_state=42)

        # Further split the temporary data into training (75% of temporary) and validation (25% of temporary) sets
        X_train, X_val, C_train, C_val, Y_train, Y_val = train_test_split(
            X_temp, C_temp, Y_temp, test_size=0.25, random_state=42)

        train_dataset = self.MIMICDataset(X_train, C_train, Y_train)
        val_dataset = self.MIMICDataset(X_val, C_val, Y_val)
        test_dataset = self.MIMICDataset(X_test, C_test, Y_test)

        train_loader = DataLoader(train_dataset, batch_size=self.batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=self.batch_size, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=self.batch_size, shuffle=False)

        return train_loader, val_loader, test_loader

# %% [markdown]
# # Model

# %%
class MultiLabelNN(nn.Module):
    def __init__(self, num_features, num_labels):
        super(MultiLabelNN, self).__init__()
        self.layer1 = nn.Linear(num_features, 32)
        self.layer2 = nn.Linear(32, 64)
        self.output_layer = nn.Linear(64, num_labels)

    def forward(self, x):
        x = torch.relu(self.layer1(x))
        x = torch.relu(self.layer2(x))
        x = torch.sigmoid(self.output_layer(x))  # Sigmoid activation to output probabilities for each label
        return x

# %% [markdown]
# # Training
#
# Look at the Step 5 from this [basic code](https://colab.research.google.com/drive/1LqE89tPVt6h1wa7lerLgF4GNvRw9QFDw?usp=sharing) for reference.

# %%
def train(x_size, c_size, y_size, x_to_c_learning_rate, c_to_y_learning_rate, weight_decay, epochs, train_loader, val_loader):
    torch.manual_seed(25)

    x_to_c = MultiLabelNN(num_features=x_size, num_labels=c_size).to(device)
    c_to_y = MultiLabelNN(num_features=c_size, num_labels=y_size).to(device)

    criterion = nn.BCELoss()
    x_to_c_optimizer = torch.optim.Adam(x_to_c.parameters(), lr=x_to_c_learning_rate, weight_decay=weight_decay)
    c_to_y_optimizer = torch.optim.Adam(c_to_y.parameters(), lr=c_to_y_learning_rate, weight_decay=weight_decay)
    x_to_c_scheduler = StepLR(x_to_c_optimizer, step_size=10, gamma=0.1)
    c_to_y_scheduler = StepLR(c_to_y_optimizer, step_size=10, gamma=0.1)

    epochs_count = []
    x_to_c_loss_values, c_to_y_loss_values = [], []
    x_to_c_predictions, c_to_y_predictions = [], []
    x_to_c_val_loss_values, c_to_y_val_loss_values = [], []
    x_to_c_val_predictions, c_to_y_val_predictions = [], []
    ground_truth_val_c, ground_truth_val_y = [], []

    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")  # Print current epoch
        epochs_count.append(epoch)

        # Training Loop
        x_to_c.train()
        c_to_y.train()

        running_x_to_c_loss, running_c_to_y_loss = 0.0, 0.0
        total_samples = 0

        for i, batch in enumerate(train_loader):
            x, c, y = batch
            x, c, y = x.to(device), c.to(device), y.to(device)

            # Forward pass through x_to_c
            x_to_c_optimizer.zero_grad()
            x = x.to(x_to_c.layer1.weight.dtype)
            predicted_c = x_to_c(x)
            x_to_c_predictions.append(predicted_c.detach().cpu().numpy())
            c_loss = criterion(predicted_c, c.float())

            # Backward pass through x_to_c
            c_loss.backward()
            x_to_c_optimizer.step()

            # Forward pass through c_to_y
            c_to_y_optimizer.zero_grad()
            predicted_y = c_to_y(c)
            c_to_y_predictions.append(predicted_y.detach().cpu().numpy())
            y_loss = criterion(predicted_y, y.unsqueeze(1).float())

            # Backward pass through c_to_y
            y_loss.backward()
            c_to_y_optimizer.step()

            # Accumulate loss values
            running_x_to_c_loss += c_loss.item()
            running_c_to_y_loss += y_loss.item()

            total_samples += len(y)

        x_to_c_loss_values.append(running_x_to_c_loss / len(train_loader))
        c_to_y_loss_values.append(running_c_to_y_loss / len(train_loader))

        x_to_c_scheduler.step()
        c_to_y_scheduler.step()

        # Validation Loop
        x_to_c.eval()
        c_to_y.eval()

        running_x_to_c_val_loss, running_c_to_y_val_loss = 0.0, 0.0
        total_val_samples = 0

        with torch.no_grad():
            for x, c, y in val_loader:
                x, c, y = x.to(device), c.to(device), y.to(device)

                ground_truth_val_c.append(c.cpu())
                ground_truth_val_y.append(y.cpu())

                # Forward pass through x_to_c
                predicted_c = x_to_c(x.to(dtype=x_to_c.layer1.weight.dtype))
                x_to_c_val_predictions.append(predicted_c.detach().cpu().numpy())
                c_loss = criterion(predicted_c, c.float())

                running_x_to_c_val_loss += c_loss.item()

                # Forward pass through c_to_y
                predicted_y = c_to_y(c)
                c_to_y_val_predictions.append(predicted_y.detach().cpu().numpy())
                y_loss = criterion(predicted_y, y.unsqueeze(1).float())

                running_c_to_y_val_loss += y_loss.item()
                total_val_samples += len(y)

        x_to_c_val_loss_values.append(running_x_to_c_val_loss / len(val_loader))
        c_to_y_val_loss_values.append(running_c_to_y_val_loss / len(val_loader))

    return (x_to_c, c_to_y, epochs_count, x_to_c_loss_values, c_to_y_loss_values, x_to_c_predictions, c_to_y_predictions, x_to_c_val_loss_values, c_to_y_val_loss_values, x_to_c_val_predictions, c_to_y_val_predictions, ground_truth_val_c, ground_truth_val_y)

# %%
# Specify Parameters
x_size = 26
c_size = 19
y_size = 1
x_to_c_learning_rate = 0.01
c_to_y_learning_rate = 0.01
weight_decay = 0.0001
epochs = 60

# Load Data
file_path = '/content/augmented-ards-data.csv'
data_processor = MIMICDataProcessor(file_path, batch_size=64)
train_loader, test_loader, val_loader = data_processor.create_dataloaders()

x_to_c, c_to_y, epochs_count, x_to_c_loss_values, c_to_y_loss_values, x_to_c_predictions, c_to_y_predictions, x_to_c_val_loss_values, c_to_y_val_loss_values, x_to_c_val_predictions, c_to_y_val_predictions, ground_truth_val_c, ground_truth_val_y = train(x_size, c_size, y_size, x_to_c_learning_rate, c_to_y_learning_rate, weight_decay, epochs, train_loader, val_loader)
# Out:
# Epoch 1/60
# Epoch 2/60
# Epoch 3/60
# Epoch 4/60
# Epoch 5/60
# Epoch 6/60
# Epoch 7/60
# Epoch 8/60
# Epoch 9/60
# Epoch 10/60
# Epoch 11/60
# Epoch 12/60
# Epoch 13/60
# Epoch 14/60
# Epoch 15/60
# Epoch 16/60
# Epoch 17/60
# Epoch 18/60
# Epoch 19/60
# Epoch 20/60
# Epoch 21/60
# Epoch 22/60
# Epoch 23/60
# Epoch 24/60
# Epoch 25/60
# Epoch 26/60
# Epoch 27/60
# Epoch 28/60
# Epoch 29/60
# Epoch 30/60
# Epoch 31/60
# Epoch 32/60
# Epoch 33/60
# Epoch 34/60
# Epoch 35/60
# Epoch 36/60
# Epoch 37/60
# Epoch 38/60
# Epoch 39/60
# Epoch 40/60
# Epoch 41/60
# Epoch 42/60
# Epoch 43/60
# Epoch 44/60
# Epoch 45/60
# Epoch 46/60
# Epoch 47/60
# Epoch 48/60
# Epoch 49/60
# Epoch 50/60
# Epoch 51/60
# Epoch 52/60
# Epoch 53/60
# Epoch 54/60
# Epoch 55/60
# Epoch 56/60
# Epoch 57/60
# Epoch 58/60
# Epoch 59/60
# Epoch 60/60

# %% [markdown]
# # Plotting Loss

# %%
plt.figure(figsize=(12, 6))
plt.plot(epochs_count, x_to_c_loss_values, label='Training Concept Model Loss')
plt.plot(epochs_count, c_to_y_loss_values, label='Training Label Model Loss')
plt.plot(epochs_count, x_to_c_val_loss_values, label='Validation Concept Predictor Loss')
plt.plot(epochs_count, c_to_y_val_loss_values, label='Validation Label Predictor Loss')
plt.title('Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_count, x_to_c_loss_values, label='Concept Model Loss')
plt.plot(epochs_count, c_to_y_loss_values, label='Label Model Loss')
plt.title('Training Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Testing loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_count, x_to_c_val_loss_values, label='Concept Predictor Loss')
plt.plot(epochs_count, c_to_y_val_loss_values, label='Label Predictor Loss')
plt.title('Testing Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Completeness Score

# %%
from sklearn.metrics import mutual_info_score
import numpy as np

def compute_mutual_information(true_labels, predicted_values):
    # Convert the predicted values to binary classes
    predicted_classes = (predicted_values > 0.5).astype(int)
    return mutual_info_score(true_labels, predicted_classes)

# Compute mutual information I(y; c)
def compute_I_y_c(ground_truth_val_y, c_to_y_val_predictions):
    true_values = np.concatenate([gy.numpy() for gy in ground_truth_val_y])
    predicted_values = np.concatenate([py.squeeze() for py in c_to_y_val_predictions])
    return compute_mutual_information(true_values, predicted_values)

# Compute mutual information I(y; c, x)
def compute_I_y_c_x(ground_truth_val_y, x_to_c_val_predictions, c_to_y_val_predictions):
    true_values = np.concatenate([gy.numpy() for gy in ground_truth_val_y])

    # Compute mutual information for each concept and label pair
    predicted_concepts = np.concatenate(x_to_c_val_predictions)
    predicted_labels = np.concatenate([py.squeeze() for py in c_to_y_val_predictions])

    combined_predictions = np.column_stack((predicted_concepts, predicted_labels))

    # Flatten combined_predictions to make it 1D
    combined_predictions_flat = combined_predictions.flatten()

    return mutual_info_score(true_values, combined_predictions_flat[:len(true_values)])

# Compute the Completeness Score
def compute_completeness_score(I_y_c, I_y_c_x):
    return I_y_c / I_y_c_x

# Calculate mutual information
I_y_c = compute_I_y_c(ground_truth_val_y, c_to_y_val_predictions)
print(f"Mutual Information I(y; c): {I_y_c}")

I_y_c_x = compute_I_y_c_x(ground_truth_val_y, x_to_c_val_predictions, c_to_y_val_predictions)
print(f"Mutual Information I(y; c, x): {I_y_c_x}")

# Calculate completeness score
completeness_score = compute_completeness_score(I_y_c, I_y_c_x)
print(f"Completeness Score: {completeness_score}")
# Out:
# Mutual Information I(y; c): 0.01740116220522253
# Mutual Information I(y; c, x): 0.6607105543136904
# Completeness Score: 0.02633704288755898
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Validation Evaluation

# %%
# Concept Predictor Evaluation
def evaluate_concept_predictor(ground_truth_c, x_to_c_predictions, concept_labels):
    results = []
    for i, label in enumerate(concept_labels):
        true_values = np.concatenate([c[:, i].numpy() for c in ground_truth_c])
        predicted_values = np.concatenate([c[:, i] for c in x_to_c_predictions])

        predicted_classes = (predicted_values > 0.5).astype(int)  # Convert probabilities to binary classes

        precision = precision_score(true_values, predicted_classes, zero_division=0)
        recall = recall_score(true_values, predicted_classes, zero_division=0)
        f1 = f1_score(true_values, predicted_classes, zero_division=0)
        accuracy = accuracy_score(true_values, predicted_classes)

        results.append({
            "Label": label,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "Accuracy": accuracy
        })
    return pd.DataFrame(results)

# %%
# Get concept labels from the data processor
concept_labels = data_processor.get_concepts()

# Evaluation
concept_predictor_results = evaluate_concept_predictor(ground_truth_val_c, x_to_c_val_predictions, concept_labels)
print("Validation Concept Predictor Results:")
print(concept_predictor_results)
# Out:
# Validation Concept Predictor Results:
#                    Label  Precision    Recall  F1 Score  Accuracy
# 0              c_rsp_mod   0.961561  0.978328  0.969872  0.954527
# 1              c_rsp_svr   0.998725  0.955081  0.976416  0.990658
# 2             c_vent_low   0.995569  0.992673  0.994119  0.991358
# 3        c_vent_moderate   0.998416  0.972531  0.985303  0.996132
# 4            c_vent_high   0.998761  1.000000  0.999380  0.998765
# 5    c_max_renf_moderate   0.909091  0.744361  0.818520  0.891605
# 6      c_max_renf_severe   0.907981  0.884505  0.896089  0.906296
# 7    c_avg_renf_moderate   0.502336  0.127976  0.203985  0.930947
# 8      c_avg_renf_severe   0.671049  0.731667  0.700048  0.922593
# 9   c_max_respf_moderate   0.852437  0.539167  0.660541  0.972634
# 10    c_max_respf_severe   0.974860  0.997143  0.985876  0.972840
# 11  c_avg_respf_moderate   0.786610  0.765120  0.775716  0.894033
# 12    c_avg_respf_severe   0.927450  0.924188  0.925817  0.887366
# 13   c_max_cnsf_moderate   0.847222  0.805145  0.825648  0.874897
# 14     c_max_cnsf_severe   0.956359  0.975076  0.965627  0.962634
# 15   c_avg_cnsf_moderate   0.981481  0.147222  0.256039  0.987325
# 16     c_avg_cnsf_severe   0.000000  0.000000  0.000000  0.997531
# 17             c_sepsis3   0.997416  1.000000  0.998706  0.997531
# 18               c_shock   0.980099  0.993719  0.986862  0.977984

# %%
# Label Predictor Evaluation
def evaluate_label_predictor(ground_truth_y, c_to_y_predictions):
    # Ensure all elements are tensors
    ground_truth_y = [torch.tensor(gy) if not isinstance(gy, torch.Tensor) else gy for gy in ground_truth_y]
    c_to_y_predictions = [torch.tensor(py) if not isinstance(py, torch.Tensor) else py for py in c_to_y_predictions]

    true_values = torch.cat(ground_truth_y).numpy()
    predicted_values = torch.cat(c_to_y_predictions).squeeze().numpy()

    predicted_classes = (predicted_values > 0.5).astype(int)  # Convert probabilities to binary classes

    precision = precision_score(true_values, predicted_classes)
    recall = recall_score(true_values, predicted_classes)
    f1 = f1_score(true_values, predicted_classes)
    auc = roc_auc_score(true_values, predicted_classes)
    accuracy = accuracy_score(true_values, predicted_classes)

    results = {"Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "AUC": auc,
        "Accuracy": accuracy}

    index = pd.Index(["Metrics"])
    return pd.DataFrame(results, index=index)

# %%
# Evaluation
print("Validation Label Predictor Results:")
label_predictor_results = evaluate_label_predictor(ground_truth_val_y, c_to_y_val_predictions)
print(label_predictor_results)
# Out:
# Validation Label Predictor Results:
#          Precision   Recall  F1 Score       AUC  Accuracy
# Metrics   0.603813  0.61874  0.611186  0.592916  0.593745

# %% [markdown]
# # Testing Evaluation

# %%
def test_model(x_to_c, c_to_y, test_loader):
    x_to_c.eval()  # Set the concept predictor model to evaluation mode
    c_to_y.eval()  # Set the label predictor model to evaluation mode
    criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for classification

    running_x_to_c_test_loss, running_c_to_y_test_loss = 0.0, 0.0
    total_test_samples = 0
    ground_truth_test_c, ground_truth_test_y = [], []
    x_to_c_test_predictions, c_to_y_test_predictions = [], []

    with torch.no_grad():
        for x, c, y in test_loader:
            # GPU
            x, c, y = x.to(device), c.to(device), y.to(device)

            # Ground truth array
            ground_truth_test_c.append(c.cpu())
            ground_truth_test_y.append(y.cpu())

            # Forward pass through x_to_c
            x = x.to(x_to_c.layer1.weight.dtype)  # ensure data type of input tensor x matches data type of weights of the first linear layer
            predicted_c = x_to_c(x)
            x_to_c_test_predictions.append(predicted_c.detach().cpu().numpy())
            c_loss = criterion(predicted_c, c.float())

            # Accumulate x_to_c loss for testing
            running_x_to_c_test_loss += c_loss.item()

            # Forward pass through c_to_y
            predicted_c_detached = predicted_c.detach()  # Detach the predicted_c tensor
            predicted_y = c_to_y(predicted_c_detached)
            c_to_y_test_predictions.append(predicted_y.detach().cpu().numpy())
            y_loss = criterion(predicted_y, y.unsqueeze(1).float())

            # Accumulate c_to_y loss for testing
            running_c_to_y_test_loss += y_loss.item()
            total_test_samples += len(y)

    print(f'Test Concept Predictor Loss: {running_x_to_c_test_loss / len(test_loader):.4f}')
    print(f'Test Label Predictor Loss: {running_c_to_y_test_loss / len(test_loader):.4f}')

    return ground_truth_test_c, ground_truth_test_y, x_to_c_test_predictions, c_to_y_test_predictions

# %%
# Call the test function and print the results
ground_truth_test_c, ground_truth_test_y, x_to_c_test_predictions, c_to_y_test_predictions = test_model(x_to_c, c_to_y, test_loader)
# Out:
# Test Concept Predictor Loss: 0.1087
# Test Label Predictor Loss: 0.6456

# %%
# Evaluate and print test results for the concept predictor
concept_test_results = evaluate_concept_predictor(ground_truth_test_c, x_to_c_test_predictions, concept_labels)
print("Test Concept Predictor Results:")
print(concept_test_results)
# Out:
# Test Concept Predictor Results:
#                    Label  Precision    Recall  F1 Score  Accuracy
# 0              c_rsp_mod   0.990132  0.961661  0.975689  0.962871
# 1              c_rsp_svr   1.000000  1.000000  1.000000  1.000000
# 2             c_vent_low   0.996774  0.996774  0.996774  0.995050
# 3        c_vent_moderate   1.000000  0.962264  0.980769  0.995050
# 4            c_vent_high   0.997525  1.000000  0.998761  0.997525
# 5    c_max_renf_moderate   0.931034  0.812030  0.867470  0.918317
# 6      c_max_renf_severe   0.912371  0.903061  0.907692  0.910891
# 7    c_avg_renf_moderate   0.727273  0.181818  0.290909  0.903465
# 8      c_avg_renf_severe   0.728814  0.767857  0.747826  0.928218
# 9   c_max_respf_moderate   0.846154  0.647059  0.733333  0.980198
# 10    c_max_respf_severe   0.984694  0.997416  0.991014  0.982673
# 11  c_avg_respf_moderate   0.928571  0.819820  0.870813  0.933168
# 12    c_avg_respf_severe   0.937294  0.975945  0.956229  0.935644
# 13   c_max_cnsf_moderate   0.823944  0.829787  0.826855  0.878713
# 14     c_max_cnsf_severe   0.964602  0.981982  0.973214  0.970297
# 15   c_avg_cnsf_moderate   1.000000  0.500000  0.666667  0.997525
# 16     c_avg_cnsf_severe   0.000000  0.000000  0.000000  1.000000
# 17             c_sepsis3   1.000000  1.000000  1.000000  1.000000
# 18               c_shock   0.985507  0.994152  0.989811  0.982673

# %%
# Evaluate and print test results for the label predictor
label_test_results = evaluate_label_predictor(ground_truth_test_y, c_to_y_test_predictions)
print("Test Label Predictor Results:")
print(label_test_results)
# Out:
# Test Label Predictor Results:
#          Precision    Recall  F1 Score       AUC  Accuracy
# Metrics   0.590909  0.632432  0.610966  0.631285  0.631188

# %% [markdown]
# # Model Weights

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Function to get weights contribution from each feature to each concept
def get_feature_to_concept_weights(model, feature_names, concept_names):
    layer1_weights = model.layer1.weight.data.cpu().numpy()
    contributions = np.zeros((len(concept_names), len(feature_names)))

    for i, feature in enumerate(feature_names):
        for j, concept in enumerate(concept_names):
            contributions[j, i] = layer1_weights[j, i]

    return pd.DataFrame(contributions, index=concept_names, columns=feature_names)

# Function to get weights contribution from each concept to final label
def get_concept_to_label_weights(model, concept_names, label_names):
    output_weights = model.output_layer.weight.data.cpu().numpy()
    contributions = np.zeros((len(label_names), len(concept_names)))

    for i, concept in enumerate(concept_names):
        for j, label in enumerate(label_names):
            contributions[j, i] = output_weights[j, i]

    return pd.DataFrame(contributions, index=label_names, columns=concept_names)

# Get feature and concept names
feature_names = data_processor.get_features()
concept_names = data_processor.get_concepts()
label_names = ['ARDS']

# Get weights contributions
feature_to_concept_contributions = get_feature_to_concept_weights(x_to_c, feature_names, concept_names)
concept_to_label_contributions = get_concept_to_label_weights(c_to_y, concept_names, label_names)

# Get weights contributions
feature_to_concept_contributions = get_feature_to_concept_weights(x_to_c, feature_names, concept_names)
concept_to_label_contributions = get_concept_to_label_weights(c_to_y, concept_names, label_names)

# %% [markdown]
# A. Feature to Concept

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(feature_to_concept_contributions, cmap='viridis', cbar=True)
plt.title('Feature to Concept Weights Contribution')
plt.xlabel('Features')
plt.ylabel('Concepts')
plt.show()

print("Feature to Concept Weights Contribution:")
print(feature_to_concept_contributions)
# Out:
# Feature to Concept Weights Contribution:
#                       upper_respiratory_infections  influenza_pneumonia  \
# c_rsp_mod                                -0.032095             0.016334
# c_rsp_svr                                -0.052591            -0.003163
# c_vent_low                               -0.060581            -0.391477
# c_vent_moderate                           0.030536             0.244009
# c_vent_high                              -0.019258            -0.082997
# c_max_renf_moderate                       0.005049             0.411055
# c_max_renf_severe                         0.126671            -0.113927
# c_avg_renf_moderate                      -0.065786            -0.371174
# c_avg_renf_severe                        -0.036595            -0.109429
# c_max_respf_moderate                      0.176457             0.601089
# c_max_respf_severe                        0.093238             0.022146
# c_avg_respf_moderate                      0.118564             0.302862
# c_avg_respf_severe                        0.152429            -0.498805
# c_max_cnsf_moderate                      -0.013894            -0.003928
# c_max_cnsf_severe                        -0.230913             0.093246
# c_avg_cnsf_moderate                       0.165657             0.121413
# c_avg_cnsf_severe                         0.028142            -0.037798
# c_sepsis3                                -0.209599            -0.245480
# c_shock                                   0.199689            -0.023460
#
#                       acute_lower_respiratory_infections  \
# c_rsp_mod                                      -0.103031
# c_rsp_svr                                      -0.097821
# c_vent_low                                     -0.189351
# c_vent_moderate                                 0.056608
# c_vent_high                                    -0.022551
# c_max_renf_moderate                             0.146400
# c_max_renf_severe                              -0.051769
# c_avg_renf_moderate                            -0.083290
# c_avg_renf_severe                              -0.067877
# c_max_respf_moderate                           -0.044013
# c_max_respf_severe                             -0.142450
# c_avg_respf_moderate                            0.176374
# c_avg_respf_severe                             -0.240564
# c_max_cnsf_moderate                            -0.125546
# c_max_cnsf_severe                              -0.092450
# c_avg_cnsf_moderate                            -0.058631
# c_avg_cnsf_severe                              -0.074350
# c_sepsis3                                      -0.108298
# c_shock                                        -0.035177
#
#                       chronic_lower_respiratory_diseases  \
# c_rsp_mod                                       0.013240
# c_rsp_svr                                      -0.102829
# c_vent_low                                     -0.168650
# c_vent_moderate                                 0.099474
# c_vent_high                                    -0.211719
# c_max_renf_moderate                             0.416662
# c_max_renf_severe                              -0.277343
# c_avg_renf_moderate                             0.083112
# c_avg_renf_severe                              -0.204772
# c_max_respf_moderate                            0.554413
# c_max_respf_severe                              0.193664
# c_avg_respf_moderate                            0.543609
# c_avg_respf_severe                             -0.057667
# c_max_cnsf_moderate                            -0.072276
# c_max_cnsf_severe                              -0.634869
# c_avg_cnsf_moderate                             0.162572
# c_avg_cnsf_severe                              -0.048191
# c_sepsis3                                      -0.168871
# c_shock                                        -0.074320
#
#                       lung_diseases_due_to_external_agents  \
# c_rsp_mod                                         0.108945
# c_rsp_svr                                         0.189479
# c_vent_low                                        0.129559
# c_vent_moderate                                  -0.071165
# c_vent_high                                      -0.163260
# c_max_renf_moderate                               0.157610
# c_max_renf_severe                                -0.197964
# c_avg_renf_moderate                               0.021336
# c_avg_renf_severe                                 0.053949
# c_max_respf_moderate                              0.172557
# c_max_respf_severe                               -0.015878
# c_avg_respf_moderate                              0.309762
# c_avg_respf_severe                               -0.293933
# c_max_cnsf_moderate                               0.009544
# c_max_cnsf_severe                                -0.112902
# c_avg_cnsf_moderate                               0.405896
# c_avg_cnsf_severe                                -0.128664
# c_sepsis3                                        -0.061145
# c_shock                                          -0.026946
#
#                       other_respiratory_diseases  InvasiveVent  \
# c_rsp_mod                              -0.088476     -0.244620
# c_rsp_svr                               0.359807      0.119781
# c_vent_low                              0.650793      0.264694
# c_vent_moderate                        -0.127245      0.022757
# c_vent_high                             0.414578      0.060468
# c_max_renf_moderate                     0.484756      0.095592
# c_max_renf_severe                       0.429327      0.165500
# c_avg_renf_moderate                    -0.008317      0.117851
# c_avg_renf_severe                       0.567849     -0.018450
# c_max_respf_moderate                    0.722724      0.237345
# c_max_respf_severe                      0.022925      0.329320
# c_avg_respf_moderate                    0.594224      0.134781
# c_avg_respf_severe                      0.511011      0.300338
# c_max_cnsf_moderate                    -0.013467      0.132134
# c_max_cnsf_severe                       0.482902      0.169460
# c_avg_cnsf_moderate                    -0.128410      0.038777
# c_avg_cnsf_severe                      -0.352893      0.053072
# c_sepsis3                              -0.461717      0.266888
# c_shock                                 0.091730      0.001674
#
#                       SupplementalOxygen      HFNC  NonInvasiveVent  ...  \
# c_rsp_mod                      -0.369176 -0.604360        -0.068928  ...
# c_rsp_svr                       0.254559  0.243773        -0.066238  ...
# c_vent_low                      0.259964 -0.308193        -0.148326  ...
# c_vent_moderate                 0.681651 -0.380640         0.220775  ...
# c_vent_high                     0.309544  0.091140         0.044690  ...
# c_max_renf_moderate             0.023343 -0.235068        -0.104287  ...
# c_max_renf_severe              -0.055160 -0.435963        -0.233023  ...
# c_avg_renf_moderate            -0.852354  0.208824         0.234359  ...
# c_avg_renf_severe               0.033719 -0.317413        -0.275995  ...
# c_max_respf_moderate           -0.119923 -0.151263         0.018164  ...
# c_max_respf_severe              0.269782  0.135660         0.049538  ...
# c_avg_respf_moderate           -0.366646 -0.111160        -0.057354  ...
# c_avg_respf_severe              0.201849 -0.088591        -0.089051  ...
# c_max_cnsf_moderate             0.101812  0.371839         0.402428  ...
# c_max_cnsf_severe               0.238316 -0.168964        -0.054735  ...
# c_avg_cnsf_moderate             0.223213 -0.015884         0.165550  ...
# c_avg_cnsf_severe               0.138607  0.026546         0.143583  ...
# c_sepsis3                       0.239795 -0.165891        -0.171619  ...
# c_shock                        -0.016492 -0.082452        -0.062144  ...
#
#                       avg_pao2fio2ratio_novent  avg_pao2fio2ratio_vent  \
# c_rsp_mod                            -0.148682                0.418268
# c_rsp_svr                            -0.277926               -0.330447
# c_vent_low                            0.017477               -0.049597
# c_vent_moderate                      -0.063355                0.013923
# c_vent_high                           0.263464                0.381345
# c_max_renf_moderate                   0.040224               -0.350080
# c_max_renf_severe                    -0.243466                0.258722
# c_avg_renf_moderate                  -0.001799                0.149450
# c_avg_renf_severe                    -0.083754                0.101186
# c_max_respf_moderate                  0.005594               -0.122123
# c_max_respf_severe                    0.142735                0.084614
# c_avg_respf_moderate                 -0.084130               -0.318890
# c_avg_respf_severe                    0.185173               -0.332606
# c_max_cnsf_moderate                   0.206133               -0.054444
# c_max_cnsf_severe                     0.037387               -0.251310
# c_avg_cnsf_moderate                   0.007246               -0.069984
# c_avg_cnsf_severe                     0.045360                0.492986
# c_sepsis3                            -0.117066               -0.278944
# c_shock                              -0.029008                0.182507
#
#                       max_respiration_pao2fio2ratio_novent  \
# c_rsp_mod                                         0.462887
# c_rsp_svr                                        -0.386669
# c_vent_low                                       -0.218400
# c_vent_moderate                                  -0.196677
# c_vent_high                                      -0.175498
# c_max_renf_moderate                              -0.403298
# c_max_renf_severe                                -0.024092
# c_avg_renf_moderate                              -0.264938
# c_avg_renf_severe                                 0.169076
# c_max_respf_moderate                             -0.081406
# c_max_respf_severe                               -0.574096
# c_avg_respf_moderate                             -0.352195
# c_avg_respf_severe                               -0.580048
# c_max_cnsf_moderate                              -0.497142
# c_max_cnsf_severe                                -0.275097
# c_avg_cnsf_moderate                              -0.122958
# c_avg_cnsf_severe                                -0.228670
# c_sepsis3                                        -0.431970
# c_shock                                          -0.035605
#
#                       max_respiration_pao2fio2ratio_vent  avg_gcs_min  \
# c_rsp_mod                                       0.627895     0.082542
# c_rsp_svr                                       0.034111    -0.082768
# c_vent_low                                     -0.245687     0.217552
# c_vent_moderate                                -0.097445     0.043485
# c_vent_high                                    -0.166378     0.008574
# c_max_renf_moderate                             0.030987    -0.416682
# c_max_renf_severe                              -0.274255     0.019219
# c_avg_renf_moderate                            -0.068969     0.290377
# c_avg_renf_severe                               0.111686    -0.117039
# c_max_respf_moderate                            0.040072     0.036040
# c_max_respf_severe                             -0.084299     0.106916
# c_avg_respf_moderate                            0.039801     0.068014
# c_avg_respf_severe                             -0.136690     0.165333
# c_max_cnsf_moderate                            -0.055406     0.109004
# c_max_cnsf_severe                               0.051079     0.119149
# c_avg_cnsf_moderate                            -0.074374    -0.034519
# c_avg_cnsf_severe                              -0.269116     0.297241
# c_sepsis3                                      -0.000433     0.117405
# c_shock                                        -0.201831     0.231592
#
#                       max_cns_gcs_min  sofa_score  suspected_infection  \
# c_rsp_mod                   -0.102067   -0.022926             0.124517
# c_rsp_svr                    0.149683    0.172970             0.601246
# c_vent_low                   0.401873    0.236830             0.470800
# c_vent_moderate              0.105123   -0.115956            -0.435667
# c_vent_high                  0.384847   -0.076872            -0.161976
# c_max_renf_moderate         -0.727024   -0.040997             0.413692
# c_max_renf_severe           -0.404871   -0.394621             0.462979
# c_avg_renf_moderate         -0.253496    0.086258            -0.061878
# c_avg_renf_severe           -0.948094    0.160459             0.193286
# c_max_respf_moderate         0.445315   -0.074528             0.064611
# c_max_respf_severe          -0.651100   -0.373768             0.276439
# c_avg_respf_moderate        -0.303122    0.235984             0.403667
# c_avg_respf_severe          -0.202888   -0.074901             0.414765
# c_max_cnsf_moderate          0.244437    0.078210             0.320111
# c_max_cnsf_severe           -0.392214    0.166176             0.352505
# c_avg_cnsf_moderate         -0.202369    0.278944             0.168913
# c_avg_cnsf_severe           -0.258132    0.202127            -0.045419
# c_sepsis3                   -0.288008   -0.027515             0.534494
# c_shock                     -0.105452    0.308265            -0.071144
#
#                       one_vasopressor  multi_vasopressor
# c_rsp_mod                    0.109540          -0.133896
# c_rsp_svr                   -0.038456           0.119747
# c_vent_low                   0.055412           0.401548
# c_vent_moderate              0.058378           0.264534
# c_vent_high                 -0.087760           0.498987
# c_max_renf_moderate         -0.199476          -0.078691
# c_max_renf_severe            0.236980           0.303785
# c_avg_renf_moderate          0.227946           0.310127
# c_avg_renf_severe           -0.199697          -0.161521
# c_max_respf_moderate        -0.605737          -0.263766
# c_max_respf_severe          -0.998139          -0.906169
# c_avg_respf_moderate         0.170198           0.173453
# c_avg_respf_severe           0.210562          -0.301265
# c_max_cnsf_moderate          0.345565           0.092814
# c_max_cnsf_severe           -0.088422           0.126332
# c_avg_cnsf_moderate         -0.040675           0.290422
# c_avg_cnsf_severe            0.009910           0.591938
# c_sepsis3                    0.483486           0.479390
# c_shock                     -0.007300           0.008514
#
# [19 rows x 26 columns]

# %% [markdown]
# B. Concept to Label

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(concept_to_label_contributions, cmap='viridis', cbar=True)
plt.title('Concept to Label Weights Contribution')
plt.xlabel('Concepts')
plt.ylabel('Labels')
plt.show()

print("Concept to Label Weights Contribution:")
print(concept_to_label_contributions)
# Out:
# Concept to Label Weights Contribution:
#       c_rsp_mod  c_rsp_svr  c_vent_low  c_vent_moderate  c_vent_high  \
# ARDS  -0.352918  -0.149751   -0.044309          0.14895    -0.000113
#
#       c_max_renf_moderate  c_max_renf_severe  c_avg_renf_moderate  \
# ARDS            -0.158843           0.007897             0.153409
#
#       c_avg_renf_severe  c_max_respf_moderate  c_max_respf_severe  \
# ARDS          -0.252283              0.139508           -0.390105
#
#       c_avg_respf_moderate  c_avg_respf_severe  c_max_cnsf_moderate  \
# ARDS              0.208021           -0.151621            -0.038926
#
#       c_max_cnsf_severe  c_avg_cnsf_moderate  c_avg_cnsf_severe  c_sepsis3  \
# ARDS           0.019169            -0.024875           0.244417  -0.095589
#
#        c_shock
# ARDS -0.000177

# %% [markdown]
# C. Combined Feature-Concept Pair to Label

# %%
# Extract the weights for the label 'ARDS'
concept_to_label_weights = concept_to_label_contributions.loc[label_names[0]].values

# Reshape concept_to_label_weights for element-wise multiplication
concept_to_label_weights = concept_to_label_weights.reshape(-1, 1)

# Calculate the combined contributions by element-wise multiplication
combined_contributions = feature_to_concept_contributions.values * concept_to_label_weights

# Create a DataFrame for the combined contributions
combined_df = pd.DataFrame(combined_contributions, index=concept_names, columns=feature_names)

# Plotting the combined heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(combined_df, cmap='viridis', cbar=True, fmt=".2f")
plt.title('Combined Feature to Concept Contributions Predicting ARDS')
plt.xlabel('Features')
plt.ylabel('Concepts')
plt.show()

print("Combined Contributions Predicting ARDS:")
print(combined_df)
# Out:
# Combined Contributions Predicting ARDS:
#                       upper_respiratory_infections  influenza_pneumonia  \
# c_rsp_mod                                 0.011327            -0.005764
# c_rsp_svr                                 0.007876             0.000474
# c_vent_low                                0.002684             0.017346
# c_vent_moderate                           0.004548             0.036345
# c_vent_high                               0.000002             0.000009
# c_max_renf_moderate                      -0.000802            -0.065293
# c_max_renf_severe                         0.001000            -0.000900
# c_avg_renf_moderate                      -0.010092            -0.056941
# c_avg_renf_severe                         0.009232             0.027607
# c_max_respf_moderate                      0.024617             0.083857
# c_max_respf_severe                       -0.036373            -0.008639
# c_avg_respf_moderate                      0.024664             0.063002
# c_avg_respf_severe                       -0.023111             0.075629
# c_max_cnsf_moderate                       0.000541             0.000153
# c_max_cnsf_severe                        -0.004426             0.001787
# c_avg_cnsf_moderate                      -0.004121            -0.003020
# c_avg_cnsf_severe                         0.006878            -0.009238
# c_sepsis3                                 0.020035             0.023465
# c_shock                                  -0.000035             0.000004
#
#                       acute_lower_respiratory_infections  \
# c_rsp_mod                                       0.036361
# c_rsp_svr                                       0.014649
# c_vent_low                                      0.008390
# c_vent_moderate                                 0.008432
# c_vent_high                                     0.000003
# c_max_renf_moderate                            -0.023255
# c_max_renf_severe                              -0.000409
# c_avg_renf_moderate                            -0.012777
# c_avg_renf_severe                               0.017124
# c_max_respf_moderate                           -0.006140
# c_max_respf_severe                              0.055571
# c_avg_respf_moderate                            0.036689
# c_avg_respf_severe                              0.036474
# c_max_cnsf_moderate                             0.004887
# c_max_cnsf_severe                              -0.001772
# c_avg_cnsf_moderate                             0.001458
# c_avg_cnsf_severe                              -0.018173
# c_sepsis3                                       0.010352
# c_shock                                         0.000006
#
#                       chronic_lower_respiratory_diseases  \
# c_rsp_mod                                      -0.004673
# c_rsp_svr                                       0.015399
# c_vent_low                                      0.007473
# c_vent_moderate                                 0.014817
# c_vent_high                                     0.000024
# c_max_renf_moderate                            -0.066184
# c_max_renf_severe                              -0.002190
# c_avg_renf_moderate                             0.012750
# c_avg_renf_severe                               0.051660
# c_max_respf_moderate                            0.077345
# c_max_respf_severe                             -0.075549
# c_avg_respf_moderate                            0.113082
# c_avg_respf_severe                              0.008743
# c_max_cnsf_moderate                             0.002813
# c_max_cnsf_severe                              -0.012170
# c_avg_cnsf_moderate                            -0.004044
# c_avg_cnsf_severe                              -0.011779
# c_sepsis3                                       0.016142
# c_shock                                         0.000013
#
#                       lung_diseases_due_to_external_agents  \
# c_rsp_mod                                        -0.038449
# c_rsp_svr                                        -0.028375
# c_vent_low                                       -0.005741
# c_vent_moderate                                  -0.010600
# c_vent_high                                       0.000019
# c_max_renf_moderate                              -0.025035
# c_max_renf_severe                                -0.001563
# c_avg_renf_moderate                               0.003273
# c_avg_renf_severe                                -0.013611
# c_max_respf_moderate                              0.024073
# c_max_respf_severe                                0.006194
# c_avg_respf_moderate                              0.064437
# c_avg_respf_severe                                0.044566
# c_max_cnsf_moderate                              -0.000372
# c_max_cnsf_severe                                -0.002164
# c_avg_cnsf_moderate                              -0.010097
# c_avg_cnsf_severe                                -0.031448
# c_sepsis3                                         0.005845
# c_shock                                           0.000005
#
#                       other_respiratory_diseases  InvasiveVent  \
# c_rsp_mod                               0.031225  8.633076e-02
# c_rsp_svr                              -0.053881 -1.793733e-02
# c_vent_low                             -0.028836 -1.172835e-02
# c_vent_moderate                        -0.018953  3.389714e-03
# c_vent_high                            -0.000047 -6.857187e-06
# c_max_renf_moderate                    -0.077000 -1.518413e-02
# c_max_renf_severe                       0.003390  1.306945e-03
# c_avg_renf_moderate                    -0.001276  1.807934e-02
# c_avg_renf_severe                      -0.143259  4.654612e-03
# c_max_respf_moderate                    0.100826  3.311150e-02
# c_max_respf_severe                     -0.008943 -1.284693e-01
# c_avg_respf_moderate                    0.123611  2.803740e-02
# c_avg_respf_severe                     -0.077480 -4.553743e-02
# c_max_cnsf_moderate                     0.000524 -5.143473e-03
# c_max_cnsf_severe                       0.009257  3.248399e-03
# c_avg_cnsf_moderate                     0.003194 -9.646061e-04
# c_avg_cnsf_severe                      -0.086253  1.297162e-02
# c_sepsis3                               0.044135 -2.551167e-02
# c_shock                                -0.000016 -2.957961e-07
#
#                       SupplementalOxygen      HFNC  NonInvasiveVent  ...  \
# c_rsp_mod                       0.130289  0.213289         0.024326  ...
# c_rsp_svr                      -0.038120 -0.036505         0.009919  ...
# c_vent_low                     -0.011519  0.013656         0.006572  ...
# c_vent_moderate                 0.101532 -0.056697         0.032885  ...
# c_vent_high                    -0.000035 -0.000010        -0.000005  ...
# c_max_renf_moderate            -0.003708  0.037339         0.016565  ...
# c_max_renf_severe              -0.000436 -0.003443        -0.001840  ...
# c_avg_renf_moderate            -0.130759  0.032036         0.035953  ...
# c_avg_renf_severe              -0.008507  0.080078         0.069629  ...
# c_max_respf_moderate           -0.016730 -0.021102         0.002534  ...
# c_max_respf_severe             -0.105243 -0.052922        -0.019325  ...
# c_avg_respf_moderate           -0.076270 -0.023124        -0.011931  ...
# c_avg_respf_severe             -0.030604  0.013432         0.013502  ...
# c_max_cnsf_moderate            -0.003963 -0.014474        -0.015665  ...
# c_max_cnsf_severe               0.004568 -0.003239        -0.001049  ...
# c_avg_cnsf_moderate            -0.005553  0.000395        -0.004118  ...
# c_avg_cnsf_severe               0.033878  0.006488         0.035094  ...
# c_sepsis3                      -0.022922  0.015857         0.016405  ...
# c_shock                         0.000003  0.000015         0.000011  ...
#
#                       avg_pao2fio2ratio_novent  avg_pao2fio2ratio_vent  \
# c_rsp_mod                             0.052472               -0.147614
# c_rsp_svr                             0.041620                0.049485
# c_vent_low                           -0.000774                0.002198
# c_vent_moderate                      -0.009437                0.002074
# c_vent_high                          -0.000030               -0.000043
# c_max_renf_moderate                  -0.006389                0.055608
# c_max_renf_severe                    -0.001923                0.002043
# c_avg_renf_moderate                  -0.000276                0.022927
# c_avg_renf_severe                     0.021130               -0.025527
# c_max_respf_moderate                  0.000780               -0.017037
# c_max_respf_severe                   -0.055682               -0.033008
# c_avg_respf_moderate                 -0.017501               -0.066336
# c_avg_respf_severe                   -0.028076                0.050430
# c_max_cnsf_moderate                  -0.008024                0.002119
# c_max_cnsf_severe                     0.000717               -0.004817
# c_avg_cnsf_moderate                  -0.000180                0.001741
# c_avg_cnsf_severe                     0.011087                0.120494
# c_sepsis3                             0.011190                0.026664
# c_shock                               0.000005               -0.000032
#
#                       max_respiration_pao2fio2ratio_novent  \
# c_rsp_mod                                        -0.163361
# c_rsp_svr                                         0.057904
# c_vent_low                                        0.009677
# c_vent_moderate                                  -0.029295
# c_vent_high                                       0.000020
# c_max_renf_moderate                               0.064061
# c_max_renf_severe                                -0.000190
# c_avg_renf_moderate                              -0.040644
# c_avg_renf_severe                                -0.042655
# c_max_respf_moderate                             -0.011357
# c_max_respf_severe                                0.223958
# c_avg_respf_moderate                             -0.073264
# c_avg_respf_severe                                0.087947
# c_max_cnsf_moderate                               0.019352
# c_max_cnsf_severe                                -0.005273
# c_avg_cnsf_moderate                               0.003059
# c_avg_cnsf_severe                                -0.055891
# c_sepsis3                                         0.041292
# c_shock                                           0.000006
#
#                       max_respiration_pao2fio2ratio_vent   avg_gcs_min  \
# c_rsp_mod                                      -0.221595 -2.913069e-02
# c_rsp_svr                                      -0.005108  1.239463e-02
# c_vent_low                                      0.010886 -9.639533e-03
# c_vent_moderate                                -0.014514  6.477172e-03
# c_vent_high                                     0.000019 -9.722709e-07
# c_max_renf_moderate                            -0.004922  6.618685e-02
# c_max_renf_severe                              -0.002166  1.517737e-04
# c_avg_renf_moderate                            -0.010580  4.454641e-02
# c_avg_renf_severe                              -0.028177  2.952686e-02
# c_max_respf_moderate                            0.005590  5.027896e-03
# c_max_respf_severe                              0.032885 -4.170836e-02
# c_avg_respf_moderate                            0.008279  1.414827e-02
# c_avg_respf_severe                              0.020725 -2.506787e-02
# c_max_cnsf_moderate                             0.002157 -4.243112e-03
# c_max_cnsf_severe                               0.000979  2.283981e-03
# c_avg_cnsf_moderate                             0.001850  8.586675e-04
# c_avg_cnsf_severe                              -0.065776  7.265086e-02
# c_sepsis3                                       0.000041 -1.122264e-02
# c_shock                                         0.000036 -4.093392e-05
#
#                       max_cns_gcs_min  sofa_score  suspected_infection  \
# c_rsp_mod                    0.036021    0.008091            -0.043944
# c_rsp_svr                   -0.022415   -0.025902            -0.090037
# c_vent_low                  -0.017807   -0.010494            -0.020861
# c_vent_moderate              0.015658   -0.017272            -0.064893
# c_vent_high                 -0.000044    0.000009             0.000018
# c_max_renf_moderate          0.115482    0.006512            -0.065712
# c_max_renf_severe           -0.003197   -0.003116             0.003656
# c_avg_renf_moderate         -0.038889    0.013233            -0.009493
# c_avg_renf_severe            0.239188   -0.040481            -0.048763
# c_max_respf_moderate         0.062125   -0.010397             0.009014
# c_max_respf_severe           0.253997    0.145809            -0.107840
# c_avg_respf_moderate        -0.063056    0.049090             0.083971
# c_avg_respf_severe           0.030762    0.011357            -0.062887
# c_max_cnsf_moderate         -0.009515   -0.003044            -0.012461
# c_max_cnsf_severe           -0.007518    0.003185             0.006757
# c_avg_cnsf_moderate          0.005034   -0.006939            -0.004202
# c_avg_cnsf_severe           -0.063092    0.049403            -0.011101
# c_sepsis3                    0.027531    0.002630            -0.051092
# c_shock                      0.000019   -0.000054             0.000013
#
#                       one_vasopressor  multi_vasopressor
# c_rsp_mod                   -0.038658           0.047254
# c_rsp_svr                    0.005759          -0.017932
# c_vent_low                  -0.002455          -0.017792
# c_vent_moderate              0.008695           0.039402
# c_vent_high                  0.000010          -0.000057
# c_max_renf_moderate          0.031685           0.012499
# c_max_renf_severe            0.001871           0.002399
# c_avg_renf_moderate          0.034969           0.047576
# c_avg_renf_severe            0.050380           0.040749
# c_max_respf_moderate        -0.084505          -0.036797
# c_max_respf_severe           0.389379           0.353501
# c_avg_respf_moderate         0.035405           0.036082
# c_avg_respf_severe          -0.031926           0.045678
# c_max_cnsf_moderate         -0.013452          -0.003613
# c_max_cnsf_severe           -0.001695           0.002422
# c_avg_cnsf_moderate          0.001012          -0.007224
# c_avg_cnsf_severe            0.002422           0.144680
# c_sepsis3                   -0.046216          -0.045825
# c_shock                      0.000001          -0.000002
#
# [19 rows x 26 columns]

# %%
# Define the fixed scale for the heatmaps
fixed_vmin = -0.2  # Set your desired minimum value
fixed_vmax = 0.2   # Set your desired maximum value

# Create a figure with three subplots arranged in a column
fig, axes = plt.subplots(nrows=3, figsize=(12, 24))

# Plotting the feature to concept weight
sns.heatmap(feature_to_concept_contributions, cmap='viridis', cbar=True, vmin=fixed_vmin, vmax=fixed_vmax, ax=axes[0])
axes[0].set_title('Feature to Concept Weights Contribution')
axes[0].set_xlabel('Features')
axes[0].set_ylabel('Concepts')

# Plotting the concept to label weight
sns.heatmap(concept_to_label_contributions, cmap='viridis', cbar=True, vmin=fixed_vmin, vmax=fixed_vmax, ax=axes[1])
axes[1].set_title('Concept to Label Weights Contribution')
axes[1].set_xlabel('Concepts')
axes[1].set_ylabel('Labels')

# Plotting the combined heatmap
sns.heatmap(combined_df, cmap='viridis', cbar=True, fmt=".2f", vmin=fixed_vmin, vmax=fixed_vmax, ax=axes[2])
axes[2].set_title('Combined Feature to Concept Contributions Predicting ARDS')
axes[2].set_xlabel('Features')
axes[2].set_ylabel('Concepts')

# Adjust layout
plt.tight_layout()

# Save the figure as a single image
plt.savefig('ards-ind-heatmaps.png')

# Show the figure
plt.show()
