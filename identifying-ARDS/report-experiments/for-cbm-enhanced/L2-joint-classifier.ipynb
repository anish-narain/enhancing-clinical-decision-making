# %% [markdown]
# # Changes made to `joint_classifier`
#
#
#
# *   Simplified the neural network architecture (2 hidden layers for the concept predictor and label predictor each instead of 3) to try to reduce overfitting
# *   Early stopping: training stops if validation loss does not improve for 10 consecutive epochs to avoid overfitting
# *   Includes a learning rate scheduler (StepLR) that reduces the learning rate by a factor of 0.1 every 10 epochs. This helps in fine-tuning the learning process.
# *   The learning rate for the optimizer is decreased from 0.01 in to 0.001. A smaller learning rate can help in achieving a more stable and fine-grained convergence.

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR
from torch.utils.data import DataLoader, Dataset

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_score, recall_score, accuracy_score, f1_score, roc_auc_score

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Initialise GPU

# %%
# Check if GPU is available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Data Loading and Pre-processing

# %%
# Class for pre-processing the data
class MIMICDataProcessor:
    def __init__(self, file_path, batch_size=64):
        self.file_path = file_path
        self.batch_size = batch_size
        self.scaler = StandardScaler()

        # Load and preprocess the data
        self.df = pd.read_csv(file_path)
        # Replace all missing values with 0
        self.df.fillna(0, inplace=True)

        # Features
        self.X = self.df[['upper_respiratory_infections', 'influenza_pneumonia', 'acute_lower_respiratory_infections', 'chronic_lower_respiratory_diseases',
                          'lung_diseases_due_to_external_agents', 'other_respiratory_diseases', 'InvasiveVent', 'SupplementalOxygen', 'HFNC',
                          'NonInvasiveVent', 'Tracheostomy', 'None', 'avg_uo_24hr', 'avg_creatinine_max', 'max_renal_uo_24hr', 'max_renal_creatinine_max',
                          'avg_pao2fio2ratio_novent', 'avg_pao2fio2ratio_vent', 'max_respiration_pao2fio2ratio_novent', 'max_respiration_pao2fio2ratio_vent', 'avg_gcs_min', 'max_cns_gcs_min',
                          'sofa_score', 'suspected_infection', 'one_vasopressor', 'multi_vasopressor']]

        # Concepts
        self.C = self.df[['c_rsp_mod', 'c_rsp_svr', 'c_vent_low', 'c_vent_moderate', 'c_vent_high', 'c_max_renf_moderate', 'c_max_renf_severe',
                          'c_avg_renf_moderate', 'c_avg_renf_severe', 'c_max_respf_moderate', 'c_max_respf_severe', 'c_avg_respf_moderate',
                          'c_avg_respf_severe', 'c_max_cnsf_moderate', 'c_max_cnsf_severe', 'c_avg_cnsf_moderate', 'c_avg_cnsf_severe',
                          'c_sepsis3', 'c_shock', 'ards_detected', 'aspiration_detected', 'bilateral_infiltrates_detected', 'cardiac_arrest_detected',
                          'cardiac_failure_detected', 'pancreatitis_detected', 'pneumonia_detected', 'trali_detected']]

        # Label
        self.Y = self.df['ARDS']

        # Convert to tensors
        self.X_tensor = torch.tensor(self.X.values, dtype=torch.float32)
        self.C_tensor = torch.tensor(self.C.values, dtype=torch.float32)
        self.Y_tensor = torch.tensor(self.Y.values, dtype=torch.float32)

        # Normalize the features
        self.X_scaled = self.scaler.fit_transform(self.X)
        self.X_tensor_scaled = torch.tensor(self.X_scaled, dtype=torch.float32)

    def get_features(self):
        return self.X.columns.tolist()

    def get_concepts(self):
        return self.C.columns.tolist()

    def get_labels(self):
        return self.Y.columns.tolist()

    # Dataset class needed to provide the __getitem__ method for DataLoader
    class MIMICDataset(Dataset):
        def __init__(self, x, c, y):
            self.x = x
            self.c = c
            self.y = y

        def __len__(self):
            return len(self.y)

        def __getitem__(self, idx):
            return self.x[idx], self.c[idx], self.y[idx]

    def create_dataloaders(self):
        # Split the data into temporary (80%) and test (20%) sets
        X_temp, X_test, C_temp, C_test, Y_temp, Y_test = train_test_split(
            self.X_tensor_scaled, self.C_tensor, self.Y_tensor, test_size=0.20, random_state=42)

        # Further split the temporary data into training (75% of temporary) and validation (25% of temporary) sets
        X_train, X_val, C_train, C_val, Y_train, Y_val = train_test_split(
            X_temp, C_temp, Y_temp, test_size=0.25, random_state=42)

        train_dataset = self.MIMICDataset(X_train, C_train, Y_train)
        val_dataset = self.MIMICDataset(X_val, C_val, Y_val)
        test_dataset = self.MIMICDataset(X_test, C_test, Y_test)

        train_loader = DataLoader(train_dataset, batch_size=self.batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=self.batch_size, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=self.batch_size, shuffle=False)

        return train_loader, val_loader, test_loader

# %% [markdown]
# # Model

# %%
class MultiLabelNN(nn.Module):
    def __init__(self, num_features, num_concepts, num_labels):
        super(MultiLabelNN, self).__init__()
        # Layers to predict concepts
        self.layer1 = nn.Linear(num_features, 32)
        self.layer2 = nn.Linear(32, 64)
        self.concept_output_layer = nn.Linear(64, num_concepts)

        # Layers to predict final output from concepts
        self.layer4 = nn.Linear(num_concepts, 32)
        self.layer5 = nn.Linear(32, 64)
        self.label_output_layer = nn.Linear(64, num_labels)

    def forward(self, x):
        # Layers for concept prediction
        x_c = torch.relu(self.layer1(x))
        x_c = torch.relu(self.layer2(x_c))
        intermediate_output = self.concept_output_layer(x_c)
        intermediate_probability = torch.sigmoid(intermediate_output)

        # Layers for label prediction
        x = torch.relu(intermediate_output)
        x = torch.relu(self.layer4(x))
        x = torch.relu(self.layer5(x))
        final_probability = torch.sigmoid(self.label_output_layer(x))

        return intermediate_probability, final_probability

# %% [markdown]
# # Training
#
# Look at the Step 5 from this [basic code](https://colab.research.google.com/drive/1LqE89tPVt6h1wa7lerLgF4GNvRw9QFDw?usp=sharing) for reference.

# %%
def train(x_size, c_size, y_size, x_to_y_learning_rate, lamda, weight_decay, epochs, train_loader, val_loader):
    torch.manual_seed(25)

    x_to_y = MultiLabelNN(num_features=x_size, num_concepts=c_size, num_labels=y_size).to(device)

    criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for classification
    x_to_y_optimizer = torch.optim.Adam(x_to_y.parameters(), lr=x_to_y_learning_rate, weight_decay=weight_decay)
    x_to_y_scheduler = StepLR(x_to_y_optimizer, step_size=10, gamma=0.1)

    epochs_count = []
    x_to_c_loss_values, c_to_y_loss_values, total_loss_values = [], [], []
    x_to_c_predictions, c_to_y_predictions = [], []
    x_to_c_val_loss_values, c_to_y_val_loss_values, total_val_loss_values = [], [], []
    x_to_c_val_predictions, c_to_y_val_predictions = [], []
    ground_truth_val_c, ground_truth_val_y = [], []


    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")  # Print current epoch
        epochs_count.append(epoch)

        # Training Loop
        x_to_y.train()

        running_x_to_c_loss, running_c_to_y_loss = 0.0, 0.0
        running_total_loss = 0.0
        total_samples = 0

        for i, batch in enumerate(train_loader):
            x, c, y = batch
            x, c, y = x.to(device), c.to(device), y.to(device)

            # Forward pass through x_to_y
            x_to_y_optimizer.zero_grad()
            x = x.to(x_to_y.layer1.weight.dtype)  # ensure data type of input tensor x matches data type of weights of the first linear layer
            predicted_c, predicted_y = x_to_y(x)

            # Squeeze the predictions to match the target dimensions
            predicted_c = predicted_c.squeeze()
            predicted_y = predicted_y.squeeze()

            x_to_c_predictions.append(predicted_c.detach().cpu().numpy())
            c_to_y_predictions.append(predicted_y.detach().cpu().numpy())

            c_loss = criterion(predicted_c, c.float())
            y_loss = criterion(predicted_y, y.float())

            # Combined loss
            total_loss = c_loss + lamda * y_loss

            # Backward pass and optimisation for combined loss
            total_loss.backward()
            x_to_y_optimizer.step()

            # Accumulate loss values
            running_x_to_c_loss += c_loss.item()
            running_c_to_y_loss += y_loss.item()
            running_total_loss += total_loss.item()

            total_samples += len(y)

        x_to_c_loss_values.append(running_x_to_c_loss / len(train_loader))
        c_to_y_loss_values.append(running_c_to_y_loss / len(train_loader))
        total_loss_values.append(running_total_loss / len(train_loader))

        # Step the schedulers
        x_to_y_scheduler.step()

        # Validating Loop
        x_to_y.eval()

        running_x_to_c_val_loss, running_c_to_y_val_loss = 0.0, 0.0
        running_total_val_loss = 0.0
        total_val_samples = 0

        with torch.no_grad():
            for x, c, y in val_loader:
                # GPU
                x, c, y = x.to(device), c.to(device), y.to(device)

                # Ground truth array
                ground_truth_val_c.append(c.cpu())
                ground_truth_val_y.append(y.cpu())

                # Forward pass through x_to_y
                x = x.to(x_to_y.layer1.weight.dtype)  # ensure data type of input tensor x matches data type of weights of the first linear layer
                predicted_c, predicted_y = x_to_y(x)

                # Squeeze the predictions to match the target dimensions
                predicted_c = predicted_c.squeeze()
                predicted_y = predicted_y.squeeze()

                x_to_c_val_predictions.append(predicted_c.detach().cpu().numpy())
                c_to_y_val_predictions.append(predicted_y.detach().cpu().numpy())

                c_loss = criterion(predicted_c, c.float())
                y_loss = criterion(predicted_y, y.float())

                total_loss = c_loss + lamda * y_loss

                # Accumulate loss values for valing
                running_x_to_c_val_loss += c_loss.item()
                running_c_to_y_val_loss += y_loss.item()
                running_total_val_loss += total_loss.item()

                total_val_samples += len(y)

        x_to_c_val_loss_values.append(running_x_to_c_val_loss / len(val_loader))
        c_to_y_val_loss_values.append(running_c_to_y_val_loss / len(val_loader))
        total_val_loss_values.append(running_total_val_loss / len(val_loader))

    return (x_to_y, epochs_count, x_to_c_loss_values, c_to_y_loss_values, total_loss_values, x_to_c_predictions, c_to_y_predictions, x_to_c_val_loss_values, c_to_y_val_loss_values, total_val_loss_values, x_to_c_val_predictions, c_to_y_val_predictions, ground_truth_val_c, ground_truth_val_y)

# %%
# Specify Parameters
x_size = 26
c_size = 27
y_size = 1
x_to_y_learning_rate = 0.01
lamda = 0.3
weight_decay = 0.0001
epochs = 60

# Load Data
file_path = '/content/augmented-ards-data.csv'
data_processor = MIMICDataProcessor(file_path, batch_size=64)
train_loader, test_loader, val_loader = data_processor.create_dataloaders()

x_to_y, epochs_count, x_to_c_loss_values, c_to_y_loss_values, total_loss_values, x_to_c_predictions, c_to_y_predictions, x_to_c_val_loss_values, c_to_y_val_loss_values, total_val_loss_values, x_to_c_val_predictions, c_to_y_val_predictions, ground_truth_val_c, ground_truth_val_y = train(x_size, c_size, y_size, x_to_y_learning_rate, lamda, weight_decay, epochs, train_loader, val_loader)
# Out:
# Epoch 1/60
# Epoch 2/60
# Epoch 3/60
# Epoch 4/60
# Epoch 5/60
# Epoch 6/60
# Epoch 7/60
# Epoch 8/60
# Epoch 9/60
# Epoch 10/60
# Epoch 11/60
# Epoch 12/60
# Epoch 13/60
# Epoch 14/60
# Epoch 15/60
# Epoch 16/60
# Epoch 17/60
# Epoch 18/60
# Epoch 19/60
# Epoch 20/60
# Epoch 21/60
# Epoch 22/60
# Epoch 23/60
# Epoch 24/60
# Epoch 25/60
# Epoch 26/60
# Epoch 27/60
# Epoch 28/60
# Epoch 29/60
# Epoch 30/60
# Epoch 31/60
# Epoch 32/60
# Epoch 33/60
# Epoch 34/60
# Epoch 35/60
# Epoch 36/60
# Epoch 37/60
# Epoch 38/60
# Epoch 39/60
# Epoch 40/60
# Epoch 41/60
# Epoch 42/60
# Epoch 43/60
# Epoch 44/60
# Epoch 45/60
# Epoch 46/60
# Epoch 47/60
# Epoch 48/60
# Epoch 49/60
# Epoch 50/60
# Epoch 51/60
# Epoch 52/60
# Epoch 53/60
# Epoch 54/60
# Epoch 55/60
# Epoch 56/60
# Epoch 57/60
# Epoch 58/60
# Epoch 59/60
# Epoch 60/60

# %% [markdown]
# # Plotting Loss

# %%
plt.figure(figsize=(12, 6))
plt.plot(epochs_count, x_to_c_loss_values, label='Training Concept Model Loss')
plt.plot(epochs_count, c_to_y_loss_values, label='Training Label Model Loss')
plt.plot(epochs_count, total_loss_values, label='Training Full Model Loss')
plt.plot(epochs_count, x_to_c_val_loss_values, label='Validation Concept Predictor Loss')
plt.plot(epochs_count, c_to_y_val_loss_values, label='Validation Label Predictor Loss')
plt.plot(epochs_count, total_val_loss_values, label='Validation Full Model Loss')
plt.title('Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Training loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_count, x_to_c_loss_values, label='Concept Model Loss')
plt.plot(epochs_count, c_to_y_loss_values, label='Label Model Loss')
plt.plot(epochs_count, total_loss_values, label='Full Model Loss')
plt.title('Training Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Testing loss
plt.figure(figsize=(12, 6))
plt.plot(epochs_count, x_to_c_val_loss_values, label='Concept Predictor Loss')
plt.plot(epochs_count, c_to_y_val_loss_values, label='Label Predictor Loss')
plt.plot(epochs_count, total_val_loss_values, label='Full Model Loss')
plt.title('Testing Loss Per Epoch')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Validation Evaluation

# %%
def evaluate_concept_predictor(ground_truth_c, x_to_c_predictions, concept_labels):
    results = []
    precisions = []
    recalls = []
    f1_scores = []
    aucs = []
    accuracies = []

    for i, label in enumerate(concept_labels):
        true_values = torch.cat([c[:, i] if isinstance(c, torch.Tensor) else torch.tensor(c[:, i]) for c in ground_truth_c]).numpy()
        predicted_values = torch.cat([c[:, i] if isinstance(c, torch.Tensor) else torch.tensor(c[:, i]) for c in x_to_c_predictions]).numpy()

        predicted_classes = (predicted_values > 0.5).astype(int)  # Convert probabilities to binary classes

        precision = precision_score(true_values, predicted_classes, zero_division=0)
        recall = recall_score(true_values, predicted_classes, zero_division=0)
        f1 = f1_score(true_values, predicted_classes, zero_division=0)
        # Check if both classes are present in true_values before calculating AUC
        if len(np.unique(true_values)) == 2:
            auc = roc_auc_score(true_values, predicted_classes)
        else:
            auc = None
        accuracy = accuracy_score(true_values, predicted_classes)

        precisions.append(precision)
        recalls.append(recall)
        f1_scores.append(f1)
        aucs.append(auc if auc is not None else 0)  # Use 0 or another value for averaging
        accuracies.append(accuracy)

        results.append({
            "Label": label,
            "Precision": precision,
            "Recall": recall,
            "F1 Score": f1,
            "AUC": auc,
            "Accuracy": accuracy
        })

    # Calculate the average values for each metric, excluding None values for AUC
    avg_precision = np.mean(precisions)
    avg_recall = np.mean(recalls)
    avg_f1 = np.mean(f1_scores)
    avg_auc = np.mean([auc for auc in aucs if auc is not None])
    avg_accuracy = np.mean(accuracies)

    # Append the average values to the results
    results.append({
        "Label": "Average",
        "Precision": avg_precision,
        "Recall": avg_recall,
        "F1 Score": avg_f1,
        "AUC": avg_auc,
        "Accuracy": avg_accuracy
    })

    return pd.DataFrame(results)

# %%
# Get concept labels from the data processor
concept_labels = data_processor.get_concepts()

# Evaluation
concept_predictor_results = evaluate_concept_predictor(ground_truth_val_c, x_to_c_val_predictions, concept_labels)
print("Validation Concept Predictor Results:")
print(concept_predictor_results)
# Out:
# Validation Concept Predictor Results:
#                              Label  Precision    Recall  F1 Score       AUC  \
# 0                        c_rsp_mod   0.943082  0.960616  0.951768  0.894197
# 1                        c_rsp_svr   0.993832  0.949797  0.971316  0.974150
# 2                       c_vent_low   0.985453  0.992673  0.989050  0.975932
# 3                  c_vent_moderate   1.000000  0.941049  0.969630  0.970525
# 4                      c_vent_high   0.997155  1.000000  0.998575  0.712500
# 5              c_max_renf_moderate   0.674894  0.459148  0.546499  0.675499
# 6                c_max_renf_severe   0.856673  0.798559  0.826596  0.843105
# 7              c_avg_renf_moderate   0.315789  0.028571  0.052402  0.511987
# 8                c_avg_renf_severe   0.658930  0.681333  0.669944  0.815831
# 9             c_max_respf_moderate   0.757620  0.435000  0.552673  0.713885
# 10              c_max_respf_severe   0.976789  0.992857  0.984757  0.769345
# 11            c_avg_respf_moderate   0.745520  0.707732  0.726135  0.815825
# 12              c_avg_respf_severe   0.917381  0.914502  0.915940  0.826495
# 13             c_max_cnsf_moderate   0.793317  0.717002  0.753231  0.804139
# 14               c_max_cnsf_severe   0.937874  0.947554  0.942689  0.937190
# 15             c_avg_cnsf_moderate   0.000000  0.000000  0.000000  0.498935
# 16               c_avg_cnsf_severe   0.000000  0.000000  0.000000  0.500000
# 17                       c_sepsis3   0.997330  1.000000  0.998663  0.972807
# 18                         c_shock   0.963964  0.985608  0.974666  0.901505
# 19                   ards_detected   0.698765  0.902344  0.787612  0.617000
# 20             aspiration_detected   0.638298  0.346154  0.448878  0.619546
# 21  bilateral_infiltrates_detected   0.829051  0.953244  0.886820  0.514298
# 22         cardiac_arrest_detected   0.561691  0.301389  0.392287  0.585816
# 23        cardiac_failure_detected   0.708040  0.887132  0.787533  0.569506
# 24           pancreatitis_detected   0.000000  0.000000  0.000000  0.498909
# 25              pneumonia_detected   0.769199  0.884349  0.822764  0.648391
# 26                  trali_detected   0.000000  0.000000  0.000000  0.500000
# 27                         Average   0.693357  0.658763  0.664831  0.728419
#
#     Accuracy
# 0   0.927160
# 1   0.988642
# 2   0.983827
# 3   0.992140
# 4   0.997160
# 5   0.749753
# 6   0.846955
# 7   0.928560
# 8   0.917119
# 9   0.965226
# 10  0.970782
# 11  0.872140
# 12  0.872346
# 13  0.827160
# 14  0.937984
# 15  0.983086
# 16  0.997531
# 17  0.997449
# 18  0.957366
# 19  0.692387
# 20  0.699877
# 21  0.799342
# 22  0.667984
# 23  0.678519
# 24  0.884486
# 25  0.737531
# 26  0.916049
# 27  0.881058

# %%
# Label Predictor Evaluation
def evaluate_label_predictor(ground_truth_y, c_to_y_predictions):
    # Ensure all elements are tensors
    ground_truth_y = [torch.tensor(gy) if not isinstance(gy, torch.Tensor) else gy for gy in ground_truth_y]
    c_to_y_predictions = [torch.tensor(py) if not isinstance(py, torch.Tensor) else py for py in c_to_y_predictions]

    true_values = torch.cat(ground_truth_y).numpy()
    predicted_values = torch.cat(c_to_y_predictions).squeeze().numpy()

    predicted_classes = (predicted_values > 0.5).astype(int)  # Convert probabilities to binary classes

    precision = precision_score(true_values, predicted_classes)
    recall = recall_score(true_values, predicted_classes)
    f1 = f1_score(true_values, predicted_classes)
    auc = roc_auc_score(true_values, predicted_classes)
    accuracy = accuracy_score(true_values, predicted_classes)

    results = {"Precision": precision,
        "Recall": recall,
        "F1 Score": f1,
        "AUC": auc,
        "Accuracy": accuracy}

    index = pd.Index(["Metrics"])
    return pd.DataFrame(results, index=index)

# %%
# Evaluation
print("Validation Label Predictor Results:")
label_predictor_results = evaluate_label_predictor(ground_truth_val_y, c_to_y_val_predictions)
print(label_predictor_results)
# Out:
# Validation Label Predictor Results:
#          Precision    Recall  F1 Score       AUC  Accuracy
# Metrics   0.673243  0.731978  0.701383  0.676576  0.678354

# %% [markdown]
# # Testing Evaluation

# %%
def test_model(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    criterion = nn.BCELoss()  # Binary Cross-Entropy Loss for classification

    running_x_to_c_test_loss, running_c_to_y_test_loss = 0.0, 0.0
    running_total_test_loss = 0.0
    total_test_samples = 0
    ground_truth_test_c, ground_truth_test_y = [], []
    x_to_c_test_predictions, c_to_y_test_predictions = [], []

    with torch.no_grad():
        for x, c, y in test_loader:
            # GPU
            x, c, y = x.to(device), c.to(device), y.to(device)

            # Ground truth array
            ground_truth_test_c.append(c.cpu())
            ground_truth_test_y.append(y.cpu())

            # Forward pass through the model
            x = x.to(model.layer1.weight.dtype)  # ensure data type of input tensor x matches data type of weights of the first linear layer
            predicted_c, predicted_y = model(x)

            # Squeeze the predictions to match the target dimensions
            predicted_c = predicted_c.squeeze()
            predicted_y = predicted_y.squeeze()

            x_to_c_test_predictions.append(predicted_c.detach().cpu().numpy())
            c_to_y_test_predictions.append(predicted_y.detach().cpu().numpy())

            c_loss = criterion(predicted_c, c.float())
            y_loss = criterion(predicted_y, y.float())

            total_loss = c_loss + y_loss

            # Accumulate loss values for testing
            running_x_to_c_test_loss += c_loss.item()
            running_c_to_y_test_loss += y_loss.item()
            running_total_test_loss += total_loss.item()

            total_test_samples += len(y)

    print(f'Test Concept Predictor Loss: {running_x_to_c_test_loss / len(test_loader):.4f}')
    print(f'Test Label Predictor Loss: {running_c_to_y_test_loss / len(test_loader):.4f}')
    print(f'Test Total Loss: {running_total_test_loss / len(test_loader):.4f}')

    return ground_truth_test_c, ground_truth_test_y, x_to_c_test_predictions, c_to_y_test_predictions

# %%
# Call the test function and print the results
ground_truth_test_c, ground_truth_test_y, x_to_c_test_predictions, c_to_y_test_predictions = test_model(x_to_y, test_loader)
# Out:
# Test Concept Predictor Loss: 0.2532
# Test Label Predictor Loss: 0.6627
# Test Total Loss: 0.9158

# %%
# Evaluate and print test results for the concept predictor
concept_test_results = evaluate_concept_predictor(ground_truth_test_c, x_to_c_test_predictions, concept_labels)
print("Test Concept Predictor Results:")
print(concept_test_results)
# Out:
# Test Concept Predictor Results:
#                              Label  Precision    Recall  F1 Score       AUC  \
# 0                        c_rsp_mod   0.970874  0.958466  0.964630  0.929783
# 1                        c_rsp_svr   0.960526  0.960526  0.960526  0.975690
# 2                       c_vent_low   0.993569  0.996774  0.995169  0.987749
# 3                  c_vent_moderate   1.000000  0.924528  0.960784  0.962264
# 4                      c_vent_high   0.997525  1.000000  0.998761  0.500000
# 5              c_max_renf_moderate   0.622222  0.421053  0.502242  0.647796
# 6                c_max_renf_severe   0.870270  0.821429  0.845144  0.853022
# 7              c_avg_renf_moderate   0.000000  0.000000  0.000000  0.500000
# 8                c_avg_renf_severe   0.694915  0.732143  0.713043  0.840209
# 9             c_max_respf_moderate   0.909091  0.588235  0.714286  0.792826
# 10              c_max_respf_severe   0.982143  0.994832  0.988447  0.791534
# 11            c_avg_respf_moderate   0.926316  0.792793  0.854369  0.884451
# 12              c_avg_respf_severe   0.933333  0.962199  0.947547  0.892604
# 13             c_max_cnsf_moderate   0.812030  0.765957  0.788321  0.835450
# 14               c_max_cnsf_severe   0.947137  0.968468  0.957684  0.951267
# 15             c_avg_cnsf_moderate   0.000000  0.000000  0.000000  0.500000
# 16               c_avg_cnsf_severe   0.000000  0.000000  0.000000       NaN
# 17                       c_sepsis3   0.997409  0.997409  0.997409  0.970927
# 18                         c_shock   0.977011  0.994152  0.985507  0.932560
# 19                   ards_detected   0.706070  0.859922  0.775439  0.617036
# 20             aspiration_detected   0.679012  0.407407  0.509259  0.655377
# 21  bilateral_infiltrates_detected   0.803618  0.977987  0.882270  0.547133
# 22         cardiac_arrest_detected   0.450704  0.213333  0.289593  0.529895
# 23        cardiac_failure_detected   0.727536  0.880702  0.796825  0.545393
# 24           pancreatitis_detected   0.000000  0.000000  0.000000  0.500000
# 25              pneumonia_detected   0.764706  0.827715  0.794964  0.665682
# 26                  trali_detected   0.000000  0.000000  0.000000  0.500000
# 27                         Average   0.693556  0.668372  0.674897  0.715135
#
#     Accuracy
# 0   0.945545
# 1   0.985149
# 2   0.992574
# 3   0.990099
# 4   0.997525
# 5   0.725248
# 6   0.853960
# 7   0.891089
# 8   0.918317
# 9   0.980198
# 10  0.977723
# 11  0.925743
# 12  0.923267
# 13  0.856436
# 14  0.952970
# 15  0.995050
# 16  1.000000
# 17  0.995050
# 18  0.975248
# 19  0.683168
# 20  0.737624
# 21  0.794554
# 22  0.611386
# 23  0.683168
# 24  0.893564
# 25  0.717822
# 26  0.938119
# 27  0.886689

# %%
# Evaluate and print test results for the label predictor
label_test_results = evaluate_label_predictor(ground_truth_test_y, c_to_y_test_predictions)
print("Test Label Predictor Results:")
print(label_test_results)
# Out:
# Test Label Predictor Results:
#          Precision    Recall  F1 Score       AUC  Accuracy
# Metrics    0.61809  0.664865  0.640625  0.658916  0.658416

# %% [markdown]
# # Completeness Score

# %%
from sklearn.metrics import mutual_info_score
import numpy as np

def compute_mutual_information(true_labels, predicted_values):
    # Convert the predicted values to binary classes
    predicted_classes = (predicted_values > 0.5).astype(int)
    return mutual_info_score(true_labels, predicted_classes)

# Compute mutual information I(y; c)
def compute_I_y_c(ground_truth_val_y, c_to_y_val_predictions):
    true_values = np.concatenate([gy.numpy() for gy in ground_truth_val_y])
    predicted_values = np.concatenate([py.squeeze() for py in c_to_y_val_predictions])
    return compute_mutual_information(true_values, predicted_values)

# Compute mutual information I(y; c, x)
def compute_I_y_c_x(ground_truth_val_y, x_to_c_val_predictions, c_to_y_val_predictions):
    true_values = np.concatenate([gy.numpy() for gy in ground_truth_val_y])

    # Compute mutual information for each concept and label pair
    predicted_concepts = np.concatenate(x_to_c_val_predictions)
    predicted_labels = np.concatenate([py.squeeze() for py in c_to_y_val_predictions])

    combined_predictions = np.column_stack((predicted_concepts, predicted_labels))

    # Flatten combined_predictions to make it 1D
    combined_predictions_flat = combined_predictions.flatten()

    return mutual_info_score(true_values, combined_predictions_flat[:len(true_values)])

# Compute the Completeness Score
def compute_completeness_score(I_y_c, I_y_c_x):
    return I_y_c / I_y_c_x

# Calculate mutual information
I_y_c = compute_I_y_c(ground_truth_val_y, c_to_y_val_predictions)
print(f"Mutual Information I(y; c): {I_y_c}")

I_y_c_x = compute_I_y_c_x(ground_truth_val_y, x_to_c_val_predictions, c_to_y_val_predictions)
print(f"Mutual Information I(y; c, x): {I_y_c_x}")

# Calculate completeness score
completeness_score = compute_completeness_score(I_y_c, I_y_c_x)
print(f"Completeness Score: {completeness_score}")
# Out:
# Mutual Information I(y; c): 0.06460448094085688
# Mutual Information I(y; c, x): 0.6913553125271956
# Completeness Score: 0.09344613365984016
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/cluster/_supervised.py:64: UserWarning: Clustering metrics expects discrete values but received binary values for label, and continuous values for target
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # Model Evaluation

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Function to get weights contribution from each feature to each concept
def get_feature_to_concept_weights(model, feature_names, concept_names):
    layer1_weights = model.layer1.weight.data.cpu().numpy()
    contributions = np.zeros((len(concept_names), len(feature_names)))

    for i, feature in enumerate(feature_names):
        for j, concept in enumerate(concept_names):
            contributions[j, i] = layer1_weights[j, i]

    return pd.DataFrame(contributions, index=concept_names, columns=feature_names)

# Function to get weights contribution from each concept to final label
def get_concept_to_label_weights(model, concept_names, label_names):
    output_weights = model.label_output_layer.weight.data.cpu().numpy()
    contributions = np.zeros((len(label_names), len(concept_names)))

    for i, concept in enumerate(concept_names):
        for j, label in enumerate(label_names):
            contributions[j, i] = output_weights[j, i]

    return pd.DataFrame(contributions, index=label_names, columns=concept_names)


# Get feature and concept names
feature_names = data_processor.get_features()
concept_names = data_processor.get_concepts()
label_names = ['ARDS']

# Get weights contributions
feature_to_concept_contributions = get_feature_to_concept_weights(x_to_y, feature_names, concept_names)
concept_to_label_contributions = get_concept_to_label_weights(x_to_y, concept_names, label_names)

# %% [markdown]
# A. Feature to Concept

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(feature_to_concept_contributions, cmap='viridis', cbar=True)
plt.title('Feature to Concept Weights Contribution')
plt.xlabel('Features')
plt.ylabel('Concepts')
plt.show()

print("Feature to Concept Weights Contribution:")
print(feature_to_concept_contributions)
# Out:
# Feature to Concept Weights Contribution:
#                                 upper_respiratory_infections  \
# c_rsp_mod                                          -0.026004
# c_rsp_svr                                           0.155386
# c_vent_low                                          0.109078
# c_vent_moderate                                    -0.014957
# c_vent_high                                        -0.110413
# c_max_renf_moderate                                 0.120808
# c_max_renf_severe                                   0.235585
# c_avg_renf_moderate                                -0.270452
# c_avg_renf_severe                                  -0.158006
# c_max_respf_moderate                                0.157088
# c_max_respf_severe                                 -0.105223
# c_avg_respf_moderate                                0.206659
# c_avg_respf_severe                                 -0.025688
# c_max_cnsf_moderate                                 0.193965
# c_max_cnsf_severe                                  -0.053906
# c_avg_cnsf_moderate                                 0.221831
# c_avg_cnsf_severe                                  -0.110153
# c_sepsis3                                          -0.227916
# c_shock                                             0.183975
# ards_detected                                      -0.238651
# aspiration_detected                                 0.035966
# bilateral_infiltrates_detected                     -0.047484
# cardiac_arrest_detected                            -0.077051
# cardiac_failure_detected                           -0.182962
# pancreatitis_detected                              -0.075851
# pneumonia_detected                                  0.025585
# trali_detected                                      0.111393
#
#                                 influenza_pneumonia  \
# c_rsp_mod                                 -0.375422
# c_rsp_svr                                 -0.137125
# c_vent_low                                -0.501623
# c_vent_moderate                           -0.015177
# c_vent_high                               -0.276896
# c_max_renf_moderate                        0.051934
# c_max_renf_severe                         -0.050357
# c_avg_renf_moderate                       -0.321182
# c_avg_renf_severe                          0.086262
# c_max_respf_moderate                       0.587429
# c_max_respf_severe                         0.239587
# c_avg_respf_moderate                       0.758947
# c_avg_respf_severe                        -0.324771
# c_max_cnsf_moderate                       -0.023732
# c_max_cnsf_severe                          0.166260
# c_avg_cnsf_moderate                        0.077441
# c_avg_cnsf_severe                          0.330290
# c_sepsis3                                 -0.065473
# c_shock                                    0.056548
# ards_detected                              0.201524
# aspiration_detected                        0.065681
# bilateral_infiltrates_detected             0.066427
# cardiac_arrest_detected                   -0.395615
# cardiac_failure_detected                   0.576167
# pancreatitis_detected                      0.054173
# pneumonia_detected                        -0.382108
# trali_detected                            -0.358073
#
#                                 acute_lower_respiratory_infections  \
# c_rsp_mod                                                -0.074495
# c_rsp_svr                                                -0.098574
# c_vent_low                                                0.034611
# c_vent_moderate                                           0.152659
# c_vent_high                                              -0.044666
# c_max_renf_moderate                                      -0.011369
# c_max_renf_severe                                        -0.142234
# c_avg_renf_moderate                                      -0.123325
# c_avg_renf_severe                                        -0.072998
# c_max_respf_moderate                                     -0.091666
# c_max_respf_severe                                       -0.112602
# c_avg_respf_moderate                                      0.170738
# c_avg_respf_severe                                       -0.268978
# c_max_cnsf_moderate                                      -0.101997
# c_max_cnsf_severe                                         0.180727
# c_avg_cnsf_moderate                                      -0.087233
# c_avg_cnsf_severe                                        -0.001108
# c_sepsis3                                                -0.066554
# c_shock                                                  -0.141366
# ards_detected                                            -0.089480
# aspiration_detected                                       0.001515
# bilateral_infiltrates_detected                           -0.033359
# cardiac_arrest_detected                                   0.053068
# cardiac_failure_detected                                 -0.124756
# pancreatitis_detected                                    -0.045144
# pneumonia_detected                                       -0.061042
# trali_detected                                            0.085415
#
#                                 chronic_lower_respiratory_diseases  \
# c_rsp_mod                                                -0.244726
# c_rsp_svr                                                -0.080010
# c_vent_low                                               -0.107867
# c_vent_moderate                                           0.113911
# c_vent_high                                              -0.256373
# c_max_renf_moderate                                       0.362270
# c_max_renf_severe                                        -0.317452
# c_avg_renf_moderate                                       0.017074
# c_avg_renf_severe                                        -0.255731
# c_max_respf_moderate                                      0.316989
# c_max_respf_severe                                        0.388608
# c_avg_respf_moderate                                      0.741998
# c_avg_respf_severe                                       -0.099779
# c_max_cnsf_moderate                                      -0.149232
# c_max_cnsf_severe                                        -0.387441
# c_avg_cnsf_moderate                                       0.299243
# c_avg_cnsf_severe                                        -0.158519
# c_sepsis3                                                -0.114556
# c_shock                                                   0.274994
# ards_detected                                            -0.221578
# aspiration_detected                                       0.246416
# bilateral_infiltrates_detected                           -0.130411
# cardiac_arrest_detected                                   0.388259
# cardiac_failure_detected                                  0.253967
# pancreatitis_detected                                     0.202289
# pneumonia_detected                                        0.108734
# trali_detected                                            0.171317
#
#                                 lung_diseases_due_to_external_agents  \
# c_rsp_mod                                                  -0.198018
# c_rsp_svr                                                   0.016391
# c_vent_low                                                  0.500422
# c_vent_moderate                                            -0.464180
# c_vent_high                                                -0.473390
# c_max_renf_moderate                                         0.145333
# c_max_renf_severe                                          -0.472291
# c_avg_renf_moderate                                         0.102640
# c_avg_renf_severe                                           0.010587
# c_max_respf_moderate                                       -0.025176
# c_max_respf_severe                                          0.349097
# c_avg_respf_moderate                                        0.601834
# c_avg_respf_severe                                         -0.425416
# c_max_cnsf_moderate                                         0.244702
# c_max_cnsf_severe                                           0.096462
# c_avg_cnsf_moderate                                         0.219626
# c_avg_cnsf_severe                                           0.024569
# c_sepsis3                                                   0.220689
# c_shock                                                     0.126887
# ards_detected                                               0.058348
# aspiration_detected                                         0.420401
# bilateral_infiltrates_detected                             -0.091926
# cardiac_arrest_detected                                    -0.309930
# cardiac_failure_detected                                   -0.053226
# pancreatitis_detected                                      -0.124815
# pneumonia_detected                                          0.023587
# trali_detected                                             -0.201854
#
#                                 other_respiratory_diseases  InvasiveVent  \
# c_rsp_mod                                        -0.223712      0.071599
# c_rsp_svr                                         0.335677      0.036239
# c_vent_low                                        0.377702      0.096553
# c_vent_moderate                                  -0.381438      0.035904
# c_vent_high                                       0.307941      0.115113
# c_max_renf_moderate                              -0.143072     -0.011511
# c_max_renf_severe                                -0.215326      0.166705
# c_avg_renf_moderate                               0.207301      0.190277
# c_avg_renf_severe                                 0.605374      0.016693
# c_max_respf_moderate                              0.458240      0.153644
# c_max_respf_severe                                0.086279      0.227742
# c_avg_respf_moderate                              0.693789      0.046604
# c_avg_respf_severe                                0.553939      0.346516
# c_max_cnsf_moderate                               0.034695      0.146370
# c_max_cnsf_severe                                 0.411598     -0.017995
# c_avg_cnsf_moderate                              -0.119761      0.027207
# c_avg_cnsf_severe                                -0.339429      0.055446
# c_sepsis3                                        -0.531950      0.228403
# c_shock                                           0.025960      0.035048
# ards_detected                                     0.325955     -0.408804
# aspiration_detected                              -0.276596     -0.065146
# bilateral_infiltrates_detected                    0.206896      0.204023
# cardiac_arrest_detected                          -0.338248      0.218639
# cardiac_failure_detected                          0.440608      0.079331
# pancreatitis_detected                            -0.000382      0.110396
# pneumonia_detected                                0.177928     -0.039457
# trali_detected                                   -0.234334      0.020937
#
#                                 SupplementalOxygen      HFNC  NonInvasiveVent  \
# c_rsp_mod                                -0.527466 -0.274215        -0.096884
# c_rsp_svr                                 0.262047  0.143456        -0.042112
# c_vent_low                                0.088550 -0.134172        -0.219240
# c_vent_moderate                           0.294145 -0.027469         0.139675
# c_vent_high                               0.352835 -0.110551         0.069957
# c_max_renf_moderate                       0.313557 -0.130109        -0.083796
# c_max_renf_severe                         0.069976 -0.198020        -0.405473
# c_avg_renf_moderate                      -0.896583  0.324083         0.370703
# c_avg_renf_severe                        -0.075543 -0.251106        -0.022087
# c_max_respf_moderate                      0.021113 -0.012669         0.083670
# c_max_respf_severe                       -0.139636  0.297117         0.020553
# c_avg_respf_moderate                     -0.273934 -0.077703        -0.037444
# c_avg_respf_severe                        0.216707 -0.113661        -0.223433
# c_max_cnsf_moderate                       0.057188  0.308860         0.265060
# c_max_cnsf_severe                         0.542686 -0.255579         0.046459
# c_avg_cnsf_moderate                       0.167023 -0.117690         0.217851
# c_avg_cnsf_severe                         0.155970  0.053942         0.007604
# c_sepsis3                                 0.197478 -0.412667        -0.388231
# c_shock                                   0.040185 -0.379726        -0.174072
# ards_detected                             0.220471  0.078044         0.126254
# aspiration_detected                      -0.611671 -0.152881         0.048704
# bilateral_infiltrates_detected            0.352319 -0.148375        -0.096626
# cardiac_arrest_detected                  -0.297547 -0.285079        -0.038277
# cardiac_failure_detected                 -0.051782  0.125712        -0.032473
# pancreatitis_detected                    -0.152944 -0.154578        -0.006574
# pneumonia_detected                        0.517893  0.547047         0.524132
# trali_detected                           -0.280146 -0.260143        -0.152022
#
#                                 ...  avg_pao2fio2ratio_novent  \
# c_rsp_mod                       ...                 -0.061798
# c_rsp_svr                       ...                 -0.321050
# c_vent_low                      ...                  0.052646
# c_vent_moderate                 ...                 -0.286806
# c_vent_high                     ...                  0.225175
# c_max_renf_moderate             ...                  0.051032
# c_max_renf_severe               ...                 -0.060883
# c_avg_renf_moderate             ...                 -0.106465
# c_avg_renf_severe               ...                 -0.241958
# c_max_respf_moderate            ...                 -0.078576
# c_max_respf_severe              ...                  0.292622
# c_avg_respf_moderate            ...                 -0.026732
# c_avg_respf_severe              ...                  0.258289
# c_max_cnsf_moderate             ...                  0.221449
# c_max_cnsf_severe               ...                 -0.231659
# c_avg_cnsf_moderate             ...                  0.131236
# c_avg_cnsf_severe               ...                  0.168415
# c_sepsis3                       ...                 -0.154224
# c_shock                         ...                 -0.030587
# ards_detected                   ...                  0.071328
# aspiration_detected             ...                  0.100768
# bilateral_infiltrates_detected  ...                  0.248576
# cardiac_arrest_detected         ...                 -0.222394
# cardiac_failure_detected        ...                 -0.064513
# pancreatitis_detected           ...                  0.149800
# pneumonia_detected              ...                 -0.215011
# trali_detected                  ...                  0.013689
#
#                                 avg_pao2fio2ratio_vent  \
# c_rsp_mod                                     0.487796
# c_rsp_svr                                    -0.302137
# c_vent_low                                    0.175415
# c_vent_moderate                              -0.042312
# c_vent_high                                  -0.097572
# c_max_renf_moderate                          -0.151597
# c_max_renf_severe                             0.450920
# c_avg_renf_moderate                           0.023072
# c_avg_renf_severe                            -0.092183
# c_max_respf_moderate                         -0.357144
# c_max_respf_severe                           -0.038271
# c_avg_respf_moderate                         -0.096570
# c_avg_respf_severe                           -0.316436
# c_max_cnsf_moderate                          -0.320067
# c_max_cnsf_severe                            -0.262337
# c_avg_cnsf_moderate                           0.309909
# c_avg_cnsf_severe                             0.580339
# c_sepsis3                                    -0.329271
# c_shock                                      -0.007938
# ards_detected                                 1.059580
# aspiration_detected                           0.196962
# bilateral_infiltrates_detected               -0.015758
# cardiac_arrest_detected                      -0.447538
# cardiac_failure_detected                     -0.348128
# pancreatitis_detected                         0.478980
# pneumonia_detected                            0.207965
# trali_detected                                0.093262
#
#                                 max_respiration_pao2fio2ratio_novent  \
# c_rsp_mod                                                   0.286658
# c_rsp_svr                                                  -0.229173
# c_vent_low                                                 -0.160598
# c_vent_moderate                                            -0.154664
# c_vent_high                                                -0.462624
# c_max_renf_moderate                                        -0.242760
# c_max_renf_severe                                          -0.192715
# c_avg_renf_moderate                                        -0.302078
# c_avg_renf_severe                                           0.116912
# c_max_respf_moderate                                       -0.057775
# c_max_respf_severe                                          0.054735
# c_avg_respf_moderate                                       -0.058575
# c_avg_respf_severe                                         -0.526173
# c_max_cnsf_moderate                                        -0.219370
# c_max_cnsf_severe                                           0.157749
# c_avg_cnsf_moderate                                        -0.116876
# c_avg_cnsf_severe                                           0.065661
# c_sepsis3                                                  -0.492964
# c_shock                                                    -0.243569
# ards_detected                                               0.071251
# aspiration_detected                                        -0.016679
# bilateral_infiltrates_detected                             -0.038181
# cardiac_arrest_detected                                    -0.222991
# cardiac_failure_detected                                   -0.167076
# pancreatitis_detected                                      -0.170320
# pneumonia_detected                                          0.056226
# trali_detected                                              0.613384
#
#                                 max_respiration_pao2fio2ratio_vent  \
# c_rsp_mod                                                 0.577721
# c_rsp_svr                                                -0.077125
# c_vent_low                                               -0.012438
# c_vent_moderate                                          -0.025727
# c_vent_high                                              -0.338781
# c_max_renf_moderate                                      -0.057721
# c_max_renf_severe                                        -0.230697
# c_avg_renf_moderate                                       0.092905
# c_avg_renf_severe                                         0.084070
# c_max_respf_moderate                                      0.218671
# c_max_respf_severe                                       -0.038937
# c_avg_respf_moderate                                      0.003973
# c_avg_respf_severe                                       -0.183012
# c_max_cnsf_moderate                                      -0.095576
# c_max_cnsf_severe                                        -0.042190
# c_avg_cnsf_moderate                                      -0.044199
# c_avg_cnsf_severe                                        -0.329867
# c_sepsis3                                                 0.051469
# c_shock                                                  -0.002861
# ards_detected                                             0.161413
# aspiration_detected                                      -0.035251
# bilateral_infiltrates_detected                            0.028202
# cardiac_arrest_detected                                   0.094656
# cardiac_failure_detected                                  0.266382
# pancreatitis_detected                                    -0.297437
# pneumonia_detected                                       -0.041461
# trali_detected                                            0.187169
#
#                                 avg_gcs_min  max_cns_gcs_min  sofa_score  \
# c_rsp_mod                         -0.025366        -0.491440   -0.015675
# c_rsp_svr                         -0.012435         0.210231    0.312019
# c_vent_low                         0.072474         0.152289    0.003071
# c_vent_moderate                    0.056382        -0.389068    0.059590
# c_vent_high                       -0.113340         0.317609   -0.124017
# c_max_renf_moderate               -0.151988        -0.769930    0.078397
# c_max_renf_severe                  0.342544        -0.416811   -0.209612
# c_avg_renf_moderate                0.086350        -0.102074   -0.002503
# c_avg_renf_severe                 -0.086022        -0.607792    0.323957
# c_max_respf_moderate              -0.125539         0.465942    0.153278
# c_max_respf_severe                 0.358093        -0.267897   -0.205421
# c_avg_respf_moderate              -0.052330        -0.128207    0.017861
# c_avg_respf_severe                 0.206182        -0.117754   -0.035448
# c_max_cnsf_moderate                0.518231         0.134638    0.049601
# c_max_cnsf_severe                  0.081072         0.257086    0.108846
# c_avg_cnsf_moderate                0.058309         0.016588    0.060929
# c_avg_cnsf_severe                  0.113753         0.041774    0.191219
# c_sepsis3                         -0.055096        -0.097709   -0.026245
# c_shock                            0.179484        -0.182254    0.120148
# ards_detected                      0.258680        -0.261268    0.092935
# aspiration_detected               -0.168900        -0.423481   -0.390052
# bilateral_infiltrates_detected    -0.188830        -0.988851   -0.170122
# cardiac_arrest_detected           -0.147126         0.082595   -0.290492
# cardiac_failure_detected           0.147908         0.148313    0.030083
# pancreatitis_detected             -0.010006        -0.501441    0.072537
# pneumonia_detected                 0.017391        -0.645369   -0.131969
# trali_detected                    -0.107356         0.338201   -0.231946
#
#                                 suspected_infection  one_vasopressor  \
# c_rsp_mod                                  0.135448        -0.159907
# c_rsp_svr                                  0.264915         0.100065
# c_vent_low                                 0.316126        -0.079418
# c_vent_moderate                           -0.517524         0.121476
# c_vent_high                               -0.345894        -0.007670
# c_max_renf_moderate                        0.370081        -0.242789
# c_max_renf_severe                          0.327908        -0.248285
# c_avg_renf_moderate                        0.035332         0.257496
# c_avg_renf_severe                         -0.049490        -0.129232
# c_max_respf_moderate                       0.310714        -0.421116
# c_max_respf_severe                         0.192039        -0.434930
# c_avg_respf_moderate                       0.172036         0.260318
# c_avg_respf_severe                         0.358135         0.049525
# c_max_cnsf_moderate                        0.140377         0.256792
# c_max_cnsf_severe                          0.147686        -0.097891
# c_avg_cnsf_moderate                       -0.228405         0.088206
# c_avg_cnsf_severe                          0.108231         0.150973
# c_sepsis3                                  0.431835         0.651817
# c_shock                                   -0.051704        -0.188493
# ards_detected                              0.039700         0.121091
# aspiration_detected                       -0.258435        -0.387605
# bilateral_infiltrates_detected             0.474592         0.027587
# cardiac_arrest_detected                   -0.133169         0.208486
# cardiac_failure_detected                   0.238779         0.550373
# pancreatitis_detected                     -0.056630         0.238903
# pneumonia_detected                         0.261679         0.290999
# trali_detected                            -0.043867         0.165862
#
#                                 multi_vasopressor
# c_rsp_mod                               -0.120456
# c_rsp_svr                                0.305946
# c_vent_low                               0.626489
# c_vent_moderate                          0.142461
# c_vent_high                              0.339682
# c_max_renf_moderate                      0.311540
# c_max_renf_severe                        0.073218
# c_avg_renf_moderate                      0.475254
# c_avg_renf_severe                       -0.526090
# c_max_respf_moderate                    -0.090948
# c_max_respf_severe                      -0.370828
# c_avg_respf_moderate                     0.263245
# c_avg_respf_severe                      -0.285091
# c_max_cnsf_moderate                      0.000050
# c_max_cnsf_severe                       -0.005747
# c_avg_cnsf_moderate                      0.409491
# c_avg_cnsf_severe                        0.601641
# c_sepsis3                                0.526514
# c_shock                                 -0.120468
# ards_detected                            0.140928
# aspiration_detected                     -0.435193
# bilateral_infiltrates_detected           0.142080
# cardiac_arrest_detected                  0.152759
# cardiac_failure_detected                 0.093612
# pancreatitis_detected                    0.306898
# pneumonia_detected                       0.142269
# trali_detected                           0.078424
#
# [27 rows x 26 columns]

# %% [markdown]
# B. Concept to Label

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(concept_to_label_contributions, cmap='viridis', cbar=True)
plt.title('Concept to Label Weights Contribution')
plt.xlabel('Concepts')
plt.ylabel('Labels')
plt.show()

print("Concept to Label Weights Contribution:")
print(concept_to_label_contributions)
# Out:
# Concept to Label Weights Contribution:
#          c_rsp_mod  c_rsp_svr    c_vent_low  c_vent_moderate  c_vent_high  \
# ARDS -4.228752e-09  -0.000895  2.379108e-07        -0.059436      0.00846
#
#       c_max_renf_moderate  c_max_renf_severe  c_avg_renf_moderate  \
# ARDS            -0.020278           0.020839             0.022134
#
#       c_avg_renf_severe  c_max_respf_moderate  ...  c_sepsis3   c_shock  \
# ARDS          -0.157047             -0.000054  ...  -0.131883  0.024284
#
#       ards_detected  aspiration_detected  bilateral_infiltrates_detected  \
# ARDS        0.01102            -0.149503                       -0.245856
#
#       cardiac_arrest_detected  cardiac_failure_detected  \
# ARDS                 0.028298                  -0.01423
#
#       pancreatitis_detected  pneumonia_detected  trali_detected
# ARDS              -0.023083            0.224358       -0.236559
#
# [1 rows x 27 columns]

# %% [markdown]
# C. Combined Feature-Concept Pair to Label

# %%
# Extract the weights for the label 'ARDS'
concept_to_label_weights = concept_to_label_contributions.loc[label_names[0]].values

# Reshape concept_to_label_weights for element-wise multiplication
concept_to_label_weights = concept_to_label_weights.reshape(-1, 1)

# Calculate the combined contributions by element-wise multiplication
combined_contributions = feature_to_concept_contributions.values * concept_to_label_weights

# Create a DataFrame for the combined contributions
combined_df = pd.DataFrame(combined_contributions, index=concept_names, columns=feature_names)

# Plotting the combined heatmap
plt.figure(figsize=(14, 10))
sns.heatmap(combined_df, cmap='viridis', cbar=True, fmt=".2f")
plt.title('Combined Feature to Concept Contributions Predicting ARDS')
plt.xlabel('Features')
plt.ylabel('Concepts')
plt.show()

print("Combined Contributions Predicting ARDS:")
print(combined_df)
# Out:
# Combined Contributions Predicting ARDS:
#                                 upper_respiratory_infections  \
# c_rsp_mod                                       1.099646e-10
# c_rsp_svr                                      -1.390648e-04
# c_vent_low                                      2.595072e-08
# c_vent_moderate                                 8.889995e-04
# c_vent_high                                    -9.340756e-04
# c_max_renf_moderate                            -2.449684e-03
# c_max_renf_severe                               4.909325e-03
# c_avg_renf_moderate                            -5.986093e-03
# c_avg_renf_severe                               2.481436e-02
# c_max_respf_moderate                           -8.413529e-06
# c_max_respf_severe                              1.441776e-02
# c_avg_respf_moderate                           -1.245570e-03
# c_avg_respf_severe                              6.519505e-03
# c_max_cnsf_moderate                             7.281778e-04
# c_max_cnsf_severe                               7.281460e-03
# c_avg_cnsf_moderate                            -1.493415e-02
# c_avg_cnsf_severe                               6.763332e-03
# c_sepsis3                                       3.005820e-02
# c_shock                                         4.467649e-03
# ards_detected                                  -2.630051e-03
# aspiration_detected                            -5.376974e-03
# bilateral_infiltrates_detected                  1.167434e-02
# cardiac_arrest_detected                        -2.180392e-03
# cardiac_failure_detected                        2.603537e-03
# pancreatitis_detected                           1.750874e-03
# pneumonia_detected                              5.740268e-03
# trali_detected                                 -2.635092e-02
#
#                                 influenza_pneumonia  \
# c_rsp_mod                              1.587568e-09
# c_rsp_svr                              1.227219e-04
# c_vent_low                            -1.193415e-07
# c_vent_moderate                        9.020543e-04
# c_vent_high                           -2.342498e-03
# c_max_renf_moderate                   -1.053101e-03
# c_max_renf_severe                     -1.049388e-03
# c_avg_renf_moderate                   -7.108928e-03
# c_avg_renf_severe                     -1.354719e-02
# c_max_respf_moderate                  -3.146231e-05
# c_max_respf_severe                    -3.282848e-02
# c_avg_respf_moderate                  -4.574302e-03
# c_avg_respf_severe                     8.242599e-02
# c_max_cnsf_moderate                   -8.909564e-05
# c_max_cnsf_severe                     -2.245789e-02
# c_avg_cnsf_moderate                   -5.213468e-03
# c_avg_cnsf_severe                     -2.027965e-02
# c_sepsis3                              8.634802e-03
# c_shock                                1.373204e-03
# ards_detected                          2.220893e-03
# aspiration_detected                   -9.819482e-03
# bilateral_infiltrates_detected        -1.633157e-02
# cardiac_arrest_detected               -1.119516e-02
# cardiac_failure_detected              -8.198839e-03
# pancreatitis_detected                 -1.250476e-03
# pneumonia_detected                    -8.572883e-02
# trali_detected                         8.470537e-02
#
#                                 acute_lower_respiratory_infections  \
# c_rsp_mod                                             3.150199e-10
# c_rsp_svr                                             8.822053e-05
# c_vent_low                                            8.234261e-09
# c_vent_moderate                                      -9.073469e-03
# c_vent_high                                          -3.778703e-04
# c_max_renf_moderate                                   2.305453e-04
# c_max_renf_severe                                    -2.964004e-03
# c_avg_renf_moderate                                  -2.729623e-03
# c_avg_renf_severe                                     1.146418e-02
# c_max_respf_moderate                                  4.909545e-06
# c_max_respf_severe                                    1.542888e-02
# c_avg_respf_moderate                                 -1.029065e-03
# c_avg_respf_severe                                    6.826577e-02
# c_max_cnsf_moderate                                  -3.829123e-04
# c_max_cnsf_severe                                    -2.441209e-02
# c_avg_cnsf_moderate                                   5.872713e-03
# c_avg_cnsf_severe                                     6.803908e-05
# c_sepsis3                                             8.777290e-03
# c_shock                                              -3.432921e-03
# ards_detected                                        -9.861111e-04
# aspiration_detected                                  -2.264425e-04
# bilateral_infiltrates_detected                        8.201450e-03
# cardiac_arrest_detected                               1.501728e-03
# cardiac_failure_detected                              1.775268e-03
# pancreatitis_detected                                 1.042073e-03
# pneumonia_detected                                   -1.369526e-02
# trali_detected                                       -2.020558e-02
#
#                                 chronic_lower_respiratory_diseases  \
# c_rsp_mod                                             1.034888e-09
# c_rsp_svr                                             7.160566e-05
# c_vent_low                                           -2.566277e-08
# c_vent_moderate                                      -6.770452e-03
# c_vent_high                                          -2.168875e-03
# c_max_renf_moderate                                  -7.345955e-03
# c_max_renf_severe                                    -6.615341e-03
# c_avg_renf_moderate                                   3.779011e-04
# c_avg_renf_severe                                     4.016192e-02
# c_max_respf_moderate                                 -1.697774e-05
# c_max_respf_severe                                   -5.324748e-02
# c_avg_respf_moderate                                 -4.472148e-03
# c_avg_respf_severe                                    2.532362e-02
# c_max_cnsf_moderate                                  -5.602423e-04
# c_max_cnsf_severe                                     5.233448e-02
# c_avg_cnsf_moderate                                  -2.014571e-02
# c_avg_cnsf_severe                                     9.732985e-03
# c_sepsis3                                             1.510797e-02
# c_shock                                               6.677931e-03
# ards_detected                                        -2.441900e-03
# aspiration_detected                                  -3.683999e-02
# bilateral_infiltrates_detected                        3.206221e-02
# cardiac_arrest_detected                               1.098702e-02
# cardiac_failure_detected                             -3.613942e-03
# pancreatitis_detected                                -4.669459e-03
# pneumonia_detected                                    2.439530e-02
# trali_detected                                       -4.052646e-02
#
#                                 lung_diseases_due_to_external_agents  \
# c_rsp_mod                                               8.373697e-10
# c_rsp_svr                                              -1.466907e-05
# c_vent_low                                              1.190558e-07
# c_vent_moderate                                         2.758919e-02
# c_vent_high                                            -4.004802e-03
# c_max_renf_moderate                                    -2.946993e-03
# c_max_renf_severe                                      -9.842017e-03
# c_avg_renf_moderate                                     2.271800e-03
# c_avg_renf_severe                                      -1.662697e-03
# c_max_respf_moderate                                    1.348435e-06
# c_max_respf_severe                                     -4.783362e-02
# c_avg_respf_moderate                                   -3.627355e-03
# c_avg_respf_severe                                      1.079693e-01
# c_max_cnsf_moderate                                     9.186506e-04
# c_max_cnsf_severe                                      -1.302980e-02
# c_avg_cnsf_moderate                                    -1.478568e-02
# c_avg_cnsf_severe                                      -1.508504e-03
# c_sepsis3                                              -2.910501e-02
# c_shock                                                 3.081316e-03
# ards_detected                                           6.430245e-04
# aspiration_detected                                    -6.285117e-02
# bilateral_infiltrates_detected                          2.260053e-02
# cardiac_arrest_detected                                -8.770431e-03
# cardiac_failure_detected                                7.574079e-04
# pancreatitis_detected                                   2.881128e-03
# pneumonia_detected                                      5.291906e-03
# trali_detected                                          4.775036e-02
#
#                                 other_respiratory_diseases  InvasiveVent  \
# c_rsp_mod                                     9.460208e-10 -3.027744e-10
# c_rsp_svr                                    -3.004186e-04 -3.243267e-05
# c_vent_low                                    8.985944e-08  2.297106e-08
# c_vent_moderate                               2.267129e-02 -2.134017e-03
# c_vent_high                                   2.605129e-03  9.738397e-04
# c_max_renf_moderate                           2.901148e-03  2.334239e-04
# c_max_renf_severe                            -4.487150e-03  3.473934e-03
# c_avg_renf_moderate                           4.588326e-03  4.211528e-03
# c_avg_renf_severe                            -9.507236e-02 -2.621605e-03
# c_max_respf_moderate                         -2.454302e-05 -8.229082e-06
# c_max_respf_severe                           -1.182199e-02 -3.120547e-02
# c_avg_respf_moderate                         -4.181585e-03 -2.808907e-04
# c_avg_respf_severe                           -1.405881e-01 -8.794483e-02
# c_max_cnsf_moderate                           1.302505e-04  5.494965e-04
# c_max_cnsf_severe                            -5.559751e-02  2.430722e-03
# c_avg_cnsf_moderate                           8.062601e-03 -1.831645e-03
# c_avg_cnsf_severe                             2.084079e-02 -3.404343e-03
# c_sepsis3                                     7.015495e-02 -3.012240e-02
# c_shock                                       6.304015e-04  8.510940e-04
# ards_detected                                 3.592188e-03 -4.505226e-03
# aspiration_detected                           4.135187e-02  9.739505e-03
# bilateral_infiltrates_detected               -5.086667e-02 -5.016015e-02
# cardiac_arrest_detected                      -9.571798e-03  6.187072e-03
# cardiac_failure_detected                     -6.269839e-03 -1.128880e-03
# pancreatitis_detected                         8.812702e-06 -2.548271e-03
# pneumonia_detected                            3.991962e-02 -8.852403e-03
# trali_detected                                5.543378e-02 -4.952934e-03
#
#                                 SupplementalOxygen          HFNC  \
# c_rsp_mod                             2.230524e-09  1.159587e-09
# c_rsp_svr                            -2.345228e-04 -1.283878e-04
# c_vent_low                            2.106703e-08 -3.192090e-08
# c_vent_moderate                      -1.748288e-02  1.632631e-03
# c_vent_high                           2.984930e-03 -9.352449e-04
# c_max_renf_moderate                  -6.358160e-03  2.638299e-03
# c_max_renf_severe                     1.458229e-03 -4.126501e-03
# c_avg_renf_moderate                  -1.984466e-02  7.173136e-03
# c_avg_renf_severe                     1.186380e-02  3.943553e-02
# c_max_respf_moderate                 -1.130772e-06  6.785552e-07
# c_max_respf_severe                    1.913303e-02 -4.071122e-02
# c_avg_respf_moderate                  1.651046e-03  4.683298e-04
# c_avg_respf_severe                   -5.499970e-02  2.884678e-02
# c_max_cnsf_moderate                   2.146928e-04  1.159510e-03
# c_max_cnsf_severe                    -7.330454e-02  3.452291e-02
# c_avg_cnsf_moderate                  -1.124435e-02  7.923124e-03
# c_avg_cnsf_severe                    -9.576485e-03 -3.311989e-03
# c_sepsis3                            -2.604393e-02  5.442359e-02
# c_shock                               9.758608e-04 -9.221255e-03
# ards_detected                         2.429704e-03  8.600862e-04
# aspiration_detected                   9.144658e-02  2.285622e-02
# bilateral_infiltrates_detected       -8.661973e-02  3.647880e-02
# cardiac_arrest_detected              -8.420024e-03 -8.067194e-03
# cardiac_failure_detected              7.368618e-04 -1.788883e-03
# pancreatitis_detected                 3.530424e-03  3.568135e-03
# pneumonia_detected                    1.161934e-01  1.227344e-01
# trali_detected                        6.627111e-02  6.153915e-02
#
#                                 NonInvasiveVent  ...  \
# c_rsp_mod                          4.096996e-10  ...
# c_rsp_svr                          3.768884e-05  ...
# c_vent_low                        -5.215955e-08  ...
# c_vent_moderate                   -8.301798e-03  ...
# c_vent_high                        5.918262e-04  ...
# c_max_renf_moderate                1.699174e-03  ...
# c_max_renf_severe                 -8.449588e-03  ...
# c_avg_renf_moderate                8.205018e-03  ...
# c_avg_renf_severe                  3.468624e-03  ...
# c_max_respf_moderate              -4.481313e-06  ...
# c_max_respf_severe                -2.816232e-03  ...
# c_avg_respf_moderate               2.256802e-04  ...
# c_avg_respf_severe                 5.670669e-02  ...
# c_max_cnsf_moderate                9.950765e-04  ...
# c_max_cnsf_severe                 -6.275519e-03  ...
# c_avg_cnsf_moderate               -1.466618e-02  ...
# c_avg_cnsf_severe                 -4.669082e-04  ...
# c_sepsis3                          5.120095e-02  ...
# c_shock                           -4.227151e-03  ...
# ards_detected                      1.391387e-03  ...
# aspiration_detected               -7.281414e-03  ...
# bilateral_infiltrates_detected     2.375613e-02  ...
# cardiac_arrest_detected           -1.083162e-03  ...
# cardiac_failure_detected           4.620955e-04  ...
# pancreatitis_detected              1.517456e-04  ...
# pneumonia_detected                 1.175930e-01  ...
# trali_detected                     3.596217e-02  ...
#
#                                 avg_pao2fio2ratio_novent  \
# c_rsp_mod                                   2.613291e-10
# c_rsp_svr                                   2.873286e-04
# c_vent_low                                  1.252509e-08
# c_vent_moderate                             1.704667e-02
# c_vent_high                                 1.904945e-03
# c_max_renf_moderate                        -1.034809e-03
# c_max_renf_severe                          -1.268738e-03
# c_avg_renf_moderate                        -2.356450e-03
# c_avg_renf_severe                           3.799889e-02
# c_max_respf_moderate                        4.208492e-06
# c_max_respf_severe                         -4.009529e-02
# c_avg_respf_moderate                        1.611165e-04
# c_avg_respf_severe                         -6.555300e-02
# c_max_cnsf_moderate                         8.313557e-04
# c_max_cnsf_severe                           3.129193e-02
# c_avg_cnsf_moderate                        -8.835101e-03
# c_avg_cnsf_severe                          -1.034063e-02
# c_sepsis3                                   2.033950e-02
# c_shock                                    -7.427691e-04
# ards_detected                               7.860752e-04
# aspiration_detected                        -1.506505e-02
# bilateral_infiltrates_detected             -6.111389e-02
# cardiac_arrest_detected                    -6.293348e-03
# cardiac_failure_detected                    9.180162e-04
# pancreatitis_detected                      -3.457848e-03
# pneumonia_detected                         -4.823935e-02
# trali_detected                             -3.238273e-03
#
#                                 avg_pao2fio2ratio_vent  \
# c_rsp_mod                                -2.062767e-09
# c_rsp_svr                                 2.704020e-04
# c_vent_low                                4.173322e-08
# c_vent_moderate                           2.514880e-03
# c_vent_high                              -8.254464e-04
# c_max_renf_moderate                       3.074021e-03
# c_max_renf_severe                         9.396659e-03
# c_avg_renf_moderate                       5.106674e-04
# c_avg_renf_severe                         1.447715e-02
# c_max_respf_moderate                      1.912837e-05
# c_max_respf_severe                        5.243886e-03
# c_avg_respf_moderate                      5.820420e-04
# c_avg_respf_severe                        8.031061e-02
# c_max_cnsf_moderate                      -1.201583e-03
# c_max_cnsf_severe                         3.543583e-02
# c_avg_cnsf_moderate                      -2.086378e-02
# c_avg_cnsf_severe                        -3.563259e-02
# c_sepsis3                                 4.342510e-02
# c_shock                                  -1.927670e-04
# ards_detected                             1.167710e-02
# aspiration_detected                      -2.944645e-02
# bilateral_infiltrates_detected            3.874187e-03
# cardiac_arrest_detected                  -1.266450e-02
# cardiac_failure_detected                  4.953851e-03
# pancreatitis_detected                    -1.105635e-02
# pneumonia_detected                        4.665864e-02
# trali_detected                           -2.206188e-02
#
#                                 max_respiration_pao2fio2ratio_novent  \
# c_rsp_mod                                              -1.212205e-09
# c_rsp_svr                                               2.051019e-04
# c_vent_low                                             -3.820802e-08
# c_vent_moderate                                         9.192683e-03
# c_vent_high                                            -3.913727e-03
# c_max_renf_moderate                                     4.922578e-03
# c_max_renf_severe                                      -4.015971e-03
# c_avg_renf_moderate                                    -6.686099e-03
# c_avg_renf_severe                                      -1.836065e-02
# c_max_respf_moderate                                    3.094378e-06
# c_max_respf_severe                                     -7.499790e-03
# c_avg_respf_moderate                                    3.530411e-04
# c_avg_respf_severe                                      1.335411e-01
# c_max_cnsf_moderate                                    -8.235513e-04
# c_max_cnsf_severe                                      -2.130835e-02
# c_avg_cnsf_moderate                                     7.868380e-03
# c_avg_cnsf_severe                                      -4.031530e-03
# c_sepsis3                                               6.501336e-02
# c_shock                                                -5.914812e-03
# ards_detected                                           7.852186e-04
# aspiration_detected                                     2.493534e-03
# bilateral_infiltrates_detected                          9.386976e-03
# cardiac_arrest_detected                                -6.310242e-03
# cardiac_failure_detected                                2.377488e-03
# pancreatitis_detected                                   3.931517e-03
# pneumonia_detected                                      1.261465e-02
# trali_detected                                         -1.451015e-01
#
#                                 max_respiration_pao2fio2ratio_vent  \
# c_rsp_mod                                            -2.443041e-09
# c_rsp_svr                                             6.902425e-05
# c_vent_low                                           -2.959097e-09
# c_vent_moderate                                       1.529095e-03
# c_vent_high                                          -2.866030e-03
# c_max_renf_moderate                                   1.170438e-03
# c_max_renf_severe                                    -4.807468e-03
# c_avg_renf_moderate                                   2.056336e-03
# c_avg_renf_severe                                    -1.320303e-02
# c_max_respf_moderate                                 -1.171185e-05
# c_max_respf_severe                                    5.335154e-03
# c_avg_respf_moderate                                 -2.394589e-05
# c_avg_respf_severe                                    4.644783e-02
# c_max_cnsf_moderate                                  -3.588065e-04
# c_max_cnsf_severe                                     5.698959e-03
# c_avg_cnsf_moderate                                   2.975542e-03
# c_avg_cnsf_severe                                     2.025370e-02
# c_sepsis3                                            -6.787908e-03
# c_shock                                              -6.948059e-05
# ards_detected                                         1.778854e-03
# aspiration_detected                                   5.270060e-03
# bilateral_infiltrates_detected                       -6.933716e-03
# cardiac_arrest_detected                               2.678593e-03
# cardiac_failure_detected                             -3.790601e-03
# pancreatitis_detected                                 6.865761e-03
# pneumonia_detected                                   -9.302126e-03
# trali_detected                                       -4.427649e-02
#
#                                  avg_gcs_min  max_cns_gcs_min    sofa_score  \
# c_rsp_mod                       1.072669e-10     2.078176e-09  6.628482e-11
# c_rsp_svr                       1.112883e-05    -1.881493e-04 -2.792461e-04
# c_vent_low                      1.724232e-08     3.623115e-08  7.305318e-10
# c_vent_moderate                -3.351113e-03     2.312478e-02 -3.541800e-03
# c_vent_high                    -9.588415e-04     2.686922e-03 -1.049161e-03
# c_max_renf_moderate             3.081950e-03     1.561229e-02 -1.589694e-03
# c_max_renf_severe               7.138234e-03    -8.685859e-03 -4.368082e-03
# c_avg_renf_moderate             1.911246e-03    -2.259281e-03 -5.539003e-05
# c_avg_renf_severe               1.350948e-02     9.545206e-02 -5.087649e-02
# c_max_respf_moderate            6.723790e-06    -2.495552e-05 -8.209449e-06
# c_max_respf_severe             -4.906617e-02     3.670745e-02  2.814691e-02
# c_avg_respf_moderate            3.153988e-04     7.727238e-04 -1.076496e-04
# c_avg_respf_severe             -5.232830e-02     2.988557e-02  8.996577e-03
# c_max_cnsf_moderate             1.945523e-03     5.054529e-04  1.862091e-04
# c_max_cnsf_severe              -1.095094e-02    -3.472648e-02 -1.470268e-02
# c_avg_cnsf_moderate            -3.925489e-03    -1.116733e-03 -4.101851e-03
# c_avg_cnsf_severe              -6.984407e-03    -2.564924e-03 -1.174074e-02
# c_sepsis3                       7.266261e-03     1.288618e-02  3.461260e-03
# c_shock                         4.358575e-03    -4.425842e-03  2.917661e-03
# ards_detected                   2.850781e-03    -2.879308e-03  1.024192e-03
# aspiration_detected             2.525099e-02     6.331167e-02  5.831396e-02
# bilateral_infiltrates_detected  4.642496e-02     2.431149e-01  4.182545e-02
# cardiac_arrest_detected        -4.163379e-03     2.337292e-03 -8.220393e-03
# cardiac_failure_detected       -2.104720e-03    -2.110489e-03 -4.280794e-04
# pancreatitis_detected           2.309711e-04     1.157481e-02 -1.674377e-03
# pneumonia_detected              3.901818e-03    -1.447936e-01 -2.960819e-02
# trali_detected                  2.539608e-02    -8.000455e-02  5.486896e-02
#
#                                 suspected_infection  one_vasopressor  \
# c_rsp_mod                             -5.727781e-10     6.762077e-10
# c_rsp_svr                             -2.370896e-04    -8.955429e-05
# c_vent_low                             7.520982e-08    -1.889441e-08
# c_vent_moderate                        3.075974e-02    -7.220082e-03
# c_vent_high                           -2.926207e-03    -6.489039e-05
# c_max_renf_moderate                   -7.504343e-03     4.923170e-03
# c_max_renf_severe                      6.833227e-03    -5.173969e-03
# c_avg_renf_moderate                    7.820297e-04     5.699326e-03
# c_avg_renf_severe                      7.772275e-03     2.029546e-02
# c_max_respf_moderate                  -1.664161e-05     2.255468e-05
# c_max_respf_severe                    -2.631332e-02     5.959450e-02
# c_avg_respf_moderate                  -1.036887e-03    -1.568981e-03
# c_avg_respf_severe                    -9.089367e-02    -1.256920e-02
# c_max_cnsf_moderate                    5.269963e-04     9.640374e-04
# c_max_cnsf_severe                     -1.994907e-02     1.322289e-02
# c_avg_cnsf_moderate                    1.537672e-02    -5.938238e-03
# c_avg_cnsf_severe                     -6.645355e-03    -9.269680e-03
# c_sepsis3                             -5.695156e-02    -8.596328e-02
# c_shock                               -1.255574e-03    -4.577361e-03
# ards_detected                          4.375182e-04     1.334478e-03
# aspiration_detected                    3.863675e-02     5.794810e-02
# bilateral_infiltrates_detected        -1.166813e-01    -6.782472e-03
# cardiac_arrest_detected               -3.768424e-03     5.899766e-03
# cardiac_failure_detected              -3.397813e-03    -7.831784e-03
# pancreatitis_detected                  1.307191e-03    -5.514632e-03
# pneumonia_detected                     5.870962e-02     6.528788e-02
# trali_detected                         1.037717e-02    -3.923617e-02
#
#                                 multi_vasopressor
# c_rsp_mod                            5.093806e-10
# c_rsp_svr                           -2.738111e-04
# c_vent_low                           1.490486e-07
# c_vent_moderate                     -8.467358e-03
# c_vent_high                          2.873657e-03
# c_max_renf_moderate                 -6.317262e-03
# c_max_renf_severe                    1.525782e-03
# c_avg_renf_moderate                  1.051911e-02
# c_avg_renf_severe                    8.262098e-02
# c_max_respf_moderate                 4.871134e-06
# c_max_respf_severe                   5.081120e-02
# c_avg_respf_moderate                -1.586623e-03
# c_avg_respf_severe                   7.235532e-02
# c_max_cnsf_moderate                  1.866067e-07
# c_max_cnsf_severe                    7.762275e-04
# c_avg_cnsf_moderate                 -2.756780e-02
# c_avg_cnsf_severe                   -3.694055e-02
# c_sepsis3                           -6.943804e-02
# c_shock                             -2.925432e-03
# ards_detected                        1.553099e-03
# aspiration_detected                  6.506268e-02
# bilateral_infiltrates_detected      -3.493129e-02
# cardiac_arrest_detected              4.322783e-03
# cardiac_failure_detected            -1.332099e-03
# pancreatitis_detected               -7.084154e-03
# pneumonia_detected                   3.191913e-02
# trali_detected                      -1.855186e-02
#
# [27 rows x 26 columns]
